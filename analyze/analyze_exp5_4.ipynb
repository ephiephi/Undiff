# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os

# %%
def df_for_snr(snr_path):
    stats_path = os.path.join(snr_path, "stats_dns.json")
    with open(stats_path) as f:
        data = json.load(f)
    df = pd.DataFrame.from_dict(data).T.reset_index()
    for i in range(len(df)):
        df.at[i, "index"] = df["index"][i].split("s")[1]
    df["index"] = df["index"].astype(float)
    df = df.sort_values(by=['index']).reset_index(drop=True)
    df= df.rename(columns={"index": "s"})
    df.to_excel(os.path.join(snr_path,"measurements.xlsx"))

    return df

# %%
root = "/data/ephraim/datasets/known_noise/undiff/exp5_4/a/enhanced/"
root2 = "/data/ephraim/datasets/known_noise/undiff/exp5_4/b/enhanced/"
root2b = "/data/ephraim/datasets/known_noise/undiff/exp5_4/b/enhanced_2/"

# %%
df_for_snr(os.path.join(root, "snr10"))
# Out:
#          s                pesq                 stoi              pesq_diff  \
# 0  0.00001  1.0338506698608398   0.3915999141185741  -0.014637589454650879
# 1  0.00005  1.0866467952728271   0.8542154654928565   0.038158535957336426
# 2  0.00008  1.0545880794525146   0.8550829593737835   0.006099820137023926
# 3  0.00010  1.0456783771514893   0.8479606275079672  -0.002809882164001465
# 4  0.00100  1.0287013053894043  0.38866480406934817  -0.019786953926086426
# 5  0.01000  1.0801525115966797   0.4634876273915048   0.031664252281188965
# 6  0.10000  1.0801525115966797   0.4634876273915048   0.031664252281188965
# 7  0.90000  1.0801525115966797   0.4634876273915048   0.031664252281188965
# 8  1.00000  1.0801525115966797   0.4634876273915048   0.031664252281188965
# 9  1.10000  1.0801525115966797   0.4634876273915048   0.031664252281188965
#
#                stoi_diff                OVRL                 SIG  \
# 0   -0.45895453427293376   2.799629238434902   3.530280637887327
# 1   0.003661017101348696   2.090459181804556  3.5177656171481653
# 2   0.004528510982275691   2.029967676507305   3.542336820387193
# 3  -0.002593820883540654  1.9853080132361323  3.5211996296612327
# 4    -0.4618896443221597  1.2846186508240456  1.8044370025261085
# 5   -0.38706682100000306   2.050853804747207  2.3948427066511497
# 6   -0.38706682100000306   2.050853804747207  2.3948427066511497
# 7   -0.38706682100000306   2.050853804747207  2.3948427066511497
# 8   -0.38706682100000306   2.050853804747207  2.3948427066511497
# 9   -0.38706682100000306   2.050853804747207  2.3948427066511497
#
#                   BAK                                        enhance_dir  \
# 0   3.168493882985529  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1  1.8119963128055634  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2   1.693270302415139  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3  1.6478920785580886  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4  1.3313842243552478  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
# 9  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...
# 9  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2, "snr10"))
# Out:
#          s                pesq                 stoi               pesq_diff  \
# 0  0.00001   1.039435625076294   0.5464796162845134    -0.04342055320739746
# 1  0.00005   1.110709547996521    0.933883425166651     0.02785336971282959
# 2  0.00008  1.0925922393798828   0.9527329303454438    0.009736061096191406
# 3  0.00010  1.0797818899154663    0.946329407138277  -0.0030742883682250977
# 4  0.00100  1.0252562761306763  0.45306432672239233    -0.05759990215301514
# 5  0.01000    1.06905198097229   0.4905963120098233   -0.013804197311401367
# 6  0.10000    1.06905198097229   0.4905963120098233   -0.013804197311401367
# 7  0.90000    1.06905198097229   0.4905963120098233   -0.013804197311401367
# 8  1.00000    1.06905198097229   0.4905963120098233   -0.013804197311401367
# 9  1.10000    1.06905198097229   0.4905963120098233   -0.013804197311401367
#
#                 stoi_diff                OVRL                 SIG  \
# 0    -0.40160046013480455  2.6766153871398095  3.5285345517886464
# 1   -0.014196651252666892  2.2877568980391527  3.5539427618254393
# 2   0.0046528539261259105  2.3527711579495607   3.521857486903243
# 3  -0.0017506692810409508   2.325717278559993   3.515089641592151
# 4     -0.4950157496969256  1.1831341260766006  1.5272699953861406
# 5     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 6     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 7     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 8     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 9     -0.4574837644094946  2.0561589061114076   2.424318311745673
#
#                   BAK                                        enhance_dir  \
# 0   3.042367082421118  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1    2.33580123365877  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2  2.4509187894421705  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3   2.398243372876268  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4  1.2274679492093203  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 9   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...
# 9  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2b, "snr10"))
# Out:
#           s                pesq                stoi               pesq_diff  \
# 0  0.000050  1.1286684274673462   0.949701980202425    0.045812249183654785
# 1  0.000060   1.116242527961731  0.9569239460477326     0.03338634967803955
# 2  0.000070  1.1024227142333984  0.9553860748172265     0.01956653594970703
# 3  0.000075  1.0968396663665771  0.9541600243459484    0.013983488082885742
# 4  0.000080  1.0925170183181763  0.9529210759188483    0.009660840034484863
# 5  0.000085  1.0884290933609009  0.9512184505096678    0.005572915077209473
# 6  0.000090  1.0852653980255127    0.94933551561651    0.002409219741821289
# 7  0.000100  1.0797780752182007   0.946377565120356  -0.0030781030654907227
#
#                 stoi_diff                OVRL                 SIG  \
# 0   0.0016219037831071148  2.3671952029754166   3.505471110984374
# 1    0.008843869628414658  2.3663465877097942  3.5575199993823716
# 2    0.007305998397908575  2.3622899894909004  3.5339200448780277
# 3    0.006079947926630469    2.34500757553334   3.519219788715632
# 4   0.0048409994995304295  2.3675864475961714  3.5287755869025093
# 5   0.0031383740903498936   2.343452680425249  3.5151953929990247
# 6   0.0012554391971920653  2.3435533733885654   3.519047817021877
# 7  -0.0017025112989619284  2.3303255652836237   3.517158987857969
#
#                   BAK                                        enhance_dir  \
# 0  2.5074754632517537  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1   2.446520027273107  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2  2.4629340364802426  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3   2.441143421215499  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4  2.4712865243011826  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5  2.4310368741776225  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6  2.4303251159816197  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7  2.4037013732605073  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
enhance_dir = os.path.join(root, "snr10/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5_4/a/enhanced/snr10/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    1.000000    1.000000       1.000000         1.0000   1.000000
# mean     1.048488    0.850554       1.033851         0.3916  -0.014638
# std           NaN         NaN            NaN            NaN        NaN
# min      1.048488    0.850554       1.033851         0.3916  -0.014638
# 25%      1.048488    0.850554       1.033851         0.3916  -0.014638
# 50%      1.048488    0.850554       1.033851         0.3916  -0.014638
# 75%      1.048488    0.850554       1.033851         0.3916  -0.014638
# max      1.048488    0.850554       1.033851         0.3916  -0.014638
#
#        stoi_diff
# count   1.000000
# mean   -0.458955
# std          NaN
# min    -0.458955
# 25%    -0.458955
# 50%    -0.458955
# 75%    -0.458955
# max    -0.458955

# %%
enhance_dir = os.path.join(root2, "snr10/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5_4/b/enhanced/snr10/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    1.000000     1.00000       1.000000        1.00000   1.000000
# mean     1.082856     0.94808       1.039436        0.54648  -0.043421
# std           NaN         NaN            NaN            NaN        NaN
# min      1.082856     0.94808       1.039436        0.54648  -0.043421
# 25%      1.082856     0.94808       1.039436        0.54648  -0.043421
# 50%      1.082856     0.94808       1.039436        0.54648  -0.043421
# 75%      1.082856     0.94808       1.039436        0.54648  -0.043421
# max      1.082856     0.94808       1.039436        0.54648  -0.043421
#
#        stoi_diff
# count     1.0000
# mean     -0.4016
# std          NaN
# min      -0.4016
# 25%      -0.4016
# 50%      -0.4016
# 75%      -0.4016
# max      -0.4016

# %%
enhance_dir = os.path.join(root, "snr5/s0.0003")
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr5/s0.0003/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.059176       0.815065  -0.014690
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.059176       0.815065  -0.090425
# 25%      1.035998    0.815752       1.059176       0.815065  -0.039869
# 50%      1.048488    0.850554       1.059176       0.815065   0.010688
# 75%      1.099045    0.876377       1.059176       0.815065   0.023177
# max      1.149601    0.902200       1.059176       0.815065   0.035667
#
#        stoi_diff
# count   3.000000
# mean   -0.029503
# std     0.060847
# min    -0.087135
# 25%    -0.061313
# 50%    -0.035490
# 75%    -0.000687
# max     0.034115
