# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os
from pathlib import Path

# %%
def get_df2(dir,enh_type):
    exp_dir = Path("/data/ephraim/datasets/known_noise/undiff/exp_ar_i_real_freq")/dir
    pkl_results_file = os.path.join(exp_dir, f"measures_{enh_type}.pickle")
    # print(pkl_results_file)

    with open(pkl_results_file, "rb") as handle:
        dfme = pd.read_pickle(handle)
    return dfme

# %%
def best(func,enh_type, dirs="b" ):
    mine = None
    df_noisy = None
    for d in dirs: 
        if func(d,enh_type) is None:
            continue
        dfme = func(d,enh_type)
        dfme = dfme.assign(dir=d)
        cur_df_noisy = dfme[dfme["name"]=="noisy"].reset_index(drop=True)
        cur_df_noisy.loc[0,"dir"] = d
        if df_noisy is None:
            df_noisy = cur_df_noisy
        else:
            df_noisy = pd.concat([df_noisy, cur_df_noisy])
        dfme = dfme[dfme["name"] != "noisy"]
        dfme_5 = dfme[dfme["snr"]=="5"]
        dfme5 = dfme_5[dfme_5["stoi"]>0.5]
        dfme5 = dfme_5[dfme_5["si_sdr"]>0.0]
        cols =["dir","name","stoi","input_stoi","pesq","input_pesq","OVRL","SIG","BAK","si_sdr",'sdr', "sar",'sir',"noise_type", "filename"]
        NOISES = ["Car","Babble","Room","Factory","Speech"]
        for noisetype in NOISES :
            cur_mine = dfme5[dfme5["noise_type"]==noisetype]
            cur_mine = cur_mine[cur_mine["pesq"] ==cur_mine["pesq"].max()].reset_index(drop=True)[cols]
            # cur_mine.loc[0,"dir"] = d
            if mine is None:
                mine = cur_mine
            else:
                mine = pd.concat([mine, cur_mine])
    mine=mine.reset_index(drop=True)
    return mine[["stoi","pesq","name","si_sdr","OVRL","SIG","BAK","noise_type","dir"]]

# %%
mine = None
df_noisy = None
for d in "b": 
    if get_df(d) is None:
        continue
    dfme = get_df(d)
    dfme = dfme.assign(dir=d)
    cur_df_noisy = dfme[dfme["name"]=="noisy"].reset_index(drop=True)
    cur_df_noisy.loc[0,"dir"] = d
    if df_noisy is None:
        df_noisy = cur_df_noisy
    else:
        df_noisy = pd.concat([df_noisy, cur_df_noisy])
    dfme = dfme[dfme["name"] != "noisy"]
    dfme_5 = dfme[dfme["snr"]=="5"]
    dfme5 = dfme_5[dfme_5["stoi"]>0.5]
    dfme5 = dfme_5[dfme_5["si_sdr"]>0.0]
    cols =["dir","name","stoi","input_stoi","pesq","input_pesq","OVRL","SIG","BAK","si_sdr",'sdr', "sar",'sir',"noise_type", "filename"]
    NOISES = ["Car","Babble","Room","Factory","Speech"]
    for noisetype in NOISES :
        cur_mine = dfme5[dfme5["noise_type"]==noisetype]
        cur_mine = cur_mine[cur_mine["pesq"] ==cur_mine["pesq"].max()].reset_index(drop=True)[cols]
        # cur_mine.loc[0,"dir"] = d
        if mine is None:
            mine = cur_mine
        else:
            mine = pd.concat([mine, cur_mine])
mine=mine.reset_index(drop=True)
mine[["stoi","pesq","name","si_sdr","OVRL","SIG","BAK","noise_type","dir"]]
# Out:
#        stoi      pesq   name     si_sdr      OVRL       SIG       BAK  \
# 0  0.958182  1.398454  s0.06  13.660651  2.704530  3.564754  3.059687
# 1  0.867668  1.161091  s0.07   7.656960  2.138805  3.308524  2.292542
# 2  0.904098  1.258870  s0.06   8.826588  2.594425  3.530742  2.928851
# 3  0.877937  1.225953  s0.06   8.631515  2.255678  3.385633  2.433926
# 4  0.874211  1.267511  s0.06   7.785585  2.553145  3.543476  2.797705
#
#   noise_type dir
# 0        Car   b
# 1     Babble   b
# 2       Room   b
# 3    Factory   b
# 4     Speech   b

# %%
best(get_df2,"enhanced_50", dirs="b" )
# Out:
#        stoi      pesq   name     si_sdr      OVRL       SIG       BAK  \
# 0  0.954359  1.376534  s0.08  11.517978  2.648852  3.529621  3.009853
# 1  0.869152  1.185173  s0.09   6.198558  1.939798  3.275911  1.826645
# 2  0.905470  1.236652   s0.1   6.895669  2.165124  3.453503  2.149363
# 3  0.875589  1.233149  s0.04   8.403200  2.882501  3.440270  3.541321
# 4  0.881728  1.229208  s0.04   6.819245  2.561037  3.365776  3.019327
#
#   noise_type dir
# 0        Car   b
# 1     Babble   b
# 2       Room   b
# 3    Factory   b
# 4     Speech   b

# %%
best(get_df2,"enhanced_70", dirs="b" )
# Out:
#        stoi      pesq   name     si_sdr      OVRL       SIG       BAK  \
# 0  0.945869  1.355647  s0.04  13.284158  2.665343  3.509293  3.045419
# 1  0.857561  1.165542  s0.07   5.395995  2.157625  3.425514  2.249041
# 2  0.909892  1.239618  s0.07   9.293389  2.375473  3.575078  2.400708
# 3  0.873749  1.209693  s0.04   8.591170  2.705359  3.461369  3.128164
# 4  0.887670  1.189299  s0.06   7.543113  2.199032  3.396130  2.319069
#
#   noise_type dir
# 0        Car   b
# 1     Babble   b
# 2       Room   b
# 3    Factory   b
# 4     Speech   b

# %%
best(get_df2,"enhanced_constant", dirs="b" )
# Out:
#        stoi      pesq   name     si_sdr      OVRL       SIG       BAK  \
# 0  0.954302  1.181781  s0.01  11.884570  2.425841  3.522840  2.619391
# 1  0.785481  1.061288  s0.01   1.225562  1.132703  1.250097  1.085187
# 2  0.806802  1.082602  s0.01   3.400340  2.301844  3.505908  2.249751
# 3  0.844679  1.119358  s0.01   6.719692  2.295842  3.428011  2.535821
# 4  0.799403  1.065090  s0.01   2.270824  2.232239  3.383477  2.379073
#
#   noise_type dir
# 0        Car   b
# 1     Babble   b
# 2       Room   b
# 3    Factory   b
# 4     Speech   b

# %%
best(get_df2,"enhanced_sinusoidal", dirs="b" )
# Out:
# Empty DataFrame
# Columns: [stoi, pesq, name, si_sdr, OVRL, SIG, BAK, noise_type, dir]
# Index: []

# %%
ddd = get_df2("b","enhanced_constant")
ddd[["stoi","pesq","name","si_sdr","OVRL","SIG","BAK","noise_type"]]
# Out:
#         stoi      pesq   name     si_sdr      OVRL       SIG       BAK  \
# 0   0.443116  1.049195  s0.04 -75.989410  1.615678  1.975998  3.605592
# 1   0.487512  1.025636  s0.04 -75.392319  1.482764  1.867124  3.478506
# 2   0.815394  1.132609  s0.04 -58.259205  1.517693  2.017272  3.468282
# 3   0.831504  1.088497  s0.04 -43.032928  1.650216  1.960825  3.678943
# 4   0.754270  1.185755  s0.04 -66.510979  1.424779  1.872194  3.196842
# 5  -0.000418  1.084459  s0.06 -79.669205  1.547163  2.309586  2.011494
# 6  -0.001160  1.071846  s0.06 -79.999573  1.469180  2.181433  2.436330
# 7  -0.079132  1.076283  s0.06 -79.995834  1.360787  1.926367  2.617344
# 8  -0.081941  1.100185  s0.06 -79.994400  1.455473  1.988109  2.710627
# 9  -0.173228  1.094210  s0.06 -80.000000  1.363399  1.864974  2.714111
# 10 -0.000323  1.071220  s0.07 -79.882568  1.371006  2.078899  2.041605
# 11 -0.180661  1.065338  s0.07 -79.974930  1.239024  1.683018  2.573588
# 12  0.000028  1.072035  s0.07 -79.996262  1.441458  2.117420  2.171622
# 13  0.000021  1.066138  s0.07 -79.999985  1.524587  2.252648  2.254038
# 14  0.000334  1.071208  s0.07 -79.972275  1.549120  2.294325  2.014874
# 15 -0.000354  1.081681  s0.08 -79.664978  1.522541  2.264030  2.107092
# 16 -0.000926  1.068538  s0.08 -79.999855  1.452622  2.160503  2.335903
# 17 -0.000937  1.068743  s0.08 -79.985199  1.483679  2.227320  2.438801
# 18 -0.000115  1.068447  s0.08 -79.998795  1.479066  2.184628  2.504543
# 19 -0.000205  1.072186  s0.08 -79.991730  1.499383  2.247014  2.118452
# 20 -0.000325  1.070477  s0.09 -79.998558  1.417172  2.117015  2.098021
# 21  0.000336  1.072510  s0.09 -79.999481  1.525014  2.281401  2.098781
# 22  0.000105  1.070962  s0.09 -79.990067  1.372976  2.067398  2.009743
# 23  0.000019  1.073124  s0.09 -79.993927  1.469139  2.213712  2.108898
# 24  0.000428  1.067503  s0.09 -79.999992  1.430241  2.150563  2.000844
# 25 -0.000349  1.077028   s0.1 -79.545975  1.442191  2.149095  2.104629
# 26 -0.001145  1.070671   s0.1 -79.992256  1.543628  2.280231  2.461900
# 27  0.000276  1.069510   s0.1 -79.987862  1.425318  2.082457  2.189518
# 28  0.000443  1.063948   s0.1 -79.972954  1.503305  2.251477  2.111233
# 29  0.000242  1.073346   s0.1 -79.999901  1.507513  2.268240  2.243482
# 30 -0.000470  1.079284  s0.12 -79.964050  1.506683  2.236138  2.119465
# 31  0.000382  1.075722  s0.12 -79.996559  1.384952  2.062311  2.133762
# 32  0.000150  1.069808  s0.12 -79.998459  1.395663  2.079438  2.080678
# 33  0.000177  1.068226  s0.12 -79.998116  1.432211  2.123931  2.122297
# 34  0.000565  1.063754  s0.12 -79.999443  1.459203  2.204570  2.405724
# 35 -0.000182  1.069343  s0.15 -79.992607  1.505315  2.271150  2.326522
# 36  0.000367  1.072312  s0.15 -79.989014  1.515387  2.245287  2.250506
# 37 -0.000794  1.073586  s0.15 -79.999214  1.453407  2.151651  2.245099
# 38 -0.000164  1.071023  s0.15 -79.986412  1.479744  2.185668  2.143071
# 39  0.000373  1.070021  s0.15 -79.986084  1.517063  2.252153  2.046224
# 40  0.954302  1.181781  s0.01  11.884570  2.425841  3.522840  2.619391
# 41  0.785481  1.061288  s0.01   1.225562  1.132703  1.250097  1.085187
# 42  0.806802  1.082602  s0.01   3.400340  2.301844  3.505908  2.249751
# 43  0.844679  1.119358  s0.01   6.719692  2.295842  3.428011  2.535821
# 44  0.799403  1.065090  s0.01   2.270824  2.232239  3.383477  2.379073
# 0   0.949485  1.450840  noisy   3.399018  2.572152  3.544472  2.829959
# 1   0.811560  1.094499  noisy   3.379046  1.303753  1.756922  1.302023
# 2   0.849798  1.098094  noisy   3.426823  1.326090  2.071808  1.272048
# 3   0.788819  1.050884  noisy   3.390694  1.449310  2.429013  1.405593
# 4   0.814749  1.070846  noisy   3.478303  1.317856  1.940656  1.309525
# 5   0.975945  1.986190  noisy   8.398449  2.749611  3.579381  3.115361
# 6   0.898844  1.200251  noisy   8.386578  2.112767  3.381407  2.138635
# 7   0.929015  1.232241  noisy   8.413836  2.039281  3.392018  1.883620
# 8   0.899186  1.117313  noisy   8.396352  2.142419  3.441292  2.058755
# 9   0.904541  1.145853  noisy   8.445883  2.056880  3.454111  1.908877
#
#    noise_type
# 0         Car
# 1      Babble
# 2        Room
# 3     Factory
# 4      Speech
# 5         Car
# 6      Babble
# 7        Room
# 8     Factory
# 9      Speech
# 10        Car
# 11     Babble
# 12       Room
# 13    Factory
# 14     Speech
# 15        Car
# 16     Babble
# 17       Room
# 18    Factory
# 19     Speech
# 20        Car
# 21     Babble
# 22       Room
# 23    Factory
# 24     Speech
# 25        Car
# 26     Babble
# 27       Room
# 28    Factory
# 29     Speech
# 30        Car
# 31     Babble
# 32       Room
# 33    Factory
# 34     Speech
# 35        Car
# 36     Babble
# 37       Room
# 38    Factory
# 39     Speech
# 40        Car
# 41     Babble
# 42       Room
# 43    Factory
# 44     Speech
# 0         Car
# 1      Babble
# 2        Room
# 3     Factory
# 4      Speech
# 5         Car
# 6      Babble
# 7        Room
# 8     Factory
# 9      Speech

# %%
def get_df(dir):
    exp_dir = Path("/data/ephraim/datasets/known_noise/undiff/exp_ar_i_real_freq")/dir
    pkl_results_file = os.path.join(exp_dir, "measures.pickle")
    # print(pkl_results_file)

    with open(pkl_results_file, "rb") as handle:
        dfme = pd.read_pickle(handle)
    return dfme

# %%
pkl_results_file = "/data/ephraim/datasets/known_noise/sgmse/exp_i/storm_vbd/enhanced_real/measures_storm.pickle"

with open(pkl_results_file, "rb") as handle:
    df2 = pd.read_pickle(handle)
for i in range(len(df2["snr"])):
    df2.at[i, "snr"] = df2["snr"][i].split("_")[0]

# %%
df_storm_5 = df2[df2["snr"]=="5"].reset_index(drop=True).sort_values(by=['dir'])

# %%
df_storm_5["noise_type"][2]
# Out:
# 'Factory'

# %%
pkl_results_file = "/data/ephraim/datasets/known_noise/sgmse/exp_i/sgmse_WSJ0Chime3/enhanced_real/measures_storm.pickle"

with open(pkl_results_file, "rb") as handle:
    df1 = pd.read_pickle(handle)
for i in range(len(df1["snr"])):
    df1.at[i, "snr"] = df1["snr"][i].split("_")[0]

# %%
df_sg_5 = df1[df1["snr"]=="5"].reset_index(drop=True).sort_values(by=['dir'])

# %%
df_sg_5["noise_type"][2]
# Out:
# 'Factory'

# %%
dfme = get_df("b")
dfme5 = dfme[dfme["snr"]=="5"]
dfme5.columns
# dfme5[["stoi","pesq","name","sdr","noise_type","OVRL","name"]]
# Out:
# Index(['input_si_sdr', 'input_sdr', 'input_sir', 'input_sar', 'input_stoi',
#        'input_pesq', 'si_sdr', 'sdr', 'sir', 'sar', 'stoi', 'pesq', 'name',
#        'filename', 'snr', 'noise_type', 'len_in_sec', 'sr', 'num_hops',
#        'OVRL_raw', 'SIG_raw', 'BAK_raw', 'OVRL', 'SIG', 'BAK', 'P808_MOS'],
#       dtype='object')

# %%
dfme5[["stoi","pesq","name","sdr","noise_type","OVRL","name"]]
# Out:
#         stoi      pesq   name       sdr noise_type      OVRL   name
# 0   0.951289  1.707156  s0.08 -7.007517        Car  2.871114  s0.08
# 1   0.861448  1.143089  s0.08  5.716976     Babble  2.074874  s0.08
# 2   0.900278  1.206448  s0.08  8.704413       Room  2.184801  s0.08
# 3   0.855052  1.209033  s0.08  8.995117    Factory  2.003319  s0.08
# 4   0.845591  1.205385  s0.08  7.931415     Speech  2.342523  s0.08
# ..       ...       ...    ...       ...        ...       ...    ...
# 0   0.949485  1.450840  noisy  3.418408        Car  2.572152  noisy
# 1   0.811560  1.094499  noisy  3.481235     Babble  1.303753  noisy
# 2   0.849798  1.098094  noisy  3.498583       Room  1.326090  noisy
# 3   0.788819  1.050884  noisy  3.472528    Factory  1.449310  noisy
# 4   0.814749  1.070846  noisy  3.588195     Speech  1.317856  noisy
#
# [87 rows x 7 columns]

# %%
dfme5[dfme5["noise_type"]=="Speech"][["stoi","pesq","name","sdr","noise_type","OVRL","name"]]
# Out:
#         stoi      pesq   name        sdr noise_type      OVRL   name
# 4   0.845591  1.205385  s0.08   7.931415     Speech  2.342523  s0.08
# 9   0.844765  1.036694   s0.1 -41.319191     Speech  1.556230   s0.1
# 14  0.000040  1.072614  s0.15 -93.580579     Speech  1.494835  s0.15
# 19 -0.001294  1.069574   s0.2 -83.991592     Speech  1.495935   s0.2
# 24  0.490596  1.069052   s0.5  -9.963103     Speech  2.056159   s0.5
# 29  0.490596  1.069052   s0.7  -9.963103     Speech  2.056159   s0.7
# 34  0.151895  1.111551  s0.11 -85.773455     Speech  1.354089  s0.11
# 39  0.000804  1.064994  s0.12 -78.972445     Speech  1.449455  s0.12
# 44  0.000374  1.067996   s0.3 -89.020008     Speech  1.443755   s0.3
# 49  0.490596  1.069052   s0.8  -9.963103     Speech  2.056159   s0.8
# 54  0.670118  1.063429  s0.01   5.265230     Speech  2.099880  s0.01
# 59  0.852247  1.233961  s0.04   8.522827     Speech  2.820812  s0.04
# 64  0.874211  1.267511  s0.06   9.106492     Speech  2.553145  s0.06
# 69  0.878141  1.159647  s0.07   8.281570     Speech  2.360968  s0.07
# 74  0.862880  1.119339  s0.09 -27.975288     Speech  1.964660  s0.09
# 81  0.884634  1.181394  s0.05   8.787351     Speech  2.565764  s0.05
# 4   0.814749  1.070846  noisy   3.588195     Speech  1.317856  noisy

# %%
mine = None
df_noisy = None
for d in "abcdefghij": 
    if get_df(d) is None:
        continue
    dfme = get_df(d)
    dfme = dfme.assign(dir=d)
    cur_df_noisy = dfme[dfme["name"]=="noisy"].reset_index(drop=True)
    cur_df_noisy.loc[0,"dir"] = d
    if df_noisy is None:
        df_noisy = cur_df_noisy
    else:
        df_noisy = pd.concat([df_noisy, cur_df_noisy])
    dfme = dfme[dfme["name"] != "noisy"]
    dfme_5 = dfme[dfme["snr"]=="5"]
    dfme5 = dfme_5[dfme_5["stoi"]>0.5]
    dfme5 = dfme_5[dfme_5["si_sdr"]>0.0]
    cols =["dir","name","stoi","input_stoi","pesq","input_pesq","OVRL","SIG","BAK","si_sdr",'sdr', "sar",'sir',"noise_type", "filename"]
    NOISES = ["Car","Babble","Room","Factory","Speech"]
    for noisetype in NOISES :
        cur_mine = dfme5[dfme5["noise_type"]==noisetype]
        cur_mine = cur_mine[cur_mine["pesq"] ==cur_mine["pesq"].max()].reset_index(drop=True)[cols]
        # cur_mine.loc[0,"dir"] = d
        if mine is None:
            mine = cur_mine
        else:
            mine = pd.concat([mine, cur_mine])
mine=mine.reset_index(drop=True)
mine[["stoi","pesq","name","si_sdr","OVRL","SIG","BAK","noise_type","dir"]]
# dfme5[dfme5["pasq"]][["stoi","pesq","name","si_sdr","OVRL","SIG","BAK"]]
# Out:
#         stoi      pesq    name     si_sdr      OVRL       SIG       BAK  \
# 0   0.869590  1.303951   s0.05  13.219555  2.588476  3.545048  2.769215
# 1   0.789678  1.209189   s0.05   8.296641  2.314856  3.500724  2.333461
# 2   0.783910  1.216113   s0.06   9.599147  2.188923  3.461140  1.960687
# 3   0.796191  1.259398   s0.04   9.437238  2.598039  3.486083  2.808521
# 4   0.792051  1.224145  s0.055   8.891444  2.199174  3.375086  2.183514
# 5   0.958182  1.398454   s0.06  13.660651  2.704530  3.564754  3.059687
# 6   0.867668  1.161091   s0.07   7.656960  2.138805  3.308524  2.292542
# 7   0.904098  1.258870   s0.06   8.826588  2.594425  3.530742  2.928851
# 8   0.877937  1.225953   s0.06   8.631515  2.255678  3.385633  2.433926
# 9   0.874211  1.267511   s0.06   7.785585  2.553145  3.543476  2.797705
# 10  0.873442  1.193813   s0.04  11.974384  2.361731  3.410512  2.576923
# 11  0.797722  1.157869   s0.05   7.756507  2.488107  3.437832  2.712152
# 12  0.807859  1.139493   s0.05   8.132334  2.349418  3.425470  2.484449
# 13  0.798830  1.197898   s0.05   8.658771  2.232261  3.305948  2.381340
# 14  0.743635  1.129436   s0.07   7.124791  1.968472  3.153083  2.037819
# 15  0.870292  1.143136   s0.07   6.182115  2.584180  3.412967  2.936584
# 16  0.723459  1.066144   s0.08   1.388013  2.113088  3.029432  2.676768
# 17  0.781241  1.085570   s0.05   7.907474  2.304794  3.237567  2.542306
#
#    noise_type dir
# 0         Car   a
# 1      Babble   a
# 2        Room   a
# 3     Factory   a
# 4      Speech   a
# 5         Car   b
# 6      Babble   b
# 7        Room   b
# 8     Factory   b
# 9      Speech   b
# 10        Car   c
# 11     Babble   c
# 12       Room   c
# 13    Factory   c
# 14     Speech   c
# 15        Car   d
# 16     Babble   d
# 17       Room   d

# %%
for noisetype in NOISES:
    noise_mine  = mine[mine["noise_type"]==noisetype]
    noise_mine.to_excel(f"/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/ours_{noisetype}.xlsx")

# %%
for noisetype in NOISES:
    noise_df_sg_5 = df_sg_5[df_sg_5["noise_type"]==noisetype]
    noise_df_sg_5[cols].to_excel(f"/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/sgmse_{noisetype}.xlsx")
# df_sg_5[cols].describe()[1:3].to_excel("/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/sgmse_stats.xlsx")

# %%
for noisetype in NOISES:
    noise_df_storm_5 = df_storm_5[df_storm_5["noise_type"]==noisetype]
    noise_df_storm_5[cols].to_excel(f"/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/storm_{noisetype}.xlsx")
    # df_storm_5[cols].describe()[1:3].to_excel("/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/storm_stats.xlsx")

# %%
mine.head()
# Out:
#   dir   name      stoi  input_stoi      pesq  input_pesq      OVRL       SIG  \
# 0   a   s0.3  0.939825    0.924115  1.383912    1.305760  2.659904  3.536586
# 1   a  s0.11  0.823307    0.720964  1.280107    1.057805  3.182914  3.478178
# 2   a  s0.12  0.817155    0.758443  1.240639    1.053132  2.381563  3.518393
# 3   a  s0.11  0.799380    0.699227  1.310608    1.032454  2.753213  3.355914
# 4   a   s0.1  0.817351    0.719912  1.360432    1.038966  3.067470  3.371378
#
#         BAK     si_sdr        sdr        sar  sir noise_type  \
# 0  2.907966   4.052824   4.122058   4.122058  inf        Car
# 1  4.028701   9.817067  10.241671  10.241671  inf     Babble
# 2  2.331776   8.819594   9.239682   9.239682  inf       Room
# 3  3.358786   9.963297  10.560804  10.560804  inf    Factory
# 4  3.958709  10.687693  11.307800  11.307800  inf     Speech
#
#                                             filename
# 0  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4  /data/ephraim/datasets/known_noise/undiff/exp_...

# %%
for i in range(len(df_storm_5["dir"])):
    dir_ = df_storm_5["dir"][i]
    noisetype = df_storm_5["noise_type"][i]
    mine_parallel = mine[(mine["dir"]==dir_) & (mine["noise_type"]==noisetype)]
    if len(mine_parallel)==0:
        idx = df_storm_5[(df_storm_5.dir==dir_)&(df_storm_5.noise_type==noisetype)].index
        df_storm_5 = df_storm_5.drop(idx)

# %%
for i in range(len(df_sg_5["dir"])):
    dir_ = df_sg_5["dir"][i]
    noisetype = df_sg_5["noise_type"][i]
    mine_parallel = mine[(mine["dir"]==dir_) & (mine["noise_type"]==noisetype)]
    if len(mine_parallel)==0:
        idx = df_sg_5[(df_sg_5.dir==dir_)&(df_sg_5.noise_type==noisetype)].index
        df_sg_5 = df_sg_5.drop(idx)

# %%
minestats = mine.describe()[1:3]
minestats = minestats.assign(alg="ours")
df_storm_5stats = df_storm_5[cols].describe()[1:3]
df_storm_5stats = df_storm_5stats.assign(alg="storm")
df_sg_5stats = df_sg_5[cols].describe()[1:3]
df_sg_5stats = df_sg_5stats.assign(alg="sgmse")
statsdf = pd.concat([minestats,df_sg_5stats,df_storm_5stats])
statsdf.to_excel("/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/all_stats.xlsx")
#
# Out:
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
for noisetype in NOISES:
    noise_mine = mine[mine["noise_type"]==noisetype]
    minestats = noise_mine.describe()[1:3]
    minestats = minestats.assign(alg="ours")
    
    noisedf_storm_5 =  df_storm_5[df_storm_5["noise_type"]==noisetype]
    df_storm_5stats = noisedf_storm_5[cols].describe()[1:3]
    df_storm_5stats = df_storm_5stats.assign(alg="storm")
    
    noise_df_sg_5 = df_sg_5[df_sg_5["noise_type"]==noisetype]
    df_sg_5stats = noise_df_sg_5[cols].describe()[1:3]
    df_sg_5stats = df_sg_5stats.assign(alg="sgmse")
    statsdf = pd.concat([minestats,df_sg_5stats,df_storm_5stats])
    statsdf.to_excel(f"/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/stats_{noisetype}.xlsx")
# Out:
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
mine[mine["dir"]=="b"]["filename"].values[0]
# Out:
# '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.1/digits_snr5_power0.0032503484660146675_var0.0003345966415635422.wav'

# %%
mine
# Out:
#    dir   name      stoi  input_stoi      pesq  input_pesq      OVRL       SIG  \
# 0    a   s0.3  0.939825    0.924115  1.383912    1.305760  2.659904  3.536586
# 1    a  s0.11  0.823307    0.720964  1.280107    1.057805  3.182914  3.478178
# 2    a  s0.12  0.817155    0.758443  1.240639    1.053132  2.381563  3.518393
# 3    a  s0.11  0.799380    0.699227  1.310608    1.032454  2.753213  3.355914
# 4    a   s0.1  0.817351    0.719912  1.360432    1.038966  3.067470  3.371378
# 5    b   s0.5  0.966272    0.949485  1.484406    1.450840  2.822509  3.554529
# 6    b   s0.1  0.919819    0.811560  1.344813    1.094499  2.490880  2.983444
# 7    b  s0.11  0.927087    0.849798  1.350227    1.098094  2.775957  3.461169
# 8    b   s0.2  0.889186    0.788819  1.303768    1.050884  2.396726  3.502589
# 9    b   s0.1  0.921975    0.814749  1.410096    1.070846  3.068494  3.506921
# 10   c   s0.5  0.930945    0.903866  1.487049    1.329980  2.785427  3.434315
# 11   c  s0.11  0.826691    0.727911  1.328989    1.072707  2.717979  3.243343
# 12   c  s0.12  0.825916    0.768282  1.320936    1.071792  2.317762  3.332677
# 13   c   s0.1  0.831551    0.710416  1.332999    1.042651  2.801620  3.251211
# 14   c  s0.08  0.817308    0.732532  1.327853    1.055121  2.743716  3.129081
# 15   d   s0.3  0.933738    0.959705  1.358292    1.380368  2.974151  3.436723
# 16   d  s0.15  0.834732    0.794016  1.231005    1.135045  2.286238  3.197840
# 17   d  s0.15  0.837439    0.803903  1.259797    1.110713  2.394743  3.362707
# 18   d  s0.15  0.839677    0.764054  1.284734    1.053340  2.657996  3.502245
# 19   d  s0.11  0.855771    0.781006  1.283714    1.085858  2.742617  3.190600
# 20   e   s0.5  0.801988    0.970316  1.207544    1.300624  3.230736  3.634418
# 21   g   s0.7  0.622548    0.911020  1.271922    1.439448  1.884654  2.326055
# 22   g   s0.3  0.547625    0.601060  1.293821    1.071339  1.754705  2.272896
# 23   g   s0.3  0.596486    0.635764  1.292042    1.074896  1.178298  1.320955
# 24   g   s0.2  0.554213    0.563224  1.284709    1.046265  2.548240  3.018102
# 25   g   s0.3  0.570321    0.603332  1.276339    1.050435  1.837662  2.413867
#
#          BAK     si_sdr        sdr        sar  sir noise_type  \
# 0   2.907966   4.052824   4.122058   4.122058  inf        Car
# 1   4.028701   9.817067  10.241671  10.241671  inf     Babble
# 2   2.331776   8.819594   9.239682   9.239682  inf       Room
# 3   3.358786   9.963297  10.560804  10.560804  inf    Factory
# 4   3.958709  10.687693  11.307800  11.307800  inf     Speech
# 5   3.287671   3.634245   3.677216   3.677216  inf        Car
# 6   3.459883   9.103237  10.111362  10.111362  inf     Babble
# 7   3.243907   8.437196   9.193236   9.193236  inf       Room
# 8   2.550169   8.345171   8.744496   8.744496  inf    Factory
# 9   3.792855   9.492676  10.583368  10.583368  inf     Speech
# 10  3.353409   3.477432   3.535534   3.535534  inf        Car
# 11  3.472535   8.963179   9.469522   9.469522  inf     Babble
# 12  2.580552   8.043703   8.459894   8.459894  inf       Room
# 13  3.601769   9.394425  10.249101  10.249101  inf    Factory
# 14  3.668252   8.871036   9.845259   9.845259  inf     Speech
# 15  3.726189   3.244414   3.257955   3.257955  inf        Car
# 16  2.780303   7.042177   7.239135   7.239135  inf     Babble
# 17  2.625331   7.189383   7.403234   7.403234  inf       Room
# 18  2.948729   8.838657   9.093274   9.093274  inf    Factory
# 19  3.563788   9.605022  10.083327  10.083327  inf     Speech
# 20  3.935822   4.367503   2.347105   2.347105  inf        Car
# 21  2.657492   2.742744   2.843352   2.843352  inf        Car
# 22  3.196079   6.590670   6.916094   6.916094  inf     Babble
# 23  1.405203   5.335276   4.608346   4.608346  inf       Room
# 24  3.801812   8.015369   8.244029   8.244029  inf    Factory
# 25  3.039018   8.260644   8.739818   8.739818  inf     Speech
#
#                                              filename
# 0   /data/ephraim/datasets/known_noise/undiff/exp_...
# 1   /data/ephraim/datasets/known_noise/undiff/exp_...
# 2   /data/ephraim/datasets/known_noise/undiff/exp_...
# 3   /data/ephraim/datasets/known_noise/undiff/exp_...
# 4   /data/ephraim/datasets/known_noise/undiff/exp_...
# 5   /data/ephraim/datasets/known_noise/undiff/exp_...
# 6   /data/ephraim/datasets/known_noise/undiff/exp_...
# 7   /data/ephraim/datasets/known_noise/undiff/exp_...
# 8   /data/ephraim/datasets/known_noise/undiff/exp_...
# 9   /data/ephraim/datasets/known_noise/undiff/exp_...
# 10  /data/ephraim/datasets/known_noise/undiff/exp_...
# 11  /data/ephraim/datasets/known_noise/undiff/exp_...
# 12  /data/ephraim/datasets/known_noise/undiff/exp_...
# 13  /data/ephraim/datasets/known_noise/undiff/exp_...
# 14  /data/ephraim/datasets/known_noise/undiff/exp_...
# 15  /data/ephraim/datasets/known_noise/undiff/exp_...
# 16  /data/ephraim/datasets/known_noise/undiff/exp_...
# 17  /data/ephraim/datasets/known_noise/undiff/exp_...
# 18  /data/ephraim/datasets/known_noise/undiff/exp_...
# 19  /data/ephraim/datasets/known_noise/undiff/exp_...
# 20  /data/ephraim/datasets/known_noise/undiff/exp_...
# 21  /data/ephraim/datasets/known_noise/undiff/exp_...
# 22  /data/ephraim/datasets/known_noise/undiff/exp_...
# 23  /data/ephraim/datasets/known_noise/undiff/exp_...
# 24  /data/ephraim/datasets/known_noise/undiff/exp_...
# 25  /data/ephraim/datasets/known_noise/undiff/exp_...

# %%
mine["filename"][2]
# Out:
# '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_real/a/enhanced_60/snr5/s0.12/noiseRoom_digits_snr5_power0.0030414224602282047_var4.565821647644043.wav'

# %%
import shutil
for i in range(len(mine["dir"])):
    wavpath = mine["filename"][i]
    dir_ = mine["dir"][i]
    noisetype = mine["noise_type"][i]
    # print(wavpath)
    name = f"{dir_}_{noisetype}_snr5_ours.wav"
    # print(name)
    dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/wavs/{name}"
    shutil.copyfile(wavpath, dst)
    # print(dst)

# %%
for i in df_sg_5.index.values:
    wavpath = df_sg_5["filename"][i]
    dir_ = df_sg_5["dir"][i]
    noisetype = df_sg_5["noise_type"][i]
    # print(wavpath)
    name = f"{dir_}_{noisetype}_snr5_sgmse.wav"
    # print(name)
    dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/wavs/{name}"
    shutil.copyfile(wavpath, dst)
    # print(dst)

# %%
for i in df_storm_5.index.values:
    wavpath = df_storm_5["filename"][i]
    dir_ = df_storm_5["dir"][i]
    noisetype = df_storm_5["noise_type"][i]
    # print(wavpath)
    name = f"{dir_}_{noisetype}_snr5_storm.wav"
    # print(name)
    dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/wavs/{name}"
    shutil.copyfile(wavpath, dst)
    # print(dst)

# %%
df_noisy= df_noisy.reset_index(drop=True)

# %%
df_noisy5 = df_noisy[df_noisy["snr"]=="5"]
for i in df_noisy5.index.values:
    # print(i)
    wavpath = df_noisy5["filename"][i]
    dir_ = df_noisy5["dir"][i]
    noisetype = df_noisy5["noise_type"][i]
    # print(wavpath)
    name = f"{dir_}_{noisetype}_snr5_noisy.wav"
    # print("name:", name)
    dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/wavs/{name}"
    shutil.copyfile(wavpath, dst)
    # print(dst)

# %%
from glob import glob
wavs = glob("/data/ephraim/datasets/known_noise/sgmse/exp_i/clean_i_real/*.wav")
for wavpath in wavs:
    c = Path(wavpath).name.split("_")[0]
    if "snr5" in wavpath:
        noisetype = Path(wavpath).name.split("noise")[1].split("_")[0]
        name = f"{c}_{noisetype}_snr5_clean.wav"
        dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_i/analysis/i_real/wavs/{name}"
        shutil.copyfile(wavpath, dst)
        # print(name)

# %%
import torchaudio

from audio_tools2  import *

def calc_vad(f, verbose=False):
    test_file=f
    fs,s = read_wav(test_file)
    win_len = int(fs*0.025)
    hop_len = int(fs*0.010)
    sframes = enframe(s,win_len,hop_len) # rows: frame index, cols: each frame
    if verbose:
        plot_this(compute_log_nrg(sframes))

    # percent_high_nrg is the VAD context ratio. It helps smooth the
    # output VAD decisions. Higher values are more strict.
    percent_high_nrg = 0.5

    vad = nrg_vad(sframes,percent_high_nrg)

    if verbose:
        plot_these(deframe(vad,win_len,hop_len),s)
    return deframe(vad,win_len,hop_len) 

wavs = glob("/data/ephraim/datasets/known_noise/sgmse/exp_i/clean_synth_i95/*.wav")
for wavpath in wavs:
    c = Path(wavpath).name.split("_")[0]
    if "snr5" in wavpath:
        speech, sr = torchaudio.load(wavpath)
        
        vaded_signal = calc_vad(wavpath)[0:speech.shape[1],:]
        vaded_signal_torch = (speech[0][vaded_signal.T[0]>0])
        vaded_signal_torch = torch.unsqueeze(vaded_signal_torch, dim=0)
        # raise Exception
        simple_power =  1 / speech.shape[1] * torch.sum(speech**2)
        clean_power = float( 1 / vaded_signal_torch.shape[1] * torch.sum(vaded_signal_torch**2))
        print(c, simple_power,clean_power)
# Out:
# h tensor(0.0013) 0.0020746218506246805
# a tensor(0.0069) 0.009617823176085949
# f tensor(0.0005) 0.0007283489685505629
# i tensor(0.0027) 0.004131182562559843
# g tensor(0.0003) 0.00040919758612290025
# j tensor(0.0003) 0.0004039954219479114
# c tensor(0.0040) 0.006217417772859335
# e tensor(0.0003) 0.0003898124268744141
# b tensor(0.0071) 0.010278504341840744
# d tensor(0.0026) 0.004266192205250263

# %%
group = ["d","e","f","h","j"]
group = ["b"]

minestats = mine[mine["dir"].isin(group)].describe()[1:2]
minestats = minestats.assign(alg="ours")
df_storm_5stats = df_storm_5[df_storm_5["dir"].isin(group)][cols].describe()[1:2]
df_storm_5stats = df_storm_5stats.assign(alg="storm")
df_sg_5stats = df_sg_5[df_sg_5["dir"].isin(group)][cols].describe()[1:2]
df_sg_5stats = df_sg_5stats.assign(alg="sgmse")
statsdf = pd.concat([minestats,df_sg_5stats,df_storm_5stats])
statsdf
# Out:
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#           stoi  input_stoi      pesq  input_pesq      OVRL       SIG  \
# mean  0.915586    0.852672  1.310969    1.081788  3.001991  3.420187
# mean  0.956077    0.852672  1.405901    1.081788  3.014956  3.582134
# mean  0.953902    0.852672  1.545146    1.081788  3.269887  3.533363
#
#            BAK     si_sdr        sdr        sar  sir    alg
# mean  3.770491   7.701058   8.916986   8.916986  inf   ours
# mean  3.592267   9.047626   9.381276   9.381276  inf  sgmse
# mean  4.084091  11.197200  12.140747  12.140747  inf  storm

# %%
df_storm_5[df_storm_5["dir"].isin(["a","b","c","i"])][cols]
# Out:
#   dir                                               name      stoi  \
# 0   a  digits_snr5_power0.0030414227369186283_var0.00...  0.884283
# 1   b  digits_snr5_power0.0032503484660146675_var0.00...  0.953902
# 2   c  digits_snr5_power0.001966120132704691_var0.000...  0.904474
# 8   i  digits_snr5_power0.001306394632766015_var0.000...  0.856860
#
#    input_stoi      pesq  input_pesq      OVRL       SIG       BAK     si_sdr  \
# 0    0.771595  1.397562    1.044373  3.208131  3.465962  4.085089  10.673426
# 1    0.852672  1.545146    1.081788  3.269887  3.533363  4.084091  11.197200
# 2    0.794392  1.388913    1.065842  3.038718  3.343249  3.911286  11.112709
# 8    0.767430  1.375588    1.119411  3.308637  3.578728  4.094880   9.612803
#
#          sdr        sar  sir  \
# 0  11.061013  11.061013  inf
# 1  12.140747  12.140747  inf
# 2  11.491630  11.491630  inf
# 8  10.185336  10.185336  inf
#
#                                             filename
# 0  /data/ephraim/datasets/known_noise/sgmse/exp_i...
# 1  /data/ephraim/datasets/known_noise/sgmse/exp_i...
# 2  /data/ephraim/datasets/known_noise/sgmse/exp_i...
# 8  /data/ephraim/datasets/known_noise/sgmse/exp_i...
