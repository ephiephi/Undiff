# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os
from pathlib import Path

# %%
def get_df(dir):
    exp_dir = Path("/data/ephraim/datasets/known_noise/undiff_exps/exp_l_long_ar/")/dir
    pkl_results_file = os.path.join(exp_dir, "measures.pickle")
    # print(pkl_results_file)

    with open(pkl_results_file, "rb") as handle:
        dfme = pd.read_pickle(handle)
    return dfme

# %%
pkl_results_file = "/data/ephraim/datasets/known_noise/sgmse/exp_l/enhanced/storm_vbd/measures_storm.pickle"
# pkl_results_file = "/data/ephraim/datasets/known_noise/sgmse/exp_k/enhanced/storm_TIMITChime3/measures_storm.pickle"

with open(pkl_results_file, "rb") as handle:
    df2 = pd.read_pickle(handle)
for i in range(len(df2["snr"])):
    df2.at[i, "snr"] = df2["snr"][i].split("_")[0]

# %%
df_storm_5 = df2[df2["snr"]=="5"].reset_index(drop=True).sort_values(by=['dir'])

# %%
df_storm_5["noise_type"][2]
# Out:
# '3'

# %%
pkl_results_file = "/data/ephraim/datasets/known_noise/sgmse/exp_l/enhanced/sgmse_WSJ0Chime3/measures_storm.pickle"
# pkl_results_file = "/data/ephraim/datasets/known_noise/sgmse/exp_k/enhanced/sgmse_TIMITChime3/measures_storm.pickle"

with open(pkl_results_file, "rb") as handle:
    df1 = pd.read_pickle(handle)
for i in range(len(df1["snr"])):
    df1.at[i, "snr"] = df1["snr"][i].split("_")[0]

# %%
df_sg_5 = df1[df1["snr"]=="5"].reset_index(drop=True).sort_values(by=['dir'])

# %%
df_storm_5[df_storm_5["noise_type"]=="3"][["stoi","input_stoi","pesq","input_pesq","name","sdr","noise_type","dir","snr"]].head()
# Out:
#        stoi  input_stoi      pesq  input_pesq  \
# 2  0.979987    0.963899  1.449015    1.040019
# 5  0.941920    0.893841  1.501676    1.037671
# 8  0.949389    0.891594  2.153804    1.171176
#
#                                                 name        sdr noise_type  \
# 2  noise3_digits_snr5_power0.0032503483816981316_...  15.068098          3
# 5  noise3_digits_snr5_power0.0019661204423755407_...  15.345971          3
# 8  noise3_digits_snr5_power0.0002030737086897716_...  17.823176          3
#
#   dir snr
# 2   b   5
# 5   c   5
# 8   j   5

# %%
mine[mine["dir"]=="j"]["filename"][0]
# Out:
# '/data/ephraim/datasets/known_noise/undiff_exps/exp_l_long_ar/j/enhanced_60/snr5/s0.3/noise1_digits_snr5_power0.0002030737668974325_var0.0002621779276523739.wav'

# %%
mine[mine["dir"]=="j"][["stoi","input_stoi","pesq","input_pesq","name","sdr","noise_type","dir"]]
# Out:
#        stoi  input_stoi      pesq  input_pesq   name       sdr noise_type dir
# 0  0.794395    0.670502  1.661129    1.083557   s0.3  1.973739          1   j
# 1  0.861412    0.731191  1.656674    1.065131  s0.45 -0.607560          2   j
# 2  0.815379    0.891594  1.226034    1.171176  s0.35  1.376276          3   j

# %%
mine[mine["dir"]=="j"][["stoi","input_stoi","pesq","input_pesq","name","sdr","noise_type","dir"]]
# Out:
#        stoi  input_stoi      pesq  input_pesq   name       sdr noise_type dir
# 0  0.794395    0.670502  1.661129    1.083557   s0.3  1.973739          1   j
# 1  0.861412    0.731191  1.656674    1.065131  s0.45 -0.607560          2   j
# 2  0.815379    0.891594  1.226034    1.171176  s0.35  1.376276          3   j

# %%
df_sg_5[df_sg_5["noise_type"]=="3"][["stoi","input_stoi","pesq","input_pesq","name","sdr","noise_type","dir"]].head()
# Out:
#        stoi  input_stoi      pesq  input_pesq  \
# 2  0.967374    0.963899  1.042597    1.040019
# 5  0.925866    0.893841  1.069093    1.037671
# 8  0.937568    0.891594  1.306486    1.171176
#
#                                                 name       sdr noise_type dir
# 2  noise3_digits_snr5_power0.0032503483816981316_...  3.656602          3   b
# 5  noise3_digits_snr5_power0.0019661204423755407_...  4.073775          3   c
# 8  noise3_digits_snr5_power0.0002030737086897716_...  4.632478          3   j

# %%
dfme = get_df("b")
dfme[dfme["noise_type"]=="1"][["stoi","input_stoi","pesq","input_pesq","name","sdr","noise_type"]]
# Out:
#         stoi  input_stoi      pesq  input_pesq     name        sdr noise_type
# 0   0.855172    0.802904  1.207744    1.054966    s0.08   8.246324          1
# 3   0.206643    0.802904  1.030967    1.054966  s0.0001 -20.880276          1
# 6   0.851079    0.802904  1.290376    1.054966    s0.09   9.011438          1
# 9   0.490596    0.802904  1.069052    1.054966     s0.8  -9.963103          1
# 12  0.858870    0.802904  1.267711    1.054966     s0.1   9.175990          1
# 15  0.218432    0.802904  1.028194    1.054966    s0.01 -14.185749          1
# 18  0.868638    0.802904  1.226307    1.054966    s0.11   9.717323          1
# 21  0.058132    0.802904  1.055122    1.054966   s0.005 -16.316630          1
# 24  0.896317    0.802904  1.338662    1.054966    s0.12  10.124797          1
# 27  0.889052    0.802904  1.358274    1.054966    s0.15  10.302684          1
# 30  0.787791    0.802904  1.132048    1.054966    s0.06   7.011083          1
# 33  0.123269    0.802904  1.026285    1.054966   s0.001 -21.453926          1
# 36  0.763714    0.802904  1.099330    1.054966    s0.05   6.064163          1
# 39  0.490596    0.802904  1.069052    1.054966     s0.7  -9.963103          1
# 42  0.894711    0.802904  1.422375    1.054966     s0.2  10.293576          1
# 45  0.855156    0.802904  1.236321    1.054966    s0.07   7.778129          1
# 48  0.895712    0.802904  1.320872    1.054966    s0.13  10.464715          1
# 51  0.890649    0.802904  1.328165    1.054966    s0.14  10.227880          1
# 54  0.897980    0.802904  1.356005    1.054966    s0.17  10.405402          1
# 57  0.891172    0.802904  1.300674    1.054966    s0.18  10.529310          1
# 60  0.901225    0.802904  1.404474    1.054966    s0.19  10.180870          1
# 63  0.911117    0.802904  1.407528    1.054966    s0.21  10.595116          1
# 66  0.893043    0.802904  1.322660    1.054966    s0.22  10.139561          1
# 69  0.888961    0.802904  1.327269    1.054966    s0.23   9.806997          1
# 72  0.890371    0.802904  1.287602    1.054966    s0.25   9.841496          1
# 75  0.909535    0.802904  1.299290    1.054966    s0.27   9.325897          1
# 78  0.881177    0.802904  1.322142    1.054966     s0.3   9.041054          1
# 81  0.878321    0.802904  1.249449    1.054966    s0.35   8.111065          1
# 84  0.880264    0.802904  1.246479    1.054966     s0.4   6.956889          1
# 87  0.864630    0.802904  1.226764    1.054966    s0.45   5.871939          1
# 90  0.864421    0.802904  1.217104    1.054966     s0.5   5.419704          1
# 0   0.802904    0.802904  1.054966    1.054966    noisy   3.499703          1

# %%
set(dfme["snr"])
# Out:
# {'5'}

# %%
mine = None
df_noisy = None
for d in "jbc": 
    if get_df(d) is None:
        continue
    dfme = get_df(d)
    dfme = dfme.assign(dir=d)
    cur_df_noisy = dfme[dfme["name"]=="noisy"].reset_index(drop=True)
    cur_df_noisy.loc[0,"dir"] = d
    if df_noisy is None:
        df_noisy = cur_df_noisy
    else:
        df_noisy = pd.concat([df_noisy, cur_df_noisy])
    dfme = dfme[dfme["name"] != "noisy"]
    dfme_5 = dfme[dfme["snr"]=="5"]
    dfme5 = dfme_5[dfme_5["stoi"]>0.5]
    cols =["dir","name","stoi","input_stoi","pesq","input_pesq","OVRL","SIG","BAK","si_sdr",'sdr', "sar",'sir',"noise_type", "filename"]
    NOISES = ["1","2","3"]
    for noisetype in NOISES :
        cur_mine = dfme5[dfme5["noise_type"]==noisetype]
        cur_mine = cur_mine[cur_mine["pesq"] ==cur_mine["pesq"].max()].reset_index(drop=True)[cols]
        # cur_mine.loc[0,"dir"] = d
        if mine is None:
            mine = cur_mine
        else:
            mine = pd.concat([mine, cur_mine])
mine=mine.reset_index(drop=True)
df_noisy
# dfme5[dfme5["pasq"]][["stoi","pesq","name","si_sdr","OVRL","SIG","BAK"]]
# Out:
#    input_si_sdr  input_sdr  input_sir  input_sar  input_stoi  input_pesq  \
# 0      3.240486   3.294205        inf   3.294205    0.670502    1.083557
# 1      3.265779   3.328275        inf   3.328275    0.731191    1.065131
# 2      3.258144   3.313546        inf   3.313546    0.891594    1.171176
# 0      3.408029   3.499703        inf   3.499703    0.802904    1.054966
# 1      3.430070   3.524749        inf   3.524749    0.838566    1.042880
# 2      3.407025   3.519725        inf   3.519725    0.963899    1.040019
# 0      3.150472   3.234696        inf   3.234696    0.731569    1.041438
# 1      3.165382   3.238084        inf   3.238084    0.772852    1.031474
# 2      3.135046   3.201687        inf   3.201687    0.893841    1.037671
#
#      si_sdr       sdr  sir       sar  ...     sr  num_hops  OVRL_raw  \
# 0  3.240486  3.294205  inf  3.294205  ...  16000         4  1.239743
# 1  3.265779  3.328275  inf  3.328275  ...  16000         4  1.798491
# 2  3.258144  3.313546  inf  3.313546  ...  16000         4  2.075232
# 0  3.408029  3.499703  inf  3.499703  ...  16000         7  1.683406
# 1  3.430070  3.524749  inf  3.524749  ...  16000         7  1.655487
# 2  3.407025  3.519725  inf  3.519725  ...  16000         7  2.434174
# 0  3.150472  3.234696  inf  3.234696  ...  16000         3  1.261843
# 1  3.165382  3.238084  inf  3.238084  ...  16000         3  1.464818
# 2  3.135046  3.201687  inf  3.201687  ...  16000         3  2.013015
#
#     SIG_raw   BAK_raw      OVRL       SIG       BAK  P808_MOS  dir
# 0  1.704045  1.180062  1.324035  1.833232  1.318720  2.241863    j
# 1  3.048667  1.618965  1.833232  2.945908  1.863625  2.441113    j
# 2  3.602969  1.910809  2.069428  3.313731  2.197949  2.698113    j
# 0  3.234419  1.447491  1.731892  3.074921  1.657150  2.109720    b
# 1  3.273182  1.371532  1.707175  3.101060  1.563210  2.293707    b
# 2  3.802935  2.108491  2.360256  3.433527  2.410889  2.794576    b
# 0  2.109540  1.151574  1.345598  2.205380  1.282086  2.168514    c
# 1  2.942668  1.228653  1.534404  2.864238  1.382066  2.437646    c
# 2  3.812690  1.520400  2.017209  3.439102  1.745745  2.664283    c
#
# [9 rows x 27 columns]

# %%
for noisetype in NOISES:
    noise_mine  = mine[mine["noise_type"]==noisetype]
    # noise_mine.to_excel(f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/ours_{noisetype}.xlsx")

# %%
for noisetype in NOISES:
    noise_df_sg_5 = df_sg_5[df_sg_5["noise_type"]==noisetype]
    # noise_df_sg_5[cols].to_excel(f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/sgmse_{noisetype}.xlsx")

# %%
for noisetype in NOISES:
    noise_df_storm_5 = df_storm_5[df_storm_5["noise_type"]==noisetype]
    # noise_df_storm_5[cols].to_excel(f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/storm_{noisetype}.xlsx")

# %%
for i in range(len(df_storm_5["dir"])):
    dir_ = df_storm_5["dir"][i]
    noisetype = df_storm_5["noise_type"][i]
    mine_parallel = mine[(mine["dir"]==dir_) & (mine["noise_type"]==noisetype)]
    if len(mine_parallel)==0:
        idx = df_storm_5[(df_storm_5.dir==dir_)&(df_storm_5.noise_type==noisetype)].index
        df_storm_5 = df_storm_5.drop(idx)

# %%
for i in range(len(df_sg_5["dir"])):
    dir_ = df_sg_5["dir"][i]
    noisetype = df_sg_5["noise_type"][i]
    mine_parallel = mine[(mine["dir"]==dir_) & (mine["noise_type"]==noisetype)]
    if len(mine_parallel)==0:
        idx = df_sg_5[(df_sg_5.dir==dir_)&(df_sg_5.noise_type==noisetype)].index
        df_sg_5 = df_sg_5.drop(idx)

# %%
minestats = mine.describe()[1:3]
minestats = minestats.assign(alg="ours")
df_storm_5stats = df_storm_5[cols].describe()[1:3]
df_storm_5stats = df_storm_5stats.assign(alg="storm")
df_sg_5stats = df_sg_5[cols].describe()[1:3]
df_sg_5stats = df_sg_5stats.assign(alg="sgmse")
statsdf = pd.concat([minestats,df_sg_5stats,df_storm_5stats])
statsdf.to_excel("/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/all_stats.xlsx")
#
# Out:
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
for dir__ in "bcj":
    dirminestats = mine[mine["dir"]==dir__].describe()[1:3]
    dirminestats = dirminestats.assign(alg="ours")
    dir_storm_5stats = df_storm_5[df_storm_5["dir"]==dir__]
    dir_storm_5stats = dir_storm_5stats[cols].describe()[1:3]
    dir_storm_5stats = dir_storm_5stats.assign(alg="storm")
    dir_sg_5stats = df_sg_5[df_sg_5["dir"]==dir__]
    dir_sg_5stats=dir_sg_5stats[cols].describe()[1:3]
    dir_sg_5stats = dir_sg_5stats.assign(alg="sgmse")
    dirstatsdf = pd.concat([dirminestats,dir_storm_5stats,dir_sg_5stats])
    dirstatsdf.to_excel(f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/{dir__}_stats.xlsx")
# Out:
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
dir_storm_5stats = df_storm_5[df_storm_5["dir"]=="b"]
dir_storm_5stats = dir_storm_5stats[cols].describe()[1:3]
# Out:
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
dir_storm_5stats
# Out:
#           stoi  input_stoi      pesq  input_pesq      OVRL       SIG  \
# mean  0.938733    0.868456  1.276812    1.045955  3.254223  3.504508
# std   0.037366    0.084557  0.150067    0.007934  0.020535  0.014454
#
#            BAK     si_sdr        sdr        sar  sir
# mean  4.102453  10.690414  11.764762  11.764762  inf
# std   0.028673   2.750361   3.019302   3.019302  NaN

# %%
for noisetype in NOISES:
    noise_mine = mine[mine["noise_type"]==noisetype]
    minestats = noise_mine.describe()[1:3]
    minestats = minestats.assign(alg="ours")
    
    noisedf_storm_5 =  df_storm_5[df_storm_5["noise_type"]==noisetype]
    df_storm_5stats = noisedf_storm_5[cols].describe()[1:3]
    df_storm_5stats = df_storm_5stats.assign(alg="storm")
    
    noise_df_sg_5 = df_sg_5[df_sg_5["noise_type"]==noisetype]
    df_sg_5stats = noise_df_sg_5[cols].describe()[1:3]
    df_sg_5stats = df_sg_5stats.assign(alg="sgmse")
    statsdf = pd.concat([minestats,df_sg_5stats,df_storm_5stats])
    statsdf.to_excel(f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/stats_{noisetype}.xlsx")
# Out:
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
mine[mine["dir"]=="b"]["filename"].values[0]
# Out:
# '/data/ephraim/datasets/known_noise/undiff_exps/exp_l_long_ar/b/enhanced_60/snr5/s0.2/noise1_digits_snr5_power0.0032503483816981316_var0.0041854712180793285.wav'

# %%
mine
# Out:
#   dir   name      stoi  input_stoi      pesq  input_pesq      OVRL       SIG  \
# 0   j   s0.3  0.794395    0.670502  1.661129    1.083557  2.731924  3.085501
# 1   j  s0.45  0.861412    0.731191  1.656674    1.065131  2.800846  3.316219
# 2   j  s0.35  0.815379    0.891594  1.226034    1.171176  2.713369  3.279170
# 3   b   s0.2  0.894711    0.802904  1.422375    1.054966  3.274658  3.602268
# 4   b  s0.22  0.913575    0.838566  1.434933    1.042880  3.070057  3.437725
# 5   b  s0.11  0.901071    0.963899  1.170602    1.040019  2.600292  3.198098
# 6   c  s0.19  0.845429    0.731569  1.365501    1.041438  2.756683  3.139253
# 7   c   s0.2  0.867177    0.772852  1.408349    1.031474  2.780182  3.339810
# 8   c  s0.13  0.823943    0.893841  1.129923    1.037671  2.502185  3.013084
#
#         BAK     si_sdr        sdr        sar  sir noise_type  \
# 0  3.822719   1.781237   1.973739   1.973739  inf          1
# 1  3.503590  -0.787547  -0.607560  -0.607560  inf          2
# 2  3.369210   1.250944   1.376276   1.376276  inf          3
# 3  3.995342   9.577139  10.293576  10.293576  inf          1
# 4  3.891191  10.143094  11.369005  11.369005  inf          2
# 5  3.329272   7.088957   8.746247   8.746247  inf          3
# 6  3.700506   9.392954  10.378152  10.378152  inf          1
# 7  3.450727   9.988214  10.001588  10.001588  inf          2
# 8  3.337510   7.553671   8.691373   8.691373  inf          3
#
#                                             filename
# 0  /data/ephraim/datasets/known_noise/undiff_exps...
# 1  /data/ephraim/datasets/known_noise/undiff_exps...
# 2  /data/ephraim/datasets/known_noise/undiff_exps...
# 3  /data/ephraim/datasets/known_noise/undiff_exps...
# 4  /data/ephraim/datasets/known_noise/undiff_exps...
# 5  /data/ephraim/datasets/known_noise/undiff_exps...
# 6  /data/ephraim/datasets/known_noise/undiff_exps...
# 7  /data/ephraim/datasets/known_noise/undiff_exps...
# 8  /data/ephraim/datasets/known_noise/undiff_exps...

# %%
mine["filename"][2]
# Out:
# '/data/ephraim/datasets/known_noise/undiff_exps/exp_l_long_ar/j/enhanced_60/snr5/s0.35/noise3_digits_snr5_power0.0002030737086897716_var0.00026405308744870126.wav'

# %%
import shutil
for i in range(len(mine["dir"])):
    wavpath = mine["filename"][i]
    dir_ = mine["dir"][i]
    noisetype = mine["noise_type"][i]
    # print(wavpath)
    name = f"{dir_}_{noisetype}_snr5_ours.wav"
    # print(name)
    dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/wavs/{name}"
    shutil.copyfile(wavpath, dst)
    # print(dst)

# %%
for i in df_sg_5.index.values:
    wavpath = df_sg_5["filename"][i]
    dir_ = df_sg_5["dir"][i]
    noisetype = df_sg_5["noise_type"][i]
    # print(wavpath)
    name = f"{dir_}_{noisetype}_snr5_sgmse.wav"
    # print(name)
    dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/wavs/{name}"
    shutil.copyfile(wavpath, dst)
    # print(dst)

# %%
for i in df_storm_5.index.values:
    wavpath = df_storm_5["filename"][i]
    dir_ = df_storm_5["dir"][i]
    noisetype = df_storm_5["noise_type"][i]
    # print(wavpath)
    name = f"{dir_}_{noisetype}_snr5_storm.wav"
    # print(name)
    dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/wavs/{name}"
    shutil.copyfile(wavpath, dst)
    # print(dst)

# %%
df_noisy= df_noisy.reset_index(drop=True)

# %%
df_noisy5 = df_noisy[df_noisy["snr"]=="5"]
for i in df_noisy5.index.values:
    # print(i)
    wavpath = df_noisy5["filename"][i]
    dir_ = df_noisy5["dir"][i]
    noisetype = df_noisy5["noise_type"][i]
    # print(wavpath)
    name = f"{dir_}_{noisetype}_snr5_noisy.wav"
    # print("name:", name)
    dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/wavs/{name}"
    shutil.copyfile(wavpath, dst)
    # print(dst)

# %%
from glob import glob
wavs = glob("/data/ephraim/datasets/known_noise/sgmse/exp_l/clean_wav/*.wav")
for wavpath in wavs:
    c = Path(wavpath).name.split("_")[0]
    if "snr5" in wavpath:
        noisetype = Path(wavpath).name.split("noise")[1].split("_")[0]
        name = f"{c}_{noisetype}_snr5_clean.wav"
        dst = f"/data/ephraim/datasets/known_noise/sgmse/exp_l/analysis/wavs/{name}"
        shutil.copyfile(wavpath, dst)
        # print(name)
