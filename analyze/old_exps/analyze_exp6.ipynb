# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os

# %%
def df_for_snr(snr_path):
    stats_path = os.path.join(snr_path, "stats_dns.json")
    with open(stats_path) as f:
        data = json.load(f)
    df = pd.DataFrame.from_dict(data).T.reset_index()
    for i in range(len(df)):
        df.at[i, "index"] = df["index"][i].split("s")[1]
    df["index"] = df["index"].astype(float)
    df = df.sort_values(by=['index']).reset_index(drop=True)
    df= df.rename(columns={"index": "s"})
    df.to_excel(os.path.join(snr_path,"measurements.xlsx"))

    return df

# %%
root = "/data/ephraim/datasets/known_noise/undiff/exp6b/a/enhanced/"
root2 = "/data/ephraim/datasets/known_noise/undiff/exp6b/b/enhanced/"

# %%
df_for_snr(os.path.join(root,"snr5"))
# Out:
#       s                pesq                 stoi              pesq_diff  \
# 0  0.01  1.0735305547714233  0.29064371957395946  0.0034710168838500977
# 1  0.05  1.2926185131072998   0.8445530195566605    0.22255897521972656
# 2  0.07   1.458237886428833   0.8803627274291131    0.38817834854125977
# 3  0.09  1.5486962795257568   0.9025796759936476     0.4786367416381836
# 4  0.10  1.5220502614974976   0.9060827870904661     0.4519907236099243
# 5  0.20  1.3442829847335815   0.9099008001749888     0.2742234468460083
# 6  0.30  1.1852515935897827   0.8910484804982438    0.11519205570220947
# 7  0.50   1.087753176689148   0.8679364414804485   0.017693638801574707
# 8  0.80  1.0382810831069946    0.806458941276043   -0.03177845478057861
#
#                stoi_diff                OVRL                 SIG  \
# 0    -0.5982773058323402   2.662569369357595   2.976332702595777
# 1   -0.04436800584963907   2.892256197798856  3.2003889991148484
# 2  -0.008558297977186435   2.973069094601942   3.232446458113185
# 3   0.013658650587348165  2.9970053493525275  3.2187413733017385
# 4     0.0171617616841665   3.001793800141676   3.264141672431686
# 5   0.020979774768689174  2.6191541492923416   3.493998301462592
# 6  0.0021274550919442303  2.2682406047116364  3.4943808628909037
# 7   -0.02098458392585112  2.0206562749527626  3.4428053202694517
# 8   -0.08246208413025657  1.8546358348110157  3.1789056883622853
#
#                   BAK                                        enhance_dir  \
# 0   3.908717909330246  /data/ephraim/datasets/known_noise/undiff/exp6...
# 1  3.8997978352411584  /data/ephraim/datasets/known_noise/undiff/exp6...
# 2   4.025356399648238  /data/ephraim/datasets/known_noise/undiff/exp6...
# 3   4.087765921665268  /data/ephraim/datasets/known_noise/undiff/exp6...
# 4  4.0299999027921825  /data/ephraim/datasets/known_noise/undiff/exp6...
# 5  2.8373951812934566  /data/ephraim/datasets/known_noise/undiff/exp6...
# 6   2.280036829820647  /data/ephraim/datasets/known_noise/undiff/exp6...
# 7  1.8686417822507868  /data/ephraim/datasets/known_noise/undiff/exp6...
# 8   1.714284758644306  /data/ephraim/datasets/known_noise/undiff/exp6...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr15"))
# Out:
#           s                pesq                 stoi              pesq_diff  \
# 0  0.000005  1.0912002325057983   0.8799262215703451   0.021140694618225098
# 1  0.000010  1.0807597637176514   0.8827027225479052   0.010700225830078125
# 2  0.000050  1.0251131057739258   0.5069594398298775   -0.04494643211364746
# 3  0.000080   1.211658000946045  0.34041490891528453    0.14159846305847168
# 4  0.000100  1.7422595024108887  0.31278786730328945     0.6721999645233154
# 5  0.000300  1.9026323556900024   0.3486145014201561     0.8325728178024292
# 6  0.000500  1.5146360397338867  0.35301214547241716     0.4445765018463135
# 7  0.000800  1.0467581748962402  0.35733025065599877  -0.023301362991333008
# 8  0.001000  1.0466485023498535   0.3269079502120521  -0.023411035537719727
#
#                stoi_diff                OVRL                 SIG  \
# 0  -0.008994803835954412  2.1855286491584445   3.410303947712929
# 1   -0.00621830285839442   2.069763991509663  3.3960318437764605
# 2    -0.3819615855764222  1.0745584645071848  1.2097474700907789
# 3    -0.5485061164910151  1.0645968084410613   1.213456046795804
# 4    -0.5761331581030101  1.2114759286135492  1.5897139218168803
# 5    -0.5403065239861434  1.2059919266115917  1.6138309222547969
# 6    -0.5359088799338824  1.3018072691863025   1.827551980918706
# 7    -0.5315907747503008  1.5711197191362654   2.586411562956036
# 8    -0.5620130751942475  2.0510885155816414  2.2953901685829634
#
#                   BAK                                        enhance_dir  \
# 0  2.2553128342513147  /data/ephraim/datasets/known_noise/undiff/exp6...
# 1   2.025595443526531  /data/ephraim/datasets/known_noise/undiff/exp6...
# 2  1.1389398820490793  /data/ephraim/datasets/known_noise/undiff/exp6...
# 3  1.1457938534127172  /data/ephraim/datasets/known_noise/undiff/exp6...
# 4  1.2995501434693528  /data/ephraim/datasets/known_noise/undiff/exp6...
# 5   1.273873009536442  /data/ephraim/datasets/known_noise/undiff/exp6...
# 6  1.3441080735778372  /data/ephraim/datasets/known_noise/undiff/exp6...
# 7  2.0048607063784347  /data/ephraim/datasets/known_noise/undiff/exp6...
# 8  3.8170085393008355  /data/ephraim/datasets/known_noise/undiff/exp6...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr10"))
# Out:
#           s                pesq                 stoi              pesq_diff  \
# 0  0.000005  1.0634629726409912  0.40907852573414333  -0.006596565246582031
# 1  0.000010   1.052171230316162   0.5696303782143907  -0.017888307571411133
# 2  0.000050  1.0516284704208374    0.892091248914281   -0.01843106746673584
# 3  0.000080  1.0317203998565674   0.8276748731804918   -0.03833913803100586
# 4  0.000100  1.0265551805496216   0.7663371928527223   -0.04350435733795166
# 5  0.000300   1.276224970817566  0.31550655428977614    0.20616543292999268
# 6  0.000500  1.1192964315414429   0.3437222633358998    0.04923689365386963
# 7  0.000800  1.0741058588027954  0.35127196995436877   0.004046320915222168
# 8  0.001000  1.3146498203277588   0.3516665814193824    0.24459028244018555
#
#                stoi_diff                OVRL                 SIG  \
# 0   -0.47984249967215625  2.5796722301256376  3.4514889404740754
# 1    -0.3192906471919089  2.3453858730814416   3.426878026695677
# 2  0.0031702235079814622   2.128170520269978   3.487274982273232
# 3   -0.06124615222580776  1.8694647395994748   3.275673825467421
# 4    -0.1225838325535773   1.727932058211172   3.069181028451296
# 5    -0.5734144711165235  1.3463412153419616  1.9376691424288834
# 6    -0.5451987620703999  1.2654105497095158  1.7264053602733618
# 7    -0.5376490554519308   1.088451734491884   1.260590156685149
# 8    -0.5372544439869172  1.2198081286945193  1.6074113372441283
#
#                   BAK                                        enhance_dir  \
# 0  2.9121962944715403  /data/ephraim/datasets/known_noise/undiff/exp6...
# 1   2.600726567500335  /data/ephraim/datasets/known_noise/undiff/exp6...
# 2  2.0127702219672696  /data/ephraim/datasets/known_noise/undiff/exp6...
# 3  1.7549979077012707  /data/ephraim/datasets/known_noise/undiff/exp6...
# 4  1.6791049624272298  /data/ephraim/datasets/known_noise/undiff/exp6...
# 5   1.385455879309977  /data/ephraim/datasets/known_noise/undiff/exp6...
# 6  1.2802891586265566  /data/ephraim/datasets/known_noise/undiff/exp6...
# 7  1.1560989843369258  /data/ephraim/datasets/known_noise/undiff/exp6...
# 8   1.260550120828296  /data/ephraim/datasets/known_noise/undiff/exp6...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2, "snr10"))
# Out:
#           s                pesq                 stoi              pesq_diff  \
# 0  0.000005  1.0299761295318604   0.5475060484732548   -0.02860871950785319
# 1  0.000010  1.1722700595855713   0.5307906271589867    0.11368521054585774
# 2  0.000050   1.029080867767334  0.36179821100440196   -0.02950398127237956
# 3  0.000080  1.3144428730010986    0.352730115125994     0.2558580239613851
# 4  0.000100  1.0449062585830688  0.34238207371306256  -0.013678590456644693
# 5  0.000300  1.0261871814727783   0.3436408154007878   -0.03239766756693522
# 6  0.000500  1.0803351402282715   0.3497145080310567    0.02175029118855794
# 7  0.000800  1.0948007106781006  0.29370393090180574    0.03621586163838705
# 8  0.001000  1.0259038209915161  0.15363892770334397  -0.032681028048197426
#
#               stoi_diff                OVRL                 SIG  \
# 0   -0.2883081957153683  1.7803223955658176  3.1525108785188416
# 1   -0.3050236170296364   1.131326697104564   1.282350510508256
# 2  -0.47401603318422114  1.2436814067437014  1.6946107028698068
# 3  -0.48308412906262915  1.1560063402798484  1.4405851486763248
# 4   -0.4934321704755606  1.2946798385369676  1.7773981927388953
# 5   -0.4921734287878354  1.3123655015338571  1.8402757341802503
# 6  -0.48609973615756635  1.3006457246819312  1.9519481082873313
# 7   -0.5421103132868174   2.092621475062124   2.333887699103106
# 8   -0.6821753164852792   2.006552741075876  2.2302270386596197
#
#                   BAK                                        enhance_dir  \
# 0  1.7864185404255875  /data/ephraim/datasets/known_noise/undiff/exp6...
# 1  1.1317859340756165  /data/ephraim/datasets/known_noise/undiff/exp6...
# 2   1.358509734881365  /data/ephraim/datasets/known_noise/undiff/exp6...
# 3  1.1991087442753745  /data/ephraim/datasets/known_noise/undiff/exp6...
# 4  1.3585646538711553  /data/ephraim/datasets/known_noise/undiff/exp6...
# 5  1.3486379637658241  /data/ephraim/datasets/known_noise/undiff/exp6...
# 6  1.2986840281198972  /data/ephraim/datasets/known_noise/undiff/exp6...
# 7  3.8211120775907306  /data/ephraim/datasets/known_noise/undiff/exp6...
# 8  3.6259532018032834  /data/ephraim/datasets/known_noise/undiff/exp6...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr5"))
# Out:
#           s                pesq                 stoi              pesq_diff  \
# 0  0.000005    1.43832266330719  0.21015733743906395     0.3682631254196167
# 1  0.000010  1.0847877264022827  0.24213288395457158   0.014728188514709473
# 2  0.000050  1.0568357706069946   0.6736488147050862  -0.013223767280578613
# 3  0.000080  1.0755043029785156   0.8319879035248818   0.005444765090942383
# 4  0.000100  1.0654627084732056   0.8707784651149885  -0.004596829414367676
# 5  0.000300  1.0354137420654297    0.833892111368329  -0.034645795822143555
# 6  0.000500    1.02838933467865   0.7983991424149196   -0.04167020320892334
# 7  0.000800  1.0534095764160156    0.449399730200513  -0.016649961471557617
# 8  0.001000  1.6576318740844727    0.345703608391249     0.5875723361968994
#
#                stoi_diff                OVRL                 SIG  \
# 0    -0.6787636879672356  3.2087987255516337  3.4935488984632523
# 1     -0.646788141451728   2.761269442969042   3.303819335950927
# 2   -0.21527221070121327   2.440456440133928   3.552126416901923
# 3   -0.05693312188141775  2.0419387204785724  3.2961814253482733
# 4  -0.018142560291311116  1.9623876041279673  3.2683223058444657
# 5    -0.0550289140379705  1.8934916522260758  3.2478523674719124
# 6   -0.09052188299137998   1.723604028284813  3.0441594345898215
# 7    -0.4395212952057866  1.0631624058318174  1.1876404039353903
# 8    -0.5432174170150507  1.2800877281770637    1.72906354027755
#
#                   BAK                                        enhance_dir  \
# 0   4.047615626391267  /data/ephraim/datasets/known_noise/undiff/exp6...
# 1  3.4692623798056283  /data/ephraim/datasets/known_noise/undiff/exp6...
# 2  2.5017663494817883  /data/ephraim/datasets/known_noise/undiff/exp6...
# 3  2.0596992475328393  /data/ephraim/datasets/known_noise/undiff/exp6...
# 4    1.95516543954584  /data/ephraim/datasets/known_noise/undiff/exp6...
# 5  1.7135428515192392  /data/ephraim/datasets/known_noise/undiff/exp6...
# 6  1.6611235642963444  /data/ephraim/datasets/known_noise/undiff/exp6...
# 7   1.141429613441741  /data/ephraim/datasets/known_noise/undiff/exp6...
# 8  1.3444347838592154  /data/ephraim/datasets/known_noise/undiff/exp6...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2, "snr5"))
# Out:
#           s                pesq                 stoi              pesq_diff  \
# 0  0.000005     1.0411297082901   0.6508887187063016  -0.017455140749613445
# 1  0.000010  1.0210727453231812   0.5933520040467436   -0.03751210371653239
# 2  0.000050  1.0265190601348877  0.37074942076524825  -0.032065788904825844
# 3  0.000080  1.5857053995132446   0.3465372878782447     0.5271205504735311
# 4  0.000100  1.0356720685958862  0.34657669487348036  -0.022912780443827312
# 5  0.000300   1.225403070449829  0.34431919351951085    0.16681822141011557
# 6  0.000500  1.1132358312606812  0.34646426030584015    0.05465098222096761
# 7  0.000800    1.04673171043396   0.3545365468002252   -0.01185313860575358
# 8  0.001000   1.051061987876892  0.29004019809202297  -0.007522861162821452
#
#               stoi_diff                OVRL                 SIG  \
# 0  -0.18492552548232152  1.7938704770988454   3.012761333925527
# 1  -0.24246224014187953  1.5287839687520692  2.3933920243194198
# 2   -0.4650648234233748  1.0638921390742007  1.1981387095958789
# 3   -0.4892769563103783  1.0637130861552409  1.2100782647540198
# 4   -0.4892375493151428  1.2372531211004436  1.6222378479088255
# 5  -0.49149505066911225   1.131326697104564  1.3262323195830914
# 6    -0.489349983882783  1.1584478457205956   1.454312967472803
# 7   -0.4812776973883979  1.5007093014152526  2.6086368867468748
# 8   -0.5457740460966002   2.159479380053968  2.3784598998364035
#
#                   BAK                                        enhance_dir  \
# 0  1.8811447799607104  /data/ephraim/datasets/known_noise/undiff/exp6...
# 1  1.4906191479058195  /data/ephraim/datasets/known_noise/undiff/exp6...
# 2   1.135674627571269  /data/ephraim/datasets/known_noise/undiff/exp6...
# 3  1.1445245529882266  /data/ephraim/datasets/known_noise/undiff/exp6...
# 4  1.3236572704032439  /data/ephraim/datasets/known_noise/undiff/exp6...
# 5    1.20974215734168  /data/ephraim/datasets/known_noise/undiff/exp6...
# 6   1.214127010815075  /data/ephraim/datasets/known_noise/undiff/exp6...
# 7   1.725659042579468  /data/ephraim/datasets/known_noise/undiff/exp6...
# 8   3.873330718102614  /data/ephraim/datasets/known_noise/undiff/exp6...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
enhance_dir = os.path.join(root, "snr15/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr15/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.140889       0.846489   0.067023
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.140889       0.846489  -0.008712
# 25%      1.035998    0.815752       1.140889       0.846489   0.041844
# 50%      1.048488    0.850554       1.140889       0.846489   0.092400
# 75%      1.099045    0.876377       1.140889       0.846489   0.104890
# max      1.149601    0.902200       1.140889       0.846489   0.117380
#
#        stoi_diff
# count   3.000000
# mean    0.001921
# std     0.060847
# min    -0.055711
# 25%    -0.029888
# 50%    -0.004066
# 75%     0.030737
# max     0.065539

# %%
enhance_dir = os.path.join(root, "snr5/s0.0003")
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr5/s0.0003/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.059176       0.815065  -0.014690
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.059176       0.815065  -0.090425
# 25%      1.035998    0.815752       1.059176       0.815065  -0.039869
# 50%      1.048488    0.850554       1.059176       0.815065   0.010688
# 75%      1.099045    0.876377       1.059176       0.815065   0.023177
# max      1.149601    0.902200       1.059176       0.815065   0.035667
#
#        stoi_diff
# count   3.000000
# mean   -0.029503
# std     0.060847
# min    -0.087135
# 25%    -0.061313
# 50%    -0.035490
# 75%    -0.000687
# max     0.034115
