# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os

# %%
def df_for_snr(snr_path):
    stats_path = os.path.join(snr_path, "stats_dns.json")
    with open(stats_path) as f:
        data = json.load(f)
    df = pd.DataFrame.from_dict(data).T.reset_index()
    for i in range(len(df)):
        df.at[i, "index"] = df["index"][i].split("s")[1]
    df["index"] = df["index"].astype(float)
    df = df.sort_values(by=['index']).reset_index(drop=True)
    df= df.rename(columns={"index": "s"})
    df.to_excel(os.path.join(snr_path,"measurements.xlsx"))

    return df

# %%
root = "/data/ephraim/datasets/known_noise/undiff/exp4/enhanced/"

# %%
df_for_snr(os.path.join(root, "snr15"))
# Out:
#          s                pesq                 stoi                OVRL  \
# 0  0.00005  1.1007155179977417    0.903366835979056  2.1198751890959042
# 1  0.00008  1.0325206518173218   0.8074054559524257  1.8837637469343704
# 2  0.00010  1.0237005949020386   0.7240584928638982  1.6717874305419707
# 3  0.00030  1.0321263074874878  0.25159184272033674  1.2287021321153797
# 4  0.00050  1.0210661888122559  0.27718753064472296   1.227371363994374
# 5  0.00080    1.02138090133667    0.278983698380515  1.1138901684555527
# 6  0.00100  1.1409237384796143  0.29714198697752436  1.1827477680606862
# 7  0.00500  1.0921878814697266  0.44647300680607654   2.012701891814784
# 8  0.00800  1.0918294191360474  0.44647300680607654  1.9931312363135334
#
#                   SIG                 BAK  \
# 0  3.5438900886440363  1.9393699957782016
# 1   3.365047814887016  1.7037028406532382
# 2  3.2573516581818054   1.408668640421579
# 3  1.5986645231297085  1.3053653760889943
# 4  1.6170626421813723  1.3156012330795401
# 5  1.3001617278196544    1.23156349824396
# 6  1.4980434599437256   1.263796368518305
# 7  2.3651396741157895  3.3599306313281874
# 8   2.362434551376153   3.334689777636311
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/undiff/exp4...
# 1  /data/ephraim/datasets/known_noise/undiff/exp4...
# 2  /data/ephraim/datasets/known_noise/undiff/exp4...
# 3  /data/ephraim/datasets/known_noise/undiff/exp4...
# 4  /data/ephraim/datasets/known_noise/undiff/exp4...
# 5  /data/ephraim/datasets/known_noise/undiff/exp4...
# 6  /data/ephraim/datasets/known_noise/undiff/exp4...
# 7  /data/ephraim/datasets/known_noise/undiff/exp4...
# 8  /data/ephraim/datasets/known_noise/undiff/exp4...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr10"))
# Out:
#          s                pesq                 stoi                OVRL  \
# 0  0.00005  1.1524865627288818   0.8040089110745317  2.0407586060859466
# 1  0.00008  1.2221301794052124   0.8879398302346765  2.1653753317478284
# 2  0.00010  1.2076640129089355   0.9004040712325773  2.1360571356894775
# 3  0.00030   1.059312105178833   0.8681306097924649   1.954501214467642
# 4  0.00050  1.0238544940948486   0.7353976704990053  1.7056570176505559
# 5  0.00080  1.0200554132461548  0.28754543486129774  1.0704959928473214
# 6  0.00100  1.0222744941711426  0.27241499512703365   1.139587693475621
# 7  0.00500  1.1208620071411133  0.34667179232060646  1.9928753286628722
# 8  0.00800  1.0376561880111694  0.44647300680607654  2.0209716096391803
#
#                   SIG                 BAK  \
# 0  3.3358868545733706   2.148995670637253
# 1   3.463713117403505  2.0971519072486724
# 2  3.4905681527909813  2.0328649248998696
# 3   3.412917772043353  1.7543986132443443
# 4   3.144956665244492  1.4964947086132154
# 5  1.2076955881472424  1.1725490494291808
# 6  1.3982093772835493  1.2305518985958972
# 7  2.3249710514069504  3.3951482417694208
# 8  2.3670921920389505   3.371120137621124
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/undiff/exp4...
# 1  /data/ephraim/datasets/known_noise/undiff/exp4...
# 2  /data/ephraim/datasets/known_noise/undiff/exp4...
# 3  /data/ephraim/datasets/known_noise/undiff/exp4...
# 4  /data/ephraim/datasets/known_noise/undiff/exp4...
# 5  /data/ephraim/datasets/known_noise/undiff/exp4...
# 6  /data/ephraim/datasets/known_noise/undiff/exp4...
# 7  /data/ephraim/datasets/known_noise/undiff/exp4...
# 8  /data/ephraim/datasets/known_noise/undiff/exp4...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr5"))
# Out:
#          s                pesq                 stoi                OVRL  \
# 0  0.00005  1.0333750247955322   0.3740815165004613  2.4158653939968695
# 1  0.00008  1.0520522594451904  0.41126143674215776  2.0687112286339238
# 2  0.00010  1.0606650114059448   0.5450035949042468  2.3088832368789483
# 3  0.00030  1.1541357040405273   0.8458285444178892  2.0139970132935234
# 4  0.00050  1.0711363554000854   0.8328833785949622   1.949082234881261
# 5  0.00080  1.0419130325317383   0.8132428854368032  1.8919395244112827
# 6  0.00100  1.0360803604125977   0.8046697991475235   1.861024543591181
# 7  0.00500  1.0261948108673096  0.27302587627767516  1.2154859744889053
# 8  0.00800  1.0620530843734741  0.29346628443219636  1.2168676644266065
#
#                   SIG                 BAK  \
# 0   3.161727319684261  2.9800910371813196
# 1   3.327225750003128  2.2555930941124807
# 2   3.261947741234889  2.6954159108318123
# 3    3.34705510636721  1.9607206064415479
# 4   3.411032154766447  1.8023635317224123
# 5  3.3226562171697673  1.7362651622079077
# 6  3.2871620999388353  1.6989649503616522
# 7   1.553798507608819  1.3195633581557902
# 8  1.5784027485507885  1.2749427962231252
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/undiff/exp4...
# 1  /data/ephraim/datasets/known_noise/undiff/exp4...
# 2  /data/ephraim/datasets/known_noise/undiff/exp4...
# 3  /data/ephraim/datasets/known_noise/undiff/exp4...
# 4  /data/ephraim/datasets/known_noise/undiff/exp4...
# 5  /data/ephraim/datasets/known_noise/undiff/exp4...
# 6  /data/ephraim/datasets/known_noise/undiff/exp4...
# 7  /data/ephraim/datasets/known_noise/undiff/exp4...
# 8  /data/ephraim/datasets/known_noise/undiff/exp4...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr0"))
# Out:
#          s                pesq                 stoi                OVRL  \
# 0  0.00005  1.0214641094207764  0.11493664438221778  2.9953656863224984
# 1  0.00008  1.0324381589889526     0.14734128690675  2.8886017961914314
# 2  0.00010  1.0328501462936401  0.16959685157071094  2.7066932753094686
# 3  0.00030  1.0335090160369873    0.345485361211164  2.5481304666221236
# 4  0.00050  1.0838085412979126    0.607072723202971   2.492886576069402
# 5  0.00080  1.1018329858779907   0.7132387842447099  1.5718344161494258
# 6  0.00100  1.0654382705688477   0.7208022382390432  1.5365140486143563
# 7  0.00500  1.0233805179595947   0.7089272060030183  1.6011382450988414
# 8  0.00800  1.0228140354156494   0.7028481258630033   1.581536263692947
#
#                   SIG                 BAK  \
# 0  3.2362757397393933  4.0588773793504425
# 1   3.169132330491835   3.999981728094513
# 2  3.0483751814139737  3.7325915698209777
# 3   3.402528162597217   2.981283214155412
# 4   3.433076460702604   2.769262871341122
# 5   2.469874457598821  1.6025384509387486
# 6  2.4131853580617517  1.3618919338334325
# 7  2.8886440059302756  1.4765902855513873
# 8  2.8522558357800873  1.4665647158867785
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/undiff/exp4...
# 1  /data/ephraim/datasets/known_noise/undiff/exp4...
# 2  /data/ephraim/datasets/known_noise/undiff/exp4...
# 3  /data/ephraim/datasets/known_noise/undiff/exp4...
# 4  /data/ephraim/datasets/known_noise/undiff/exp4...
# 5  /data/ephraim/datasets/known_noise/undiff/exp4...
# 6  /data/ephraim/datasets/known_noise/undiff/exp4...
# 7  /data/ephraim/datasets/known_noise/undiff/exp4...
# 8  /data/ephraim/datasets/known_noise/undiff/exp4...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr-5"))
# Out:
#          s                pesq                 stoi                OVRL  \
# 0  0.00008  1.0843217372894287   0.0979856775398089   2.905603866415526
# 1  0.00030  1.0733838081359863  0.38720268646254763  2.3139058716051495
# 2  0.00050   1.094661831855774    0.453387417050254  2.4094734086519938
# 3  0.00080   1.049619197845459   0.5673912455033749  2.1910964050784125
# 4  0.00500   1.024351716041565   0.6257735757381616  1.0653649903065985
# 5  0.00800  1.0236798524856567   0.6174840009177555  1.1206999712655474
#
#                   SIG                 BAK  \
# 0  3.1943151369465284  3.9390083100947946
# 1  3.0201432588415917  2.9614248319161374
# 2   3.224667912566486   2.878389329566535
# 3   3.493472439561497   2.102081489284327
# 4   1.259934232811351  1.0902598073357652
# 5   1.446659246946651  1.1107618295106674
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/undiff/exp3...
# 1  /data/ephraim/datasets/known_noise/undiff/exp3...
# 2  /data/ephraim/datasets/known_noise/undiff/exp3...
# 3  /data/ephraim/datasets/known_noise/undiff/exp3...
# 4  /data/ephraim/datasets/known_noise/undiff/exp3...
# 5  /data/ephraim/datasets/known_noise/undiff/exp3...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr-10"))
# Out:
#          s                pesq                 stoi                OVRL  \
# 0  0.00008  1.0252481698989868  0.08043269822254552   3.081004629268735
# 1  0.00030  1.0677076578140259  0.15219277941789325  3.1970035508403845
# 2  0.00050  1.0320186614990234  0.16970357906007755  2.8961703777601295
# 3  0.00080  1.1162000894546509  0.08044968569538538  2.9600860717984894
# 4  0.00500   1.026080846786499   0.5525002213499324   1.101209504091821
# 5  0.00800  1.0235819816589355   0.5731537367332532  1.1967279037162528
#
#                   SIG                 BAK  \
# 0   3.374541704459569  3.9778806012804298
# 1  3.4628839558563937   4.084348542023035
# 2  3.1433948555957856   4.031200686430424
# 3  3.2466487980912135   3.936329902065511
# 4  1.2201142895187078  1.1739893273568172
# 5   1.695762277488578  1.1841548931163424
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/undiff/exp3...
# 1  /data/ephraim/datasets/known_noise/undiff/exp3...
# 2  /data/ephraim/datasets/known_noise/undiff/exp3...
# 3  /data/ephraim/datasets/known_noise/undiff/exp3...
# 4  /data/ephraim/datasets/known_noise/undiff/exp3...
# 5  /data/ephraim/datasets/known_noise/undiff/exp3...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr-15"))
# Out:
#          s                pesq                 stoi                OVRL  \
# 0  0.00008  1.0319961309432983  0.07283269987005025   3.095909427142678
# 1  0.00030   1.026659607887268  0.10934051154249813  3.0866383002424467
# 2  0.00050  1.0359400510787964  0.23552582244845585  3.4275315191805573
# 3  0.00080  1.0328887701034546  0.17116474861803466  2.9708831634841513
# 4  0.00500  1.0820900201797485   0.2022114861579391   2.932379151149142
# 5  0.00800   1.044325590133667  0.35695826624063615  1.5953424307195165
#
#                   SIG                 BAK  \
# 0   3.351672696505298  4.0436005808224555
# 1   3.330787301275675   4.077395603843039
# 2  3.6303290140910898   4.193378573290868
# 3   3.244260563932171   4.010847837695523
# 4   3.190112671005149  3.9999122343332525
# 5   2.159603498383411  1.8278210929646848
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/undiff/exp3...
# 1  /data/ephraim/datasets/known_noise/undiff/exp3...
# 2  /data/ephraim/datasets/known_noise/undiff/exp3...
# 3  /data/ephraim/datasets/known_noise/undiff/exp3...
# 4  /data/ephraim/datasets/known_noise/undiff/exp3...
# 5  /data/ephraim/datasets/known_noise/undiff/exp3...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
enhance_dir = os.path.join(root, "snr5/s0.0003")
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp4/enhanced/snr5/s0.0003/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    8.000000    8.000000       8.000000   8.000000e+00   8.000000
# mean     1.044412    0.648021       1.154136   8.458285e-01   0.109724
# std      0.051030    0.205355       0.000000   1.186878e-16   0.051030
# min      1.020110    0.374111       1.154136   8.458285e-01  -0.012656
# 25%      1.020245    0.485374       1.154136   8.458285e-01   0.118925
# 50%      1.021447    0.650049       1.154136   8.458285e-01   0.132689
# 75%      1.035210    0.807582       1.154136   8.458285e-01   0.133891
# max      1.166792    0.926649       1.154136   8.458285e-01   0.134026
#
#        stoi_diff
# count   8.000000
# mean    0.197808
# std     0.205355
# min    -0.080821
# 25%     0.038247
# 50%     0.195780
# 75%     0.360455
# max     0.471718

# %%
enhance_dir = os.path.join(root, "snr-5/s0.005")
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp4/enhanced/snr-5/s0.005/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    8.000000    8.000000       8.000000   8.000000e+00   8.000000
# mean     1.044412    0.648021       1.030266   6.770994e-01  -0.014146
# std      0.051030    0.205355       0.000000   1.186878e-16   0.051030
# min      1.020110    0.374111       1.030266   6.770994e-01  -0.136526
# 25%      1.020245    0.485374       1.030266   6.770994e-01  -0.004944
# 50%      1.021447    0.650049       1.030266   6.770994e-01   0.008819
# 75%      1.035210    0.807582       1.030266   6.770994e-01   0.010021
# max      1.166792    0.926649       1.030266   6.770994e-01   0.010156
#
#        stoi_diff
# count   8.000000
# mean    0.029078
# std     0.205355
# min    -0.249550
# 25%    -0.130483
# 50%     0.027050
# 75%     0.191726
# max     0.302989
