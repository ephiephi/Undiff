# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os

# %%
def df_for_snr(snr_path):
    stats_path = os.path.join(snr_path, "stats_dns.json")
    with open(stats_path) as f:
        data = json.load(f)
    df = pd.DataFrame.from_dict(data).T.reset_index()
    for i in range(len(df)):
        df.at[i, "index"] = df["index"][i].split("s")[1]
    df["index"] = df["index"].astype(float)
    df = df.sort_values(by=['index']).reset_index(drop=True)
    df= df.rename(columns={"index": "s"})
    df.to_excel(os.path.join(snr_path,"measurements.xlsx"))

    return df

# %%
root = "/data/ephraim/datasets/known_noise/undiff/exp5_6/a/enhanced/"
root2 = "/data/ephraim/datasets/known_noise/undiff/exp5_6/b/enhanced/"
root2b = "/data/ephraim/datasets/known_noise/undiff/exp5_6/b/enhanced_2/"
root2c = "/data/ephraim/datasets/known_noise/undiff/exp5_6/b/enhanced_3/"
root2d = "/data/ephraim/datasets/known_noise/undiff/exp5_6/b/enhanced_4/"

# %%
df_for_snr(os.path.join(root2, "snr10"))
# Out:
#          s                pesq                 stoi              pesq_diff  \
# 0  0.00001  1.0412793159484863  0.14482305708285778   -0.04157686233520508
# 1  0.00006  1.0291614532470703  0.14507173899920384  -0.053694725036621094
# 2  0.00008  1.0396870374679565   0.2577275746687194   -0.04316914081573486
# 3  0.00010  1.0435363054275513  0.14281498165707124   -0.03931987285614014
# 4  0.00100  1.0344172716140747   0.1784970125961185    -0.0484389066696167
# 5  0.10000  1.0251471996307373  0.29729349730167465    -0.0577089786529541
# 6  1.00000  1.1612842082977295   0.9677311100678725    0.07842803001403809
# 7  1.50000   1.106536865234375   0.9581095488897935   0.023680686950683594
#
#               stoi_diff                OVRL                 SIG  \
# 0   -0.8032570193364601   2.806403869391139   3.172477273891215
# 1    -0.803008337420114   3.091578540864972  3.3800488739433416
# 2   -0.6903525017505985   2.918553628391646    3.33523935850632
# 3   -0.8052650947622466   2.680206427705474  3.0255012441560445
# 4   -0.7695830638231994  3.1987096810805506   3.430894604421225
# 5   -0.6507865791176433  3.1390490004523905  3.4360569661602254
# 6  0.019651033648554583   2.417447161891007  3.5491475671332013
# 7  0.010029472470475587   2.359472098823542  3.5166608983470105
#
#                   BAK                                        enhance_dir  \
# 0  3.7226294948377547  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1  3.9883458193887003  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2  3.7511135280070653  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3   3.817916116511793  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4  4.1313991937679075  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5  3.9969961500335742  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6  2.5851728984032953  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7   2.472974440789965  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2b, "snr10"))
# Out:
#      s                pesq                stoi             pesq_diff  \
# 0  0.5  1.2306716442108154  0.9643444495741316   0.14781546592712402
# 1  0.8  1.1909122467041016  0.9698880410119686   0.10805606842041016
# 2  0.9   1.170458436012268  0.9684743035487855   0.08760225772857666
# 3  1.0  1.1607424020767212  0.9666486619913468   0.07788622379302979
# 4  1.1  1.1453337669372559  0.9651758219386313   0.06247758865356445
# 5  1.2  1.1352248191833496  0.9638145410760343    0.0523686408996582
# 6  1.4   1.114476203918457   0.959512088891692  0.031620025634765625
#
#               stoi_diff                OVRL                 SIG  \
# 0   0.01626437315481366   2.561140609140889  3.5732458589968457
# 1  0.021807964592650664  2.4720767608482257  3.5608066784148065
# 2   0.02039422712946759  2.4688448968178003   3.554248550732609
# 3  0.018568585572028895   2.420991624473839  3.5475990883255606
# 4  0.017095745519313366  2.4289516112549623   3.547748018513759
# 5   0.01573446465671635  2.4145465281589327  3.5398870942818195
# 6  0.011432012472374131  2.3774030226069067  3.5284434668406774
#
#                   BAK                                        enhance_dir  \
# 0  2.8612591873716826  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1  2.6860218811567016  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2  2.6808913927655937  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3  2.6088434351016763  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4  2.5952050208514903  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5   2.559109730995807  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6  2.4982375969427983  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2c, "snr10"))
# Out:
#       s                pesq                stoi              pesq_diff  \
# 0  0.30  1.1680296659469604     0.9490004116752    0.08517348766326904
# 1  0.40  1.1435229778289795  0.9410573963295881   0.060666799545288086
# 2  0.60   1.218339443206787  0.9698001966880433     0.1354832649230957
# 3  0.70    1.20466947555542  0.9683323861962015    0.12181329727172852
# 4  0.75   1.193281650543213  0.9690810043821136    0.11042547225952148
# 5  0.80  1.1875625848770142  0.9695551887009416    0.10470640659332275
# 6  0.85  1.1802704334259033  0.9680470252863849    0.09741425514221191
# 7  1.60  1.1007699966430664  0.9562561899860036      0.017913818359375
# 8  2.00   1.084771990776062   0.949148683867258  0.0019158124923706055
#
#                stoi_diff                OVRL                 SIG  \
# 0  0.0009203352558820876  2.6361090952362636   3.569193137899167
# 1  -0.007022680089729838  2.6831387327538816   3.586464047063911
# 2   0.021720120268725385  2.5332792921538134  3.5858131012950936
# 3   0.020252309776883637  2.4932754114816302  3.5619370051632937
# 4   0.021000927962795735  2.4990695786713304    3.56159434338439
# 5   0.021475112281623687  2.4816559839599357   3.575787092110938
# 6   0.019966948867066958   2.433721830899151  3.5456946050958424
# 7   0.008176113566685683   2.369525181116876  3.5265943037016867
# 8  0.0010686074479401286  2.3396893804585446  3.5159278093276103
#
#                   BAK                                        enhance_dir  \
# 0   3.003202349903359  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1   3.045638176129102  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2  2.7782809661743713  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3  2.7405693806217712  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4   2.738916481006854  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5  2.6879341702684107  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6  2.6202357952603696  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7   2.485787630670962  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8   2.421398970459176  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2d, "snr10"))
# Out:
#       s                pesq                stoi            pesq_diff  \
# 0  0.45  1.2240115404129028  0.9615731706007766  0.14115536212921143
# 1  0.50  1.2289996147155762  0.9662613635856706  0.14614343643188477
# 2  0.55  1.2141485214233398  0.9659419052961817  0.13129234313964844
#
#               stoi_diff                OVRL                 SIG  \
# 0   0.01349309418145872   2.583271334261056   3.570632188374733
# 1    0.0181812871663527  2.5692439524067945  3.5753596536869696
# 2  0.017861828876863828  2.5390600768891813   3.571268832950817
#
#                   BAK                                        enhance_dir  \
# 0  2.9064785180876465  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1  2.8730061566636946  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2  2.8121160230389544  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr10"))
# Out:
#          s                pesq                 stoi              pesq_diff  \
# 0  0.00001  1.0274842977523804  0.07326937773892037   -0.02100396156311035
# 1  0.00006  1.0260895490646362  0.17423627825935178  -0.022398710250854492
# 2  0.00008   1.027242660522461   0.1919405820715229  -0.021245598793029785
# 3  0.00010   1.028095006942749  0.19185466274148058    -0.0203932523727417
# 4  0.00100  1.0270812511444092  0.11852538131283022  -0.021407008171081543
# 5  0.10000  1.0329958200454712  0.37643048420428105  -0.015492439270019531
# 6  0.50000  1.1911717653274536   0.8799568498679965     0.1426835060119629
# 7  0.80000  1.1473071575164795   0.8795942361819121    0.09881889820098877
# 8  1.00000  1.1173274517059326   0.8740758187658155     0.0688391923904419
#
#               stoi_diff                OVRL                 SIG  \
# 0   -0.7772850706525875   3.278539827613055   3.544914752830137
# 1   -0.6763181701321561  3.1667868942154223    3.45699326609722
# 2    -0.658613866319985  3.2510106324260915  3.5099496762336138
# 3   -0.6586997856500273   2.849697154448925   3.175013290327466
# 4   -0.7320290670786777  3.2657566588467057  3.5455217665821834
# 5   -0.4741239641872268  2.8797933041393455   3.251525601809258
# 6   0.02940240147648865  2.3119094541698155  3.5041689732597083
# 7   0.02903978779040428   2.295377645246018  3.4898806964874356
# 8  0.023521370374307682   2.180653987671681     3.4912919224895
#
#                   BAK                                        enhance_dir  \
# 0  4.0488911127832035  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1   4.010769788868965  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2   4.056236773298618  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3    3.82131864461007  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4   4.061302253859433  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5   3.781242308373151  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6  2.2927893035876683  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7    2.28275100008868  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8  1.9825669946346471  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
enhance_dir = os.path.join(root, "snr10/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5_4/a/enhanced/snr10/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    1.000000    1.000000       1.000000         1.0000   1.000000
# mean     1.048488    0.850554       1.033851         0.3916  -0.014638
# std           NaN         NaN            NaN            NaN        NaN
# min      1.048488    0.850554       1.033851         0.3916  -0.014638
# 25%      1.048488    0.850554       1.033851         0.3916  -0.014638
# 50%      1.048488    0.850554       1.033851         0.3916  -0.014638
# 75%      1.048488    0.850554       1.033851         0.3916  -0.014638
# max      1.048488    0.850554       1.033851         0.3916  -0.014638
#
#        stoi_diff
# count   1.000000
# mean   -0.458955
# std          NaN
# min    -0.458955
# 25%    -0.458955
# 50%    -0.458955
# 75%    -0.458955
# max    -0.458955

# %%
enhance_dir = os.path.join(root2, "snr10/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5_4/b/enhanced/snr10/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    1.000000     1.00000       1.000000        1.00000   1.000000
# mean     1.082856     0.94808       1.039436        0.54648  -0.043421
# std           NaN         NaN            NaN            NaN        NaN
# min      1.082856     0.94808       1.039436        0.54648  -0.043421
# 25%      1.082856     0.94808       1.039436        0.54648  -0.043421
# 50%      1.082856     0.94808       1.039436        0.54648  -0.043421
# 75%      1.082856     0.94808       1.039436        0.54648  -0.043421
# max      1.082856     0.94808       1.039436        0.54648  -0.043421
#
#        stoi_diff
# count     1.0000
# mean     -0.4016
# std          NaN
# min      -0.4016
# 25%      -0.4016
# 50%      -0.4016
# 75%      -0.4016
# max      -0.4016

# %%
enhance_dir = os.path.join(root, "snr5/s0.0003")
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr5/s0.0003/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.059176       0.815065  -0.014690
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.059176       0.815065  -0.090425
# 25%      1.035998    0.815752       1.059176       0.815065  -0.039869
# 50%      1.048488    0.850554       1.059176       0.815065   0.010688
# 75%      1.099045    0.876377       1.059176       0.815065   0.023177
# max      1.149601    0.902200       1.059176       0.815065   0.035667
#
#        stoi_diff
# count   3.000000
# mean   -0.029503
# std     0.060847
# min    -0.087135
# 25%    -0.061313
# 50%    -0.035490
# 75%    -0.000687
# max     0.034115
