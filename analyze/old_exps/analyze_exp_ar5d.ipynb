# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os

# %%
def df_for_snr(snr_path):
    # stats_path = snr_path
    stats_path = os.path.join(snr_path, "stats_dns.json")
    with open(stats_path) as f:
        data = json.load(f)
    df = pd.DataFrame.from_dict(data).T.reset_index()
    for i in range(len(df)):
        df.at[i, "index"] = df["index"][i].split("s")[1]
    df["index"] = df["index"].astype(float)
    df = df.sort_values(by=['index']).reset_index(drop=True)
    df= df.rename(columns={"index": "s"})
    df.to_excel(os.path.join(snr_path,"measurements.xlsx"))

    return df

# %%
# root = "/data/ephraim/datasets/known_noise/undiff/exp5b/a/enhanced/"
root3 = "/data/ephraim/datasets/known_noise/undiff/exp_ar_5d/b/enhanced/snr15_schdl2.5"
# /data/ephraim/datasets/known_noise/undiff/exp5b/b/enhanced/snr15/
# root3 = "/data/ephraim/datasets/known_noise/undiff/exp5b/c/enhanced/"

# %%
df_for_snr(root3)
# Out:
#      s                pesq                 stoi             pesq_diff  \
# 0  7.0  1.2325208187103271   0.9194224316039763  -0.21449899673461914
# 1  7.5  1.2523404359817505   0.9178065854487237   -0.1946793794631958
# 2  7.8  1.3035423755645752   0.9366589880484553   -0.1434774398803711
# 3  8.0   1.210623025894165   0.9192128406398684  -0.23639678955078125
# 4  8.2  1.2580674886703491   0.9277635374363564  -0.18895232677459717
# 5  8.5  1.0690311193466187  0.49067748567151814  -0.37798869609832764
# 6  9.0  1.0690311193466187  0.49067748567151814  -0.37798869609832764
#
#                stoi_diff                OVRL                 SIG  \
# 0   -0.04394157751618588  2.5370098624261184   3.390667041747462
# 1  -0.045557423671438446   2.494929868378804  3.2808558728271264
# 2  -0.026705021071706914   2.452331769373564   3.303935267227526
# 3   -0.04415116848029377  2.5799490454113467   3.280444748109057
# 4   -0.03560047168380576    2.52720756390595   3.391017454766225
# ...

# %%
df_for_snr("/data/ephraim/datasets/known_noise/undiff/exp_ar_5d/b/enhanced/snr15_schdl3")
# Out:
#      s                pesq                 stoi             pesq_diff  \
# 0  7.0  1.2550932168960571   0.9222914314366163  -0.19192659854888916
# 1  7.5  1.2961323261260986   0.9264660748569713  -0.15088748931884766
# 2  7.8   1.234999418258667   0.9286830535748541   -0.2120203971862793
# 3  8.0  1.2497774362564087   0.9243985699485255   -0.1972423791885376
# 4  8.2  1.3116252422332764   0.9292185568541238  -0.13539457321166992
# 5  8.5  1.2981816530227661   0.9236330290963554  -0.14883816242218018
# 6  9.0  1.0690311193466187  0.49067748567151814  -0.37798869609832764
#
#                stoi_diff                OVRL                 SIG  \
# 0  -0.041072577683545886   2.632377441154659    3.29959795361152
# 1   -0.03689793426319088   2.505585035755522   3.315140417891087
# 2  -0.034680955545308034  2.6863331021848245  3.3455132545783903
# 3   -0.03896543917163664  2.4346172007130202   3.272320441841278
# 4   -0.03414545226603838   2.533371965797443  3.1169093660909652
# ...

# %%
df_for_snr("/data/ephraim/datasets/known_noise/undiff/exp_ar_5d/b/enhanced/snr15_schdl4")
# Out:
#      s                pesq                stoi             pesq_diff  \
# 0  7.
# 5  0.000300   1.092055320739746   0.9265706898509404  -0.016527334849039715
# 6  0.000500  1.0588891506195068   0.9052004625559151   -0.04969350496927897
# 7  0.000800   1.046385407447815   0.8873613896714067  -0.062197248140970864
# 8  0.001000  1.0439661741256714   0.8823261209961993   -0.06461648146311443
#
#                stoi_diff                OVRL                 SIG  \
# 0    -0.8547645815264507   3.100986917169777   3.420947086485938
# 1     -0.695579331746022   3.118032676674137  3.4228415767003493
# ...

# %%
enhance_dir = os.path.join(root, "snr15/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr15/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.140889       0.846489   0.067023
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.140889       0.846489  -0.008712
# 25%      1.035998    0.815752       1.140889       0.846489   0.041844
# 50%      1.048488    0.850554       1.140889       0.846489   0.092400
# 75%      1.099045    0.876377       1.140889       0.846489   0.104890
# max      1.149601    0.902200       1.140889       0.846489   0.117380
#
#        stoi_diff
# count   3.000000
# mean    0.001921
# std     0.060847
# min    -0.055711
# 25%    -0.029888
# 50%    -0.004066
# 75%     0.030737
# max     0.065539

# %%
enhance_dir = os.path.join(root, "snr5/s0.0003")
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr5/s0.0003/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.059176       0.815065  -0.014690
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.059176       0.815065  -0.090425
# 25%      1.035998    0.815752       1.059176       0.815065  -0.039869
# 50%      1.048488    0.850554       1.059176       0.815065   0.010688
# 75%      1.099045    0.876377       1.059176       0.815065   0.023177
# max      1.149601    0.902200       1.059176       0.815065   0.035667
#
#        stoi_diff
# count   3.000000
# mean   -0.029503
# std     0.060847
# min    -0.087135
# 25%    -0.061313
# 50%    -0.035490
# 75%    -0.000687
# max     0.034115
