# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os

# %%
def df_for_snr(snr_path):
    stats_path = os.path.join(snr_path, "stats_dns.json")
    with open(stats_path) as f:
        data = json.load(f)
    df = pd.DataFrame.from_dict(data).T.reset_index()
    for i in range(len(df)):
        df.at[i, "index"] = df["index"][i].split("s")[1]
    df["index"] = df["index"].astype(float)
    df = df.sort_values(by=['index']).reset_index(drop=True)
    df= df.rename(columns={"index": "s"})
    df.to_excel(os.path.join(snr_path,"measurements.xlsx"))

    return df

# %%
root = "/data/ephraim/datasets/known_noise/undiff/exp7b/a/enhanced/"
root2 = "/data/ephraim/datasets/known_noise/undiff/exp7b/b/enhanced/"

# %%
df_for_snr(os.path.join(root, "snr5"))
# Out:
#       s                pesq                stoi              pesq_diff  \
# 0  0.01  1.1744085550308228  0.2529744738165671    0.08829665184020996
# 1  0.05   1.265303611755371  0.7604665291106348     0.1791917085647583
# 2  0.07  1.2922143936157227  0.7633542475008045    0.20610249042510986
# 3  0.09  1.4463646411895752  0.7449558485175295     0.3602527379989624
# 4  0.10  1.6411850452423096  0.7840498905919379     0.5550731420516968
# 5  0.20  1.2713918685913086  0.8001634512739915     0.1852799654006958
# 6  0.30  1.1220372915267944  0.7903467390931743    0.03592538833618164
# 7  0.50  1.0299086570739746  0.5407878771914623  -0.056203246116638184
# 8  0.80  1.0411815643310547  0.4132492165223112  -0.044930338859558105
#
#                stoi_diff                OVRL                 SIG  \
# 0    -0.5577588829051092   2.776859645085432  3.1688181914017517
# 1   -0.05026682761104151  2.6932797662703045  3.0651727684539423
# 2   -0.04737910922087185  2.6638594044876083   3.020099825063019
# 3   -0.06577750820414685   2.822194468876441   3.111470678012035
# 4  -0.026683466129738598   2.857839957558713  3.1509682646085846
# 5   -0.01056990544768488   2.785642611352452   3.418416069861903
# 6  -0.020386617628501913   2.532048014833333  3.4656426381810768
# 7    -0.2699454795302141  1.0922854601091896  1.1737959047284134
# 8    -0.3974841401993651  1.2364172857367572  1.6688195815306655
#
#                   BAK                                        enhance_dir  \
# 0    3.71645152360581  /data/ephraim/datasets/known_noise/undiff/exp7...
# 1    3.83627418696349  /data/ephraim/datasets/known_noise/undiff/exp7...
# 2  3.8583328646090673  /data/ephraim/datasets/known_noise/undiff/exp7...
# 3   4.010464175363784  /data/ephraim/datasets/known_noise/undiff/exp7...
# 4   4.014912815653855  /data/ephraim/datasets/known_noise/undiff/exp7...
# 5  3.3954482658605425  /data/ephraim/datasets/known_noise/undiff/exp7...
# 6  2.8710759355444555  /data/ephraim/datasets/known_noise/undiff/exp7...
# 7  1.0948695780716944  /data/ephraim/datasets/known_noise/undiff/exp7...
# 8   1.339270388504807  /data/ephraim/datasets/known_noise/undiff/exp7...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr15"))
# Out:
#            s                pesq                 stoi              pesq_diff  \
# 0   0.000005  1.0411556959152222   0.5402113965597127  -0.044956207275390625
# 1   0.000008  1.0963830947875977   0.6148488286840588   0.010271191596984863
# 2   0.000009  1.0341229438781738   0.5593792759990758  -0.051988959312438965
# 3   0.000010  1.1356712579727173   0.5642441209843774    0.04955935478210449
# 4   0.000020    1.11822509765625   0.3408722191735683    0.03211319446563721
# 5   0.000040  1.0655616521835327   0.3878151298112671  -0.020550251007080078
# 6   0.000050  1.1679848432540894  0.39764640367349946    0.08187294006347656
# 7   0.000080   1.063581109046936  0.37815680991097905  -0.022530794143676758
# 8   0.000100   1.633354902267456  0.39365416282680976     0.5472429990768433
# 9   0.000300  1.0331844091415405  0.39214489030582506  -0.052927494049072266
# 10  0.000500  1.0514495372772217  0.41479349894706113   -0.03466236591339111
# 11  0.000800  1.0237585306167603  0.27968330290414734   -0.06235337257385254
# 12  0.001000   1.039044976234436  0.15053313642675942   -0.04706692695617676
#
#                stoi_diff                OVRL                 SIG  \
# 0    -0.2705219601619636  1.9353038207433866  3.2978259349936576
# 1   -0.19588452803761758    1.85219981257804   3.165520715526521
# 2   -0.25135408072260057   1.720808540325553   3.202530359763075
# 3   -0.24648923573729897   1.111939816776413   1.221512045471293
# 4   -0.46986113754810804  1.4646971347140412   2.868743607175261
# 5   -0.42291822691040926  1.0752920407149897  1.2584024578827242
# 6    -0.4130869530481769  1.0686149517712968   1.229392352356718
# 7    -0.4325765468106973  1.1897313657420414  1.5239536038408048
# 8    -0.4170791938948666   1.129482340620209  1.3653461071147932
# 9    -0.4185884664158513  1.1446126902155116  1.4104074300571012
# 10   -0.3959398577746152  1.4903651185246722   2.542293477931586
# 11    -0.531050053817529   2.037539592784101   2.299438241479368
# 12   -0.6602002202949169   1.951118067216547  2.2038685000488836
#
#                    BAK                                        enhance_dir  \
# 0   1.8470578056254936  /data/ephraim/datasets/known_noise/undiff/exp7...
# 1    1.779733299111584  /data/ephraim/datasets/known_noise/undiff/exp7...
# 2     1.52558425271374  /data/ephraim/datasets/known_noise/undiff/exp7...
# 3   1.1317786644208827  /data/ephraim/datasets/known_noise/undiff/exp7...
# 4   1.2504029240890193  /data/ephraim/datasets/known_noise/undiff/exp7...
# 5    1.171602682391084  /data/ephraim/datasets/known_noise/undiff/exp7...
# 6   1.2178956178983071  /data/ephraim/datasets/known_noise/undiff/exp7...
# 7   1.3328881496878118  /data/ephraim/datasets/known_noise/undiff/exp7...
# 8   1.2459587921750748  /data/ephraim/datasets/known_noise/undiff/exp7...
# 9   1.2272596485388914  /data/ephraim/datasets/known_noise/undiff/exp7...
# 10  1.4620138737996269  /data/ephraim/datasets/known_noise/undiff/exp7...
# 11  3.7336657497839174  /data/ephraim/datasets/known_noise/undiff/exp7...
# 12   3.530559412888502  /data/ephraim/datasets/known_noise/undiff/exp7...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr10"))
# Out:
#           s                pesq                 stoi              pesq_diff  \
# 0  0.000005  1.0411725044250488   0.6417225894189411  -0.044939398765563965
# 1  0.000010   1.037397861480713   0.6662344031979988    -0.0487140417098999
# 2  0.000050    1.03047776222229  0.40482256797922994  -0.055634140968322754
# 3  0.000080  1.0344170331954956  0.36829904225576887   -0.05169486999511719
# 4  0.000100   1.035050392150879  0.38333362785579145   -0.05106151103973389
# 5  0.000300  1.0361875295639038   0.3949771646159957  -0.049924373626708984
# 6  0.000500  1.0347368717193604    0.407316960841792   -0.05137503147125244
# 7  0.000800   1.032280683517456  0.39346340015037623   -0.05383121967315674
# 8  0.001000  1.0284349918365479  0.23381071736411962   -0.05767691135406494
#
#               stoi_diff                OVRL                 SIG  \
# 0  -0.16901076730273523   1.978458094372442  3.2113633206409733
# 1   -0.1444989535236776  1.8057086917336342   3.213056940364726
# 2   -0.4059107887424463   1.067685623293949  1.2333276819043968
# 3  -0.44243431446590736   1.169202031110861  1.4961645987728767
# 4    -0.427399728865885  1.0930259814027654  1.2832670902138485
# 5  -0.41575619210568066  1.2242088987521587  1.6389938625859877
# 6  -0.40341639587988437   1.217551233482251  1.5946125944210519
# 7   -0.4172699565713001   1.861028797057758  2.1400159918329966
# 8   -0.5769226393575567  2.0883223886275752  2.3470873391623437
#
#                   BAK                                        enhance_dir  \
# 0   2.018845951977846  /data/ephraim/datasets/known_noise/undiff/exp7...
# 1   1.745996960510964  /data/ephraim/datasets/known_noise/undiff/exp7...
# 2  1.1636858185747034  /data/ephraim/datasets/known_noise/undiff/exp7...
# 3   1.244052734891939  /data/ephraim/datasets/known_noise/undiff/exp7...
# 4  1.1761739443961643  /data/ephraim/datasets/known_noise/undiff/exp7...
# 5  1.2919587463978062  /data/ephraim/datasets/known_noise/undiff/exp7...
# 6  1.3168715077588542  /data/ephraim/datasets/known_noise/undiff/exp7...
# 7  3.6077069913204967  /data/ephraim/datasets/known_noise/undiff/exp7...
# 8  3.7301222865739505  /data/ephraim/datasets/known_noise/undiff/exp7...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2, "snr10"))
# Out:
#           s                pesq                 stoi              pesq_diff  \
# 0  0.000005  1.0363031029701233   0.2367585327981303   -0.07330610354741414
# 1  0.000010  1.0803517699241638  0.32828271426289213  -0.029257436593373615
# 2  0.000050  1.0275511145591736  0.28970688330103667   -0.08205809195836385
# 3  0.000080  1.0251947045326233  0.31152531466024735   -0.08441450198491414
# 4  0.000100  1.1033053994178772  0.29718690463185155  -0.006303807099660237
# 5  0.000300  1.0688287019729614   0.2832375383143691   -0.04078050454457601
# 6  0.000500  1.1983606219291687   0.3118933178736519    0.08875141541163127
# 7  0.000800   1.049708068370819  0.22522192135126393  -0.059901138146718345
# 8  0.001000  1.0355274677276611  0.12212478787642049    -0.0740817387898763
#
#               stoi_diff                OVRL                 SIG  \
# 0   -0.5160122625314725  1.9120123602178194     3.3064020675091
# 1   -0.4244880810667106  1.3998042701726048  2.1768063576361674
# 2  -0.46306391202856606   1.200274908192271  1.5700449378344894
# 3  -0.44124548066935537  1.0750760393500693  1.2338228445701274
# 4  -0.45558389069775124  1.1268800021911227  1.3441661337332889
# 5   -0.4695332570152336   1.139765454174929  1.3839435034911556
# 6   -0.4408774774559509  1.3213703849985619   1.998304176525521
# 7   -0.5275488739783388   2.108533775281784  2.3326048741099896
# 8   -0.6306460074531822  2.0313772363558047  2.3185558641624997
#
#                   BAK                                        enhance_dir  \
# 0  1.8328146394861324  /data/ephraim/datasets/known_noise/undiff/exp7...
# 1  1.3836345957360658  /data/ephraim/datasets/known_noise/undiff/exp7...
# 2  1.2708573494299933  /data/ephraim/datasets/known_noise/undiff/exp7...
# 3   1.146899290099347  /data/ephraim/datasets/known_noise/undiff/exp7...
# 4  1.1933826537916152  /data/ephraim/datasets/known_noise/undiff/exp7...
# 5  1.2454706331600565  /data/ephraim/datasets/known_noise/undiff/exp7...
# 6  1.3334910785717224  /data/ephraim/datasets/known_noise/undiff/exp7...
# 7  3.8323573544619554  /data/ephraim/datasets/known_noise/undiff/exp7...
# 8  3.5858555940668335  /data/ephraim/datasets/known_noise/undiff/exp7...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr5"))
# Out:
#           s                pesq                 stoi              pesq_diff  \
# 0  0.000005    1.43832266330719  0.21015733743906395     0.3682631254196167
# 1  0.000010  1.0847877264022827  0.24213288395457158   0.014728188514709473
# 2  0.000050  1.0568357706069946   0.6736488147050862  -0.013223767280578613
# 3  0.000080  1.0755043029785156   0.8319879035248818   0.005444765090942383
# 4  0.000100  1.0654627084732056   0.8707784651149885  -0.004596829414367676
# 5  0.000300  1.0354137420654297    0.833892111368329  -0.034645795822143555
# 6  0.000500    1.02838933467865   0.7983991424149196   -0.04167020320892334
# 7  0.000800  1.0534095764160156    0.449399730200513  -0.016649961471557617
# 8  0.001000  1.6576318740844727    0.345703608391249     0.5875723361968994
#
#                stoi_diff                OVRL                 SIG  \
# 0    -0.6787636879672356  3.2087987255516337  3.4935488984632523
# 1     -0.646788141451728   2.761269442969042   3.303819335950927
# 2   -0.21527221070121327   2.440456440133928   3.552126416901923
# 3   -0.05693312188141775  2.0419387204785724  3.2961814253482733
# 4  -0.018142560291311116  1.9623876041279673  3.2683223058444657
# 5    -0.0550289140379705  1.8934916522260758  3.2478523674719124
# 6   -0.09052188299137998   1.723604028284813  3.0441594345898215
# 7    -0.4395212952057866  1.0631624058318174  1.1876404039353903
# 8    -0.5432174170150507  1.2800877281770637    1.72906354027755
#
#                   BAK                                        enhance_dir  \
# 0   4.047615626391267  /data/ephraim/datasets/known_noise/undiff/exp6...
# 1  3.4692623798056283  /data/ephraim/datasets/known_noise/undiff/exp6...
# 2  2.5017663494817883  /data/ephraim/datasets/known_noise/undiff/exp6...
# 3  2.0596992475328393  /data/ephraim/datasets/known_noise/undiff/exp6...
# 4    1.95516543954584  /data/ephraim/datasets/known_noise/undiff/exp6...
# 5  1.7135428515192392  /data/ephraim/datasets/known_noise/undiff/exp6...
# 6  1.6611235642963444  /data/ephraim/datasets/known_noise/undiff/exp6...
# 7   1.141429613441741  /data/ephraim/datasets/known_noise/undiff/exp6...
# 8  1.3444347838592154  /data/ephraim/datasets/known_noise/undiff/exp6...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2, "snr5"))
# Out:
#           s                pesq                 stoi             pesq_diff  \
# 0  0.000005  1.0408030152320862   0.3333279377464947  -0.06880619128545125
# 1  0.000010  1.0307561755180359   0.3529417151616075  -0.07885303099950154
# 2  0.000050  1.0419691801071167   0.3121203975947152  -0.06764002641042073
# 3  0.000080  1.0664892196655273  0.30795936036949073  -0.04311998685201009
# 4  0.000100  1.1246416568756104  0.30027045490786347  0.015032450358072916
# 5  0.000300   1.133006989955902   0.3087764442561348  0.023397783438364666
# 6  0.000500  1.1152947545051575  0.30356897510828834  0.005685547987620036
# 7  0.000800  1.0294654369354248  0.31366416992786417  -0.08014376958211263
# 8  0.001000  1.0628700852394104  0.22854668454512947  -0.04673912127812704
#
#              stoi_diff                OVRL                 SIG  \
# 0   -0.419442857583108   1.413020424122653  2.1047566444406063
# 1  -0.3998290801679953  1.3418404868971558  1.9458494558203547
# 2  -0.4406503977348875  1.0707522062959365  1.1906347838916518
# 3   -0.444811434960112  1.1319929510869788  1.3801678177590475
# 4  -0.4525003404217392  1.0855973858658725  1.2846687355741782
# 5  -0.4439943510734679  1.2060055434741284    1.54472965164871
# 6  -0.4492018202213144   1.335878571251005  1.9215083835546531
# 7  -0.4391066254017386  1.5637126993647952    2.58467330336218
# 8  -0.5242241107844733  2.0640227410169096   2.309205525894116
#
#                   BAK                                        enhance_dir  \
# 0  1.4400166297032762  /data/ephraim/datasets/known_noise/undiff/exp7...
# 1  1.4034956360133153  /data/ephraim/datasets/known_noise/undiff/exp7...
# 2  1.1377083427051944  /data/ephraim/datasets/known_noise/undiff/exp7...
# 3  1.2073822650217507  /data/ephraim/datasets/known_noise/undiff/exp7...
# 4  1.1970783659500341  /data/ephraim/datasets/known_noise/undiff/exp7...
# 5  1.2536358030043506  /data/ephraim/datasets/known_noise/undiff/exp7...
# 6  1.3604344668937898  /data/ephraim/datasets/known_noise/undiff/exp7...
# 7  1.8862419010237828  /data/ephraim/datasets/known_noise/undiff/exp7...
# 8  3.7801289295155183  /data/ephraim/datasets/known_noise/undiff/exp7...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
enhance_dir = os.path.join(root, "snr15/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr15/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.140889       0.846489   0.067023
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.140889       0.846489  -0.008712
# 25%      1.035998    0.815752       1.140889       0.846489   0.041844
# 50%      1.048488    0.850554       1.140889       0.846489   0.092400
# 75%      1.099045    0.876377       1.140889       0.846489   0.104890
# max      1.149601    0.902200       1.140889       0.846489   0.117380
#
#        stoi_diff
# count   3.000000
# mean    0.001921
# std     0.060847
# min    -0.055711
# 25%    -0.029888
# 50%    -0.004066
# 75%     0.030737
# max     0.065539

# %%
enhance_dir = os.path.join(root, "snr5/s0.0003")
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr5/s0.0003/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.059176       0.815065  -0.014690
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.059176       0.815065  -0.090425
# 25%      1.035998    0.815752       1.059176       0.815065  -0.039869
# 50%      1.048488    0.850554       1.059176       0.815065   0.010688
# 75%      1.099045    0.876377       1.059176       0.815065   0.023177
# max      1.149601    0.902200       1.059176       0.815065   0.035667
#
#        stoi_diff
# count   3.000000
# mean   -0.029503
# std     0.060847
# min    -0.087135
# 25%    -0.061313
# 50%    -0.035490
# 75%    -0.000687
# max     0.034115
