# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os

# %%
def df_for_snr(snr_path):
    stats_path = os.path.join(snr_path, "stats_dns.json")
    with open(stats_path) as f:
        data = json.load(f)
    df = pd.DataFrame.from_dict(data).T.reset_index()
    for i in range(len(df)):
        df.at[i, "index"] = df["index"][i].split("s")[1]
    df["index"] = df["index"].astype(float)
    df = df.sort_values(by=['index']).reset_index(drop=True)
    df= df.rename(columns={"index": "s"})
    df.to_excel(os.path.join(snr_path,"measurements.xlsx"))

    return df

# %%
root = "/data/ephraim/datasets/known_noise/undiff/exp5_3/a/enhanced/"
root2 = "/data/ephraim/datasets/known_noise/undiff/exp5_3/b/enhanced/"

# %%
df_for_snr(os.path.join(root, "snr10"))
# Out:
#          s                pesq                 stoi              pesq_diff  \
# 0  0.00001  1.0515317916870117    0.500705076268753   0.003043532371520996
# 1  0.00005  1.0829520225524902   0.8484034046615235    0.03446376323699951
# 2  0.00008  1.0544817447662354    0.854526733382278   0.005993485450744629
# 3  0.00010  1.0456560850143433   0.8482621631129472  -0.002832174301147461
# 4  0.00100  1.0169568061828613  0.41284863700541047  -0.031531453132629395
# 5  0.01000  1.0801525115966797   0.4634876273915048   0.031664252281188965
# 6  0.10000  1.0801525115966797   0.4634876273915048   0.031664252281188965
# 7  0.90000  1.0801525115966797   0.4634876273915048   0.031664252281188965
# 8  1.00000  1.0801525115966797   0.4634876273915048   0.031664252281188965
# 9  1.10000  1.0801525115966797   0.4634876273915048   0.031664252281188965
#
#                 stoi_diff                OVRL                 SIG  \
# 0     -0.3498493721227548  2.1060150927991224   3.283630326385397
# 1  -0.0021510437299843144  2.1252840097225447  3.5414709632701564
# 2    0.003972284990770181  2.0385182520522087   3.540470190663288
# 3   -0.002292285278560624  1.9783432606610625  3.5204961744942933
# 4     -0.4377058113860974  1.3963679303871264  2.2259109806306236
# 5    -0.38706682100000306   2.050853804747207  2.3948427066511497
# 6    -0.38706682100000306   2.050853804747207  2.3948427066511497
# 7    -0.38706682100000306   2.050853804747207  2.3948427066511497
# 8    -0.38706682100000306   2.050853804747207  2.3948427066511497
# 9    -0.38706682100000306   2.050853804747207  2.3948427066511497
#
#                   BAK                                        enhance_dir  \
# 0  2.2327608254724267  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1  1.8789143488210764  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2  1.7110351104967947  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3   1.637096162983937  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4   1.356413663119568  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
# 9  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...
# 9  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2, "snr10"))
# Out:
#          s                pesq                stoi              pesq_diff  \
# 0  0.00001  1.0363047122955322  0.5381410887063091   -0.04655146598815918
# 1  0.00005   1.138108253479004  0.9587156722791873     0.0552520751953125
# 2  0.00008  1.0929347276687622  0.9526155230842749     0.0100785493850708
# 3  0.00010  1.0797733068466187  0.9463104044465963  -0.003082871437072754
# 4  0.00100  1.0225300788879395  0.4684933249441125   -0.06032609939575195
# 5  0.01000    1.06905198097229  0.4905963120098233  -0.013804197311401367
# 6  0.10000    1.06905198097229  0.4905963120098233  -0.013804197311401367
# 7  0.90000    1.06905198097229  0.4905963120098233  -0.013804197311401367
# 8  1.00000    1.06905198097229  0.4905963120098233  -0.013804197311401367
# 9  1.10000    1.06905198097229  0.4905963120098233  -0.013804197311401367
#
#                 stoi_diff                OVRL                 SIG  \
# 0    -0.40993898771300885   2.275127759665477  3.4011558767041037
# 1    0.010635595859869396  2.2010296617810865  3.4521383396121768
# 2    0.004535446664956977  2.3555043658513157  3.5196169684904213
# 3  -0.0017696719727215982  2.3237016142106834   3.516326743946315
# 4     -0.4795867514752054   1.295888378956325   2.174135143541901
# 5     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 6     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 7     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 8     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 9     -0.4574837644094946  2.0561589061114076   2.424318311745673
#
#                   BAK                                        enhance_dir  \
# 0   2.485042307300102  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1   2.235353193884674  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2  2.4532685835550447  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3  2.3910569039837837  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4  1.1674639723266913  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 9   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...
# 7  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8  Namespace(enhanced_dir='/data/ephraim/datasets...
# 9  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
enhance_dir = os.path.join(root, "snr10/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5_2/a/enhanced/snr10/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    1.000000    1.000000       1.000000       1.000000   1.000000
# mean     1.048488    0.850554       1.033609       0.431223  -0.014879
# std           NaN         NaN            NaN            NaN        NaN
# min      1.048488    0.850554       1.033609       0.431223  -0.014879
# 25%      1.048488    0.850554       1.033609       0.431223  -0.014879
# 50%      1.048488    0.850554       1.033609       0.431223  -0.014879
# 75%      1.048488    0.850554       1.033609       0.431223  -0.014879
# max      1.048488    0.850554       1.033609       0.431223  -0.014879
#
#        stoi_diff
# count   1.000000
# mean   -0.419332
# std          NaN
# min    -0.419332
# 25%    -0.419332
# 50%    -0.419332
# 75%    -0.419332
# max    -0.419332

# %%
enhance_dir = os.path.join(root2, "snr10/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5_2/b/enhanced/snr10/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    1.000000     1.00000       1.000000       1.000000   1.000000
# mean     1.082856     0.94808       1.040112       0.529661  -0.042744
# std           NaN         NaN            NaN            NaN        NaN
# min      1.082856     0.94808       1.040112       0.529661  -0.042744
# 25%      1.082856     0.94808       1.040112       0.529661  -0.042744
# 50%      1.082856     0.94808       1.040112       0.529661  -0.042744
# 75%      1.082856     0.94808       1.040112       0.529661  -0.042744
# max      1.082856     0.94808       1.040112       0.529661  -0.042744
#
#        stoi_diff
# count   1.000000
# mean   -0.418419
# std          NaN
# min    -0.418419
# 25%    -0.418419
# 50%    -0.418419
# 75%    -0.418419
# max    -0.418419

# %%
enhance_dir = os.path.join(root, "snr5/s0.0003")
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr5/s0.0003/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.059176       0.815065  -0.014690
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.059176       0.815065  -0.090425
# 25%      1.035998    0.815752       1.059176       0.815065  -0.039869
# 50%      1.048488    0.850554       1.059176       0.815065   0.010688
# 75%      1.099045    0.876377       1.059176       0.815065   0.023177
# max      1.149601    0.902200       1.059176       0.815065   0.035667
#
#        stoi_diff
# count   3.000000
# mean   -0.029503
# std     0.060847
# min    -0.087135
# 25%    -0.061313
# 50%    -0.035490
# 75%    -0.000687
# max     0.034115
