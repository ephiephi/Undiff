# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os

# %%
def df_for_snr(snr_path):
    stats_path = os.path.join(snr_path, "stats_dns.json")
    with open(stats_path) as f:
        data = json.load(f)
    df = pd.DataFrame.from_dict(data).T.reset_index()
    for i in range(len(df)):
        df.at[i, "index"] = df["index"][i].split("s")[1]
    df["index"] = df["index"].astype(float)
    df = df.sort_values(by=['index']).reset_index(drop=True)
    df= df.rename(columns={"index": "s"})
    df.to_excel(os.path.join(snr_path,"measurements.xlsx"))

    return df

# %%
root = "/data/ephraim/datasets/known_noise/undiff/exp5_6/b/enhanced_2/"
root2 = "/data/ephraim/datasets/known_noise/undiff/exp5_7/2/enhanced/"
root3 = "/data/ephraim/datasets/known_noise/undiff/exp5_7/3/enhanced/"
root4 = "/data/ephraim/datasets/known_noise/undiff/exp5_7/4/enhanced/"
root5 = "/data/ephraim/datasets/known_noise/undiff/exp5_7/5/enhanced/"
root6 = "/data/ephraim/datasets/known_noise/undiff/exp5_7/6/enhanced/"

# %%
df_for_snr(os.path.join(root, "snr10"))
# Out:
#      s                pesq                stoi             pesq_diff  \
# 0  0.5  1.2306716442108154  0.9643444495741316   0.14781546592712402
# 1  0.8  1.1909122467041016  0.9698880410119686   0.10805606842041016
# 2  0.9   1.170458436012268  0.9684743035487855   0.08760225772857666
# 3  1.0  1.1607424020767212  0.9666486619913468   0.07788622379302979
# 4  1.1  1.1453337669372559  0.9651758219386313   0.06247758865356445
# 5  1.2  1.1352248191833496  0.9638145410760343    0.0523686408996582
# 6  1.4   1.114476203918457   0.959512088891692  0.031620025634765625
#
#               stoi_diff                OVRL                 SIG  \
# 0   0.01626437315481366   2.561140609140889  3.5732458589968457
# 1  0.021807964592650664  2.4720767608482257  3.5608066784148065
# 2   0.02039422712946759  2.4688448968178003   3.554248550732609
# 3  0.018568585572028895   2.420991624473839  3.5475990883255606
# 4  0.017095745519313366  2.4289516112549623   3.547748018513759
# 5   0.01573446465671635  2.4145465281589327  3.5398870942818195
# 6  0.011432012472374131  2.3774030226069067  3.5284434668406774
#
#                   BAK                                        enhance_dir  \
# 0  2.8612591873716826  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1  2.6860218811567016  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2  2.6808913927655937  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3  2.6088434351016763  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4  2.5952050208514903  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5   2.559109730995807  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6  2.4982375969427983  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...
# 5  Namespace(enhanced_dir='/data/ephraim/datasets...
# 6  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root2, "snr10"))
# Out:
#          s                pesq                 stoi              pesq_diff  \
# 0   0.0001  1.0366489887237549  0.14398419918113448   -0.04620718955993652
# 1   0.0010   1.037583351135254  0.49925624067493185    -0.0452728271484375
# 2   0.0030  1.5630793571472168    0.947781051908838     0.4802231788635254
# 3   0.0035  1.8153233528137207   0.9691844711144476     0.7324671745300293
# 4   0.0038  1.8047597408294678   0.9699992607919112     0.7219035625457764
# 5   0.0039  1.7814140319824219   0.9688373194602913     0.6985578536987305
# 6   0.0040  1.7307507991790771   0.9686627897349863     0.6478946208953857
# 7   0.0041   1.697608470916748   0.9705441787848009     0.6147522926330566
# 8   0.0042  1.7342212200164795   0.9725638839329669     0.6513650417327881
# 9   0.0045  1.5831444263458252   0.9713970980171334     0.5002882480621338
# 10  0.0050  1.5710117816925049   0.9727424098355598     0.4881556034088135
# 11  0.0070  1.4331707954406738   0.9764581188661531     0.3503146171569824
# 12  0.0080  1.3642566204071045   0.9747931114379298     0.2814004421234131
# 13  0.0090  1.3311810493469238   0.9740871991041449    0.24832487106323242
# 14  0.0100  1.3283737897872925   0.9729839286254253    0.24551761150360107
# 15  0.0130  1.2346279621124268   0.9688882222959188    0.15177178382873535
# 16  0.0150  1.1909663677215576   0.9644109448886962    0.10811018943786621
# 17  0.0200  1.1473033428192139   0.9622726365937214    0.06444716453552246
# 18  0.0500  1.0226027965545654   0.5296442500287353   -0.06025338172912598
# 19  0.5000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 20  0.6000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 21  0.8000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 22  1.0000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 23  1.0000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 24  1.2000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 25  1.5000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 26  2.0000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 27  3.0000    1.06905198097229   0.4905963120098233  -0.013804197311401367
#
#                  stoi_diff                OVRL                 SIG  \
# 0      -0.8040958772381834  3.0180674103409686  3.4499305636484574
# 1     -0.44882383574438606  2.7091646293824274  3.3839744408370853
# 2   -0.0002990245104799172  2.8929095396178823   3.388993364489086
# 3     0.021104394695129702  2.7869231642300827  3.3993168075433062
# 4     0.021919184372593326  2.8418904772372975   3.430724154482018
# 5     0.020757243040973372  2.9062156809667523  3.5047300818845244
# 6      0.02058271331566841  2.8656763682545843   3.506763964233408
# 7      0.02246410236548302  2.7886011905488073   3.476825836592487
# 8      0.02448380751364898  2.8441106738377373  3.4737712288800653
# 9     0.023317021597815457  2.7826184906153872  3.5006577771468743
# 10     0.02466233341624191  2.8368764292790187  3.5620736998320033
# 11    0.028378042446835172  2.6295599370471825   3.572246407352112
# 12    0.026713035018611886   2.501091339809603  3.5562230931223957
# 13    0.026007122684826967  2.5419943295786167   3.576576869689449
# 14    0.024903852206107358   2.537424943718149  3.5611665048725585
# 15    0.020808145876600848  2.4455819418443463  3.5484663413283752
# 16    0.016330868469378257  2.3767154126114107  3.5332587382252263
# 17    0.014192560174403512    2.35996395832721  3.5144924288356942
# 18    -0.41843582639058263  1.1620966677910667  1.4877699767793566
# 19     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 20     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 21     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 22     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 23     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 24     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 25     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 26     -0.4574837644094946  2.0561589061114076   2.424318311745673
# 27     -0.4574837644094946  2.0561589061114076   2.424318311745673
#
#                    BAK                                        enhance_dir  \
# 0     3.73622734446437  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1   3.3600618077211366  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2     3.63992945554634  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3   3.4532753956652913  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4    3.495819251263342  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5    3.521884837115071  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6   3.4492711093419723  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7    3.333439044826804  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8    3.452030272807206  /data/ephraim/datasets/known_noise/undiff/exp5...
# 9    3.291650445665089  /data/ephraim/datasets/known_noise/undiff/exp5...
# 10   3.317627946225204  /data/ephraim/datasets/known_noise/undiff/exp5...
# 11   2.932461161184668  /data/ephraim/datasets/known_noise/undiff/exp5...
# 12   2.717412365709067  /data/ephraim/datasets/known_noise/undiff/exp5...
# 13  2.7566838410305508  /data/ephraim/datasets/known_noise/undiff/exp5...
# 14    2.79815114075766  /data/ephraim/datasets/known_noise/undiff/exp5...
# 15  2.6324380993063863  /data/ephraim/datasets/known_noise/undiff/exp5...
# 16  2.5093961077291556  /data/ephraim/datasets/known_noise/undiff/exp5...
# 17   2.475483105493293  /data/ephraim/datasets/known_noise/undiff/exp5...
# 18  1.2291959535655093  /data/ephraim/datasets/known_noise/undiff/exp5...
# 19   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 20   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 21   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 22   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 23   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 24   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 25   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 26   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 27   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...
# 14  Namespace(enhanced_dir='/data/ephraim/datasets...
# 15  Namespace(enhanced_dir='/data/ephraim/datasets...
# 16  Namespace(enhanced_dir='/data/ephraim/datasets...
# 17  Namespace(enhanced_dir='/data/ephraim/datasets...
# 18  Namespace(enhanced_dir='/data/ephraim/datasets...
# 19  Namespace(enhanced_dir='/data/ephraim/datasets...
# 20  Namespace(enhanced_dir='/data/ephraim/datasets...
# 21  Namespace(enhanced_dir='/data/ephraim/datasets...
# 22  Namespace(enhanced_dir='/data/ephraim/datasets...
# 23  Namespace(enhanced_dir='/data/ephraim/datasets...
# 24  Namespace(enhanced_dir='/data/ephraim/datasets...
# 25  Namespace(enhanced_dir='/data/ephraim/datasets...
# 26  Namespace(enhanced_dir='/data/ephraim/datasets...
# 27  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root3, "snr10"))
# Out:
#          s                pesq                 stoi              pesq_diff  \
# 0   0.0001   1.024489402770996   0.4034570992491569   -0.05836677551269531
# 1   0.0010   1.162726640701294   0.9582900039508829    0.07987046241760254
# 2   0.0030  1.0744844675064087   0.9431144750863378  -0.008371710777282715
# 3   0.0050  1.0653303861618042   0.9349169731973762  -0.017525792121887207
# 4   0.0070  1.0457310676574707   0.8818944647100967    -0.0371251106262207
# 5   0.0080   1.032918095588684   0.8018251850067462  -0.049938082695007324
# 6   0.0090  1.0247650146484375   0.7095795881742396  -0.058091163635253906
# 7   0.0100  1.0245288610458374   0.6183094771557492  -0.058327317237854004
# 8   0.0130  1.0246440172195435   0.5268455534565337   -0.05821216106414795
# 9   0.0150  1.0258417129516602   0.4790587281625893   -0.05701446533203125
# 10  0.0200  1.0236483812332153  0.45647853460668236  -0.059207797050476074
# 11  0.0500  1.0293313264846802  0.15954185671113508   -0.05352485179901123
# 12  0.1000  1.0681085586547852   0.4905963120098233   -0.01474761962890625
# 13  0.5000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 14  0.6000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 15  0.8000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 16  1.0000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 17  1.0000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 18  1.2000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 19  1.5000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 20  2.0000    1.06905198097229   0.4905963120098233  -0.013804197311401367
# 21  3.0000    1.06905198097229   0.4905963120098233  -0.013804197311401367
#
#                 stoi_diff                OVRL                 SIG  \
# 0      -0.544622977170161  2.6452030080960225   3.456198078252837
# 1    0.010209927531565022  2.3242767071666735  3.5283759807515724
# 2   -0.004965601332980074   2.315373731245532  3.5133888029213476
# 3   -0.013163103221941697  2.2784430637739503  3.4882351556173736
# 4    -0.06618561170922121  2.0230118715925838  3.4469747615859725
# 5    -0.14625489141257175  1.5732905451641268     2.8939114376565
# 6     -0.2385004882450783  1.0716136228526185  1.2102935130654326
# 7    -0.32977059926356866  1.0616053123125286  1.1975923798946575
# 8     -0.4212345229627842  1.2414580823011225  1.7003722635729157
# 9     -0.4690213482567286  1.2430770465673315  1.6777510644064435
# 10   -0.49160154181263555  1.2337110484103324  1.7506331335832446
# 11    -0.7885382197081828    2.12150465765577  2.4122771175142184
# 12    -0.4574837644094946   2.062996624991314   2.414262453391996
# 13    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 14    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 15    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 16    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 17    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 18    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 19    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 20    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 21    -0.4574837644094946  2.0561589061114076   2.424318311745673
#
#                    BAK                                        enhance_dir  \
# 0    2.990776868081647  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1    2.406399833197189  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2     2.37302791206361  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3    2.289624124789056  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4   1.9033067735432776  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5   1.4628984758137384  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6    1.129426284408712  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7   1.1408058751853638  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8   1.2944342315199653  /data/ephraim/datasets/known_noise/undiff/exp5...
# 9   1.3289310326997348  /data/ephraim/datasets/known_noise/undiff/exp5...
# 10  1.2371504156595372  /data/ephraim/datasets/known_noise/undiff/exp5...
# 11  3.6367527392365337  /data/ephraim/datasets/known_noise/undiff/exp5...
# 12  3.3846768448180278  /data/ephraim/datasets/known_noise/undiff/exp5...
# 13   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 14   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 15   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 16   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 17   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 18   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 19   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 20   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 21   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...
# 14  Namespace(enhanced_dir='/data/ephraim/datasets...
# 15  Namespace(enhanced_dir='/data/ephraim/datasets...
# 16  Namespace(enhanced_dir='/data/ephraim/datasets...
# 17  Namespace(enhanced_dir='/data/ephraim/datasets...
# 18  Namespace(enhanced_dir='/data/ephraim/datasets...
# 19  Namespace(enhanced_dir='/data/ephraim/datasets...
# 20  Namespace(enhanced_dir='/data/ephraim/datasets...
# 21  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root4, "snr10"))
# Out:
#         s                pesq                 stoi              pesq_diff  \
# 0   0.001  1.0292633771896362  0.17951370428787855  -0.053592801094055176
# 1   0.005  1.0329011678695679  0.18972531919538388  -0.049955010414123535
# 2   0.008  1.0301603078842163   0.4718420829808707    -0.0526958703994751
# 3   0.010  1.2221125364303589   0.8378086595757939    0.13925635814666748
# 4   0.050  1.5183038711547852   0.9481673856163019    0.43544769287109375
# 5   0.070  1.5557081699371338   0.9591871289282188     0.4728519916534424
# 6   0.080  1.5877785682678223   0.9657031013048555     0.5049223899841309
# 7   0.090   1.700985312461853   0.9654555481030581     0.6181291341781616
# 8   0.095   1.912790298461914    0.972966593825943     0.8299341201782227
# 9   0.098  1.8740661144256592   0.9702014344614871     0.7912099361419678
# 10  0.099  1.7750048637390137    0.970983163235373     0.6921486854553223
# 11  0.100  1.8877999782562256   0.9713604891967353     0.8049437999725342
# 12  0.105  1.9193439483642578   0.9689288285433021     0.8364877700805664
# 13  0.110  1.8259600400924683   0.9744121474283497     0.7431038618087769
# 14  0.120   1.927321195602417   0.9746618968141064     0.8444650173187256
# 15  0.150  1.6651358604431152   0.9741789299945977     0.5822796821594238
# 16  0.200  1.5149343013763428   0.9754971843505255    0.43207812309265137
# 17  0.300  1.4283618927001953   0.9729265831501583     0.3455057144165039
# 18  0.400  1.3205046653747559   0.9726875347745407    0.23764848709106445
# 19  0.450  1.2668120861053467   0.9717756755768145    0.18395590782165527
# 20  0.500   1.302590250968933   0.9706514579890301     0.2197340726852417
# 21  0.550  1.2649850845336914   0.9647019045413714          0.18212890625
# 22  0.600    1.25625479221344   0.9680661871813528    0.17339861392974854
# 23  0.800   1.084605097770691   0.4892160786881736  0.0017489194869995117
# 24  1.000  1.0225809812545776   0.4320397256919117   -0.06027519702911377
#
#                 stoi_diff                OVRL                 SIG  \
# 0     -0.7685663721314393  3.2651505041893207   3.511980209666124
# 1      -0.758354757223934   2.919323083412409  3.1873095966189697
# 2     -0.4762379934384472   3.191421860470931    3.51212741894356
# 3    -0.11027141684352404    2.92015306477692  3.2439525365432154
# 4   8.730919698396455e-05   2.780530818592637  3.1963076464614235
# 5    0.011107052508900872  3.0048206801459867   3.362990667653894
# 6    0.017623024885537575  3.1123640341789525   3.405419450652079
# 7    0.017375471683740207   3.094734119935926  3.4446018409837005
# 8    0.024886517406625064  3.0420581290451656  3.4053861838038073
# 9    0.022121358042169192   3.186120260347193  3.4870521175138594
# 10    0.02290308681605513  3.1886906273617988  3.5061472603904957
# 11   0.023280412777417436  3.1656951997501066   3.473872531156327
# 12   0.020848752123984182   3.081360908083139  3.4485125730791557
# 13   0.026332071009031788  3.1142998772022925  3.4715834241666608
# 14   0.026581820394788513  3.0886794759408707  3.4449721511373244
# 15   0.026098853575279746  2.7768550906939953   3.487200119618548
# 16    0.02741710793120755  2.5759686891516567   3.532885901091085
# 17   0.024846506730840434  2.5740264629471907  3.5682438931203344
# 18   0.024607458355222822   2.526075142156297  3.5742308304999653
# 19    0.02369559915749664  2.4873881487798113  3.5334540157187186
# 20   0.022571381569712168   2.442227348014221   3.555046668438948
# 21   0.016621828122053484  2.4135231831900374   3.537792747977993
# 22   0.019986110762034937     2.4640503495213   3.536163672071457
# 23   -0.45886399773114434  1.1546856206951757  1.4386230562745908
# 24    -0.5160403507274063  1.1426629577212066  1.4096273258856848
#
#                    BAK                                        enhance_dir  \
# 0    4.100041376698114  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1    3.980391139906698  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2    3.979665231352601  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3    3.920521606667768  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4   3.7538651356891606  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5   3.8903949191294136  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6    4.020267393278781  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7   3.9381714237967325  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8   3.8948650139141514  /data/ephraim/datasets/known_noise/undiff/exp5...
# 9      4.0119163000769  /data/ephraim/datasets/known_noise/undiff/exp5...
# 10   4.000721066924832  /data/ephraim/datasets/known_noise/undiff/exp5...
# 11  3.9978647568364165  /data/ephraim/datasets/known_noise/undiff/exp5...
# 12   3.905087199725564  /data/ephraim/datasets/known_noise/undiff/exp5...
# 13    3.93393136646975  /data/ephraim/datasets/known_noise/undiff/exp5...
# 14  3.8969759135178843  /data/ephraim/datasets/known_noise/undiff/exp5...
# 15  3.2933735316323234  /data/ephraim/datasets/known_noise/undiff/exp5...
# 16   2.864841955104884  /data/ephraim/datasets/known_noise/undiff/exp5...
# 17  2.8261044788740106  /data/ephraim/datasets/known_noise/undiff/exp5...
# 18   2.728529416922222  /data/ephraim/datasets/known_noise/undiff/exp5...
# 19   2.702456098675185  /data/ephraim/datasets/known_noise/undiff/exp5...
# 20   2.588098671291417  /data/ephraim/datasets/known_noise/undiff/exp5...
# 21  2.5950426163818503  /data/ephraim/datasets/known_noise/undiff/exp5...
# 22   2.663635790303751  /data/ephraim/datasets/known_noise/undiff/exp5...
# 23  1.2309360041400101  /data/ephraim/datasets/known_noise/undiff/exp5...
# 24  1.2250793614588213  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...
# 14  Namespace(enhanced_dir='/data/ephraim/datasets...
# 15  Namespace(enhanced_dir='/data/ephraim/datasets...
# 16  Namespace(enhanced_dir='/data/ephraim/datasets...
# 17  Namespace(enhanced_dir='/data/ephraim/datasets...
# 18  Namespace(enhanced_dir='/data/ephraim/datasets...
# 19  Namespace(enhanced_dir='/data/ephraim/datasets...
# 20  Namespace(enhanced_dir='/data/ephraim/datasets...
# 21  Namespace(enhanced_dir='/data/ephraim/datasets...
# 22  Namespace(enhanced_dir='/data/ephraim/datasets...
# 23  Namespace(enhanced_dir='/data/ephraim/datasets...
# 24  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root5, "snr10"))
# Out:
#           s                pesq                 stoi              pesq_diff  \
# 0   0.00001  1.0297868251800537  0.08526924247113794  -0.053069353103637695
# 1   0.00010   1.032914161682129  0.23540928496948918    -0.0499420166015625
# 2   0.00050  1.0352082252502441  0.20077850678320117  -0.047647953033447266
# 3   0.00100   1.054036259651184   0.2240019462643336  -0.028819918632507324
# 4   0.01000  1.0495270490646362   0.1637588036867904  -0.033329129219055176
# 5   0.05000   1.029301404953003   0.2757336646251046   -0.05355477333068848
# 6   0.10000  1.0361289978027344  0.27960573748366935   -0.04672718048095703
# 7   0.30000  1.0338616371154785   0.2019818373411964   -0.04899454116821289
# 8   0.50000  1.0363285541534424  0.28066654530300905   -0.04652762413024902
# 9   0.70000  1.0230377912521362     0.39774847333402  -0.059818387031555176
# 10  0.80000  1.0292024612426758    0.181635350430363  -0.053653717041015625
# 11  1.00000   3.951718807220459    0.316323430954094     2.8688626289367676
# 12  1.20000  1.0218342542648315  0.31677351281656735   -0.06102192401885986
# 13  1.50000  1.0243581533432007  0.36426141660579864   -0.05849802494049072
# 14  2.00000  1.0176608562469482  0.34869519204406446   -0.06519532203674316
# 15  3.00000   1.049410104751587  0.32508125051688713   -0.03344607353210449
# 16  5.00000   1.023091197013855   0.3605451355099009  -0.059764981269836426
#
#               stoi_diff                OVRL                 SIG  \
# 0   -0.8628108339481799   3.021874396558126  3.2781760780510116
# 1   -0.7126707914498287  3.1705488874509204  3.5177715392691633
# 2   -0.7473015696361167  2.6284327282157216   2.849316485279425
# 3   -0.7240781301549843   3.130165911335559  3.4638126661810724
# 4   -0.7843212727325275   2.882998761508591   3.138415275695627
# 5   -0.6723464117942133  3.0630952472906685   3.306153383438642
# 6   -0.6684743389356486  2.7090692113826997  2.9708630363257456
# 7   -0.7460982390781215  2.9249908910706095    3.41471415511328
# 8   -0.6674135311163089  2.4361091953749003  2.6660741413609785
# 9   -0.5503316030852978   1.650401500983169  2.0846763794969756
# 10  -0.7664447259889549   2.947842296239524  3.2014780187173884
# 11  -0.6317566454652239    1.68774226773902   2.264397288317564
# 12  -0.6313065636027506   1.710437206279747  2.3217244602834843
# 13  -0.5838186598135193    1.90615766148449   2.399654879357515
# 14  -0.5993848843752534  1.8080208088053042   2.217033364840743
# 15  -0.6229988259024308  1.8428817538361009   2.340060918403093
# 16   -0.587534940909417  1.7429278123796466  2.3346238055201516
#
#                    BAK                                        enhance_dir  \
# 0    4.006677561319702  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1    3.879504303912866  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2   3.9193737279337464  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3   3.9206365221476234  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4   3.9885125994189794  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5    4.046291571203809  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6   3.9787033799461997  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7   3.6289899157994685  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8   3.9932960570758382  /data/ephraim/datasets/known_noise/undiff/exp5...
# 9   3.5016391788286367  /data/ephraim/datasets/known_noise/undiff/exp5...
# 10   4.029790777934091  /data/ephraim/datasets/known_noise/undiff/exp5...
# 11  3.4123813938691927  /data/ephraim/datasets/known_noise/undiff/exp5...
# 12  3.4072447907697914  /data/ephraim/datasets/known_noise/undiff/exp5...
# 13   3.694065109964105  /data/ephraim/datasets/known_noise/undiff/exp5...
# 14  3.7508007623415094  /data/ephraim/datasets/known_noise/undiff/exp5...
# 15   3.631378669162212  /data/ephraim/datasets/known_noise/undiff/exp5...
# 16    3.47116748874677  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...
# 14  Namespace(enhanced_dir='/data/ephraim/datasets...
# 15  Namespace(enhanced_dir='/data/ephraim/datasets...
# 16  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root6, "snr10"))
# Out:
#           s                pesq                  stoi              pesq_diff  \
# 0   0.00001  1.0293117761611938   0.16692438937592627   -0.05354440212249756
# 1   0.00010  1.0280870199203491    0.1074312759401904  -0.054769158363342285
# 2   0.00050  1.0242524147033691   0.33517474296446287  -0.058603763580322266
# 3   0.00100  1.0281686782836914   0.39686693217603203             -0.0546875
# 4   0.00500   1.193782925605774    0.9322922647796122    0.11092674732208252
# 5   0.01000  1.1053320169448853      0.95754398658682   0.022475838661193848
# 6   0.10000  1.0290776491165161   0.49106734292589893   -0.05377852916717529
# 7   0.30000  1.0236765146255493   0.36815869234442783   -0.05917966365814209
# 8   0.50000  1.0368947982788086  0.014873370880045363   -0.04596138000488281
# 9   0.80000   1.067941427230835    0.4905963120098233  -0.014914751052856445
# 10  1.00000  1.0686485767364502    0.4905963120098233  -0.014207601547241211
# 11  1.20000    1.06905198097229    0.4905963120098233  -0.013804197311401367
# 12  1.50000    1.06905198097229    0.4905963120098233  -0.013804197311401367
# 13  2.00000    1.06905198097229    0.4905963120098233  -0.013804197311401367
#
#                 stoi_diff                OVRL                 SIG  \
# 0     -0.7811556870433917  2.9824636418824326  3.2800582335822286
# 1     -0.8406488004791275  3.2583890581612716   3.504502812226639
# 2     -0.6129053334548551  2.7376060639791158  3.3993003036542353
# 3     -0.5512131442432859  2.9865112992289666  3.5395131662708814
# 4   -0.015787811639705662    2.27481441643916   3.498092341876582
# 5    0.009463910167502143  2.3777769561852944   3.530548518346631
# 6      -0.457012733493419   1.331737740786475  1.9322589603324327
# 7       -0.57992138407489  1.5623252769997367   2.758101828791348
# 8     -0.9332067055392725  2.0563100931663034  2.3809377116936226
# 9     -0.4574837644094946  1.9562410414105862  2.2570703837530393
# 10    -0.4574837644094946     2.0660273666357  2.4215600832271447
# 11    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 12    -0.4574837644094946  2.0561589061114076   2.424318311745673
# 13    -0.4574837644094946  2.0561589061114076   2.424318311745673
#
#                    BAK                                        enhance_dir  \
# 0   3.9739976317608514  /data/ephraim/datasets/known_noise/undiff/exp5...
# 1    4.102052760706158  /data/ephraim/datasets/known_noise/undiff/exp5...
# 2    3.269603987936566  /data/ephraim/datasets/known_noise/undiff/exp5...
# 3   3.6001353007637173  /data/ephraim/datasets/known_noise/undiff/exp5...
# 4   2.3303211512972433  /data/ephraim/datasets/known_noise/undiff/exp5...
# 5    2.504484023962089  /data/ephraim/datasets/known_noise/undiff/exp5...
# 6   1.3696199317983329  /data/ephraim/datasets/known_noise/undiff/exp5...
# 7    1.596158757224399  /data/ephraim/datasets/known_noise/undiff/exp5...
# 8   3.4217168149911794  /data/ephraim/datasets/known_noise/undiff/exp5...
# 9    3.438088361312275  /data/ephraim/datasets/known_noise/undiff/exp5...
# 10  3.4371118315467624  /data/ephraim/datasets/known_noise/undiff/exp5...
# 11   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 12   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
# 13   3.385140595413906  /data/ephraim/datasets/known_noise/undiff/exp5...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
enhance_dir = os.path.join(root, "snr10/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5_4/a/enhanced/snr10/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    1.000000    1.000000       1.000000         1.0000   1.000000
# mean     1.048488    0.850554       1.033851         0.3916  -0.014638
# std           NaN         NaN            NaN            NaN        NaN
# min      1.048488    0.850554       1.033851         0.3916  -0.014638
# 25%      1.048488    0.850554       1.033851         0.3916  -0.014638
# 50%      1.048488    0.850554       1.033851         0.3916  -0.014638
# 75%      1.048488    0.850554       1.033851         0.3916  -0.014638
# max      1.048488    0.850554       1.033851         0.3916  -0.014638
#
#        stoi_diff
# count   1.000000
# mean   -0.458955
# std          NaN
# min    -0.458955
# 25%    -0.458955
# 50%    -0.458955
# 75%    -0.458955
# max    -0.458955

# %%
enhance_dir = os.path.join(root2, "snr10/s"+str(0.000010))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5_4/b/enhanced/snr10/s1e-05/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    1.000000     1.00000       1.000000        1.00000   1.000000
# mean     1.082856     0.94808       1.039436        0.54648  -0.043421
# std           NaN         NaN            NaN            NaN        NaN
# min      1.082856     0.94808       1.039436        0.54648  -0.043421
# 25%      1.082856     0.94808       1.039436        0.54648  -0.043421
# 50%      1.082856     0.94808       1.039436        0.54648  -0.043421
# 75%      1.082856     0.94808       1.039436        0.54648  -0.043421
# max      1.082856     0.94808       1.039436        0.54648  -0.043421
#
#        stoi_diff
# count     1.0000
# mean     -0.4016
# std          NaN
# min      -0.4016
# 25%      -0.4016
# 50%      -0.4016
# 75%      -0.4016
# max      -0.4016

# %%
enhance_dir = os.path.join(root, "snr5/s0.0003")
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# /data/ephraim/datasets/known_noise/undiff/exp5/a/enhanced/snr5/s0.0003/stats.pickle
# b
#        pesq_noisy  stoi_noisy  pesq_enhanced  stoi_enhanced  pesq_diff  \
# count    3.000000    3.000000       3.000000       3.000000   3.000000
# mean     1.073866    0.844568       1.059176       0.815065  -0.014690
# std      0.066767    0.060847       0.000000       0.000000   0.066767
# min      1.023509    0.780949       1.059176       0.815065  -0.090425
# 25%      1.035998    0.815752       1.059176       0.815065  -0.039869
# 50%      1.048488    0.850554       1.059176       0.815065   0.010688
# 75%      1.099045    0.876377       1.059176       0.815065   0.023177
# max      1.149601    0.902200       1.059176       0.815065   0.035667
#
#        stoi_diff
# count   3.000000
# mean   -0.029503
# std     0.060847
# min    -0.087135
# 25%    -0.061313
# 50%    -0.035490
# 75%    -0.000687
# max     0.034115
