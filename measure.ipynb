# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os
from tqdm import tqdm
from glob import glob
from pathlib import Path
import argparse

from DNSMOS import dnsmos_local

# %%
ours
# Out:
# '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/enhanced_60/snr15/s0.8/digits_snr15_power0.0001966120132704691_var2.029404067900836e-05.wav'

# %%
noise_wav
# Out:
# tensor([[-0.0035, -0.0266, -0.0346,  ..., -0.0126, -0.0363, -0.0196]])

# %%
exp_dir = "/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/"
enhanced_dir =  Path(exp_dir)/"enhanced_60"
clean_dir = Path(exp_dir)/"clean_wav"
noisy_dir =  Path(exp_dir)/"noisy_wav"
snr_dirs = glob(os.path.join(enhanced_dir,"*/"))

mos_args = argparse.Namespace(
            testset_dir=enhanced_dir, personalized_MOS=False, csv_path=None)
dns_df_all = dnsmos_local.main(mos_args)

data=[]
for snr_dir in tqdm(snr_dirs): 
    # print(snr_dir)
    # snr_dir = "/data/ephraim/datasets/known_noise/enhanced_diffwave_1sec/snr10/"
    stats_path =os.path.join(snr_dir, "new_stats_dns.json")
    # if os.path.exists(stats_path):
    #     os.remove(stats_path)
    s_dirs =glob(snr_dir+"*/")
    # print(s_dirs)
    
    for i,path_ in tqdm(enumerate(s_dirs)):
        wavs_ = glob(path_+"*.wav")
        if len(wavs_)>0:
            ours = glob(path_+"*.wav")[0]
            enhance, en_sr = torchaudio.load(ours)
            name = Path(ours).name
            clean_path = Path(clean_dir)/name
            speech_wav, _sr = torchaudio.load(clean_path)
            noisy_path =  Path(noisy_dir)/name
            noisy_wav, _sr = torchaudio.load(noisy_path)
            # Compute metrics
            metrics = get_metrics(clean=speech_wav[0].numpy(), mix=noisy_wav[0].numpy(),estimate=enhance[0].numpy(), sample_rate=en_sr)
            metrics["name"] = Path(path_).name
            metrics["filename"] = (ours)
            metrics["snr"] = ours.split("snr")[1].split("/")[0]
            # Print metrics
            # print(metrics)
            data.append(metrics)
        #[sgmse2 ,sgmse1,storm1,storm2,ours ]
    if len(data) >0:
        df = pd.DataFrame.from_records(data,index=range(len(data))) 

print(df[["name","stoi","pesq","si_sdr","sdr", "sir","sar","filename"]])
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 379.93it/s]
# 24it [00:05,  4.24it/s]
#          len_in_sec       sr  num_hops   OVRL_raw    SIG_raw    BAK_raw  \
# count  2.400000e+01     24.0      24.0  24.000000  24.000000  24.000000
# mean   3.072188e+00  16000.0       3.0   2.756377   3.511196   3.011586
# std    1.360922e-15      0.0       0.0   0.479085   0.471453   0.723804
# min    3.072188e+00  16000.0       3.0   1.234100   2.013977   1.175506
# 25%    3.072188e+00  16000.0       3.0   2.571010   3.494932   2.595553
# 50%    3.072188e+00  16000.0       3.0   2.900719   3.618265   3.155013
# 75%    3.072188e+00  16000.0       3.0   3.062475   3.709937   3.580998
# max    3.072188e+00  16000.0       3.0   3.351140   4.005170   3.958208
#
#             OVRL        SIG        BAK   P808_MOS
# count  24.000000  24.000000  24.000000  24.000000
# mean    2.591230   3.236965   3.188192   2.917645
# std     0.379245   0.342883   0.646231   0.244340
# min     1.316100   2.087073   1.310244   2.078439
# 25%     2.466285   3.246143   2.887000   2.836280
# 50%     2.711821   3.323143   3.368016   2.988370
# 75%     2.827327   3.377727   3.677079   3.085768
# max     3.024070   3.547660   3.910056   3.198521
# 35it [00:04,  7.20it/s]0:00<?, ?it/s]
# 35it [00:04,  7.70it/s]0:04<00:09,  4.87s/it]
# 35it [00:03,  8.81it/s]0:09<00:04,  4.68s/it]
# 100%|██████████| 3/3 [00:13<00:00,  4.46s/it]
#      name      stoi      pesq     si_sdr        sdr  sir        sar  \
# 0   s0.08  0.774804  1.155371   7.196098   8.263950  inf   8.263950
# 1    s0.1  0.821067  1.233412   7.301231   8.113083  inf   8.113083
# 2   s0.15  0.840721  1.239702   7.200322   7.604075  inf   7.604075
# 3    s0.2  0.835769  1.224372   6.885378   7.136270  inf   7.136270
# 4    s0.3  0.843774  1.226662   6.063457   6.170658  inf   6.170658
# 5    s0.5  0.831435  1.216001   5.461143   5.407394  inf   5.407394
# 6    s0.7  0.821892  1.214518   5.215982   5.194066  inf   5.194066
# 7    s0.8  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 8   s0.08  0.832384  1.284603   9.372696  10.730274  inf  10.730274
# 9    s0.1  0.871257  1.378785  10.489999  11.677181  inf  11.677181
# 10  s0.15  0.883854  1.395049  10.907966  11.613163  inf  11.613163
# 11   s0.2  0.891573  1.492113  11.218143  11.702948  inf  11.702948
# 12   s0.3  0.897458  1.473924  10.959938  11.184930  inf  11.184930
# 13   s0.5  0.895327  1.392385  10.618467  10.650703  inf  10.650703
# 14   s0.7  0.893603  1.359825  10.359502  10.412328  inf  10.412328
# 15   s0.8  0.680864  1.079234   2.699163   2.792699  inf   2.792699
# 16  s0.08  0.875283  1.510553  10.939256  11.913450  inf  11.913450
# 17   s0.1  0.889482  1.544159  11.754502  12.118385  inf  12.118385
# 18  s0.15  0.910316  1.545522  12.816641  11.617435  inf  11.617435
# 19   s0.2  0.911839  1.582529  13.631644  10.732721  inf  10.732721
# 20   s0.3  0.921226  1.622616  14.163534   9.152320  inf   9.152320
# 21   s0.5  0.924964  1.623682  14.447042   7.473364  inf   7.473364
# 22   s0.7  0.920034  1.592560  14.068188   6.499854  inf   6.499854
# 23   s0.8  0.921447  1.600023  14.030305   6.329352  inf   6.329352
#
#                                              filename
# 0   /data/ephraim/datasets/known_noise/undiff/exp_...
# 1   /data/ephraim/datasets/known_noise/undiff/exp_...
# 2   /data/ephraim/datasets/known_noise/undiff/exp_...
# 3   /data/ephraim/datasets/known_noise/undiff/exp_...
# 4   /data/ephraim/datasets/known_noise/undiff/exp_...
# 5   /data/ephraim/datasets/known_noise/undiff/exp_...
# 6   /data/ephraim/datasets/known_noise/undiff/exp_...
# 7   /data/ephraim/datasets/known_noise/undiff/exp_...
# 8   /data/ephraim/datasets/known_noise/undiff/exp_...
# 9   /data/ephraim/datasets/known_noise/undiff/exp_...
# 10  /data/ephraim/datasets/known_noise/undiff/exp_...
# 11  /data/ephraim/datasets/known_noise/undiff/exp_...
# 12  /data/ephraim/datasets/known_noise/undiff/exp_...
# 13  /data/ephraim/datasets/known_noise/undiff/exp_...
# 14  /data/ephraim/datasets/known_noise/undiff/exp_...
# 15  /data/ephraim/datasets/known_noise/undiff/exp_...
# 16  /data/ephraim/datasets/known_noise/undiff/exp_...
# 17  /data/ephraim/datasets/known_noise/undiff/exp_...
# 18  /data/ephraim/datasets/known_noise/undiff/exp_...
# 19  /data/ephraim/datasets/known_noise/undiff/exp_...
# 20  /data/ephraim/datasets/known_noise/undiff/exp_...
# 21  /data/ephraim/datasets/known_noise/undiff/exp_...
# 22  /data/ephraim/datasets/known_noise/undiff/exp_...
# 23  /data/ephraim/datasets/known_noise/undiff/exp_...

# %%
glob(str(noisy_dir)+"/*.wav")
# Out:
# ['/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/noisy_wav/digits_snr5_power0.001966120132704691_var0.0002029404067900836.wav',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/noisy_wav/digits_snr10_power0.0006217417772859335_var6.417539147377648e-05.wav',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/noisy_wav/digits_snr15_power0.0001966120132704691_var2.029404067900836e-05.wav']

# %%
noisy_dir
# Out:
# PosixPath('/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/noisy_wav')

# %%
data_noisy = []
noisy_wavs_ = glob(str(noisy_dir)+"/*.wav")
for i,cur_noisy_path in tqdm(enumerate(noisy_wavs_)):
    noisy_wav, en_sr = torchaudio.load(cur_noisy_path)
    name = Path(cur_noisy_path).name
    clean_path = Path(clean_dir)/name
    speech_wav, _sr = torchaudio.load(clean_path)
    
    # Compute metrics
    metrics = get_metrics(clean=speech_wav[0].numpy(), mix=noisy_wav[0].numpy(),estimate=noisy_wav[0].numpy(), sample_rate=en_sr)
    metrics["name"] = Path(path_).name
    metrics["filename"] = (ours)
    metrics["snr"] = ours.split("snr")[1].split("/")[0]
    # Print metrics
    # print(metrics)
    data_noisy.append(metrics)
    #[sgmse2 ,sgmse1,storm1,storm2,ours ]
if len(data_noisy) >0:
    df_noisy = pd.DataFrame.from_records(data_noisy,index=range(len(data_noisy)))
# Out:
# 3it [00:01,  1.98it/s]

# %%
mos_args = argparse.Namespace(
            testset_dir=str(noisy_dir), personalized_MOS=False, csv_path=None
        )
dns_df_noisy = dnsmos_local.main(mos_args)
# Out:
#    input_si_sdr  input_sdr  input_sir  input_sar  input_stoi  input_pesq  \
# 0      3.100840   3.152654        inf   3.152654    0.794392    1.065842
# 1      8.113476   8.153293        inf   8.153293    0.867492    1.172677
# 2     13.120584  13.156618        inf  13.156618    0.913651    1.429465
#
#       si_sdr        sdr  sir        sar      stoi      pesq name  \
# 0   3.100840   3.152654  inf   3.152654  0.794392  1.065842   s4
# 1   8.113476   8.153293  inf   8.153293  0.867492  1.172677   s4
# 2  13.120584  13.156618  inf  13.156618  0.913651  1.429465   s4
#
#                                             filename snr
# 0  /data/ephraim/datasets/known_noise/undiff/exp_...  15
# 1  /data/ephraim/datasets/known_noise/undiff/exp_...  15
# 2  /data/ephraim/datasets/known_noise/undiff/exp_...  15

# %%
df_noisy.merge(dns_df_noisy, on="filename")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 df_noisy.merge(dns_df_noisy, on="filename")
#
# NameError: name 'dns_df_noisy' is not defined

# %%
snr_dir
# Out:
# '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/enhanced_60/snr5/'

# %%
enhanced_dir
# Out:
# PosixPath('/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/enhanced_60')

# %%
df
# Out:
#    input_si_sdr  input_sdr  input_sir  input_sar  input_stoi  input_pesq  \
# 0      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 1      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 2      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 3      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 4      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 5      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 6      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 7      3.213828   3.240499        inf   3.240499    0.800087    1.064025
#
#       si_sdr        sdr  sir        sar      stoi      pesq   name  \
# 0   7.196098   8.263950  inf   8.263950  0.774804  1.155371  s0.08
# 1   7.301231   8.113083  inf   8.113083  0.821067  1.233412   s0.1
# 2   7.200322   7.604075  inf   7.604075  0.840721  1.239702  s0.15
# 3   6.885378   7.136270  inf   7.136270  0.835769  1.224372   s0.2
# 4   6.063457   6.170658  inf   6.170658  0.843774  1.226662   s0.3
# 5   5.461143   5.407394  inf   5.407394  0.831435  1.216001   s0.5
# 6   5.215982   5.194066  inf   5.194066  0.821892  1.214518   s0.7
# 7 -79.936211 -16.616933  inf -16.616933  0.475881  1.043714   s0.8
#
#                                             filename
# 0  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4  /data/ephraim/datasets/known_noise/undiff/exp_...
# 5  /data/ephraim/datasets/known_noise/undiff/exp_...
# 6  /data/ephraim/datasets/known_noise/undiff/exp_...
# 7  /data/ephraim/datasets/known_noise/undiff/exp_...

# %%
df.merge(dns_df_all, on="filename")
# Out:
#     input_si_sdr  input_sdr  input_sir  input_sar  input_stoi  input_pesq  \
# 0       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 1       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 2       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 3       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 4       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 5       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 6       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 7       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 8       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 9       3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 10      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 11      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 12      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 13      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 14      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 15      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 16      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 17      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 18      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 19      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 20      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 21      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 22      3.213828   3.240499        inf   3.240499    0.800087    1.064025
# 23      3.213828   3.240499        inf   3.240499    0.800087    1.064025
#
#        si_sdr        sdr  sir        sar  ...  len_in_sec     sr num_hops  \
# 0    7.196098   8.263950  inf   8.263950  ...    3.072188  16000        3
# 1    7.301231   8.113083  inf   8.113083  ...    3.072188  16000        3
# 2    7.200322   7.604075  inf   7.604075  ...    3.072188  16000        3
# 3    6.885378   7.136270  inf   7.136270  ...    3.072188  16000        3
# 4    6.063457   6.170658  inf   6.170658  ...    3.072188  16000        3
# 5    5.461143   5.407394  inf   5.407394  ...    3.072188  16000        3
# 6    5.215982   5.194066  inf   5.194066  ...    3.072188  16000        3
# 7  -79.936211 -16.616933  inf -16.616933  ...    3.072188  16000        3
# 8    9.372696  10.730274  inf  10.730274  ...    3.072188  16000        3
# 9   10.489999  11.677181  inf  11.677181  ...    3.072188  16000        3
# 10  10.907966  11.613163  inf  11.613163  ...    3.072188  16000        3
# 11  11.218143  11.702948  inf  11.702948  ...    3.072188  16000        3
# 12  10.959938  11.184930  inf  11.184930  ...    3.072188  16000        3
# 13  10.618467  10.650703  inf  10.650703  ...    3.072188  16000        3
# 14  10.359502  10.412328  inf  10.412328  ...    3.072188  16000        3
# 15   2.699163   2.792699  inf   2.792699  ...    3.072188  16000        3
# 16  10.939256  11.913450  inf  11.913450  ...    3.072188  16000        3
# 17  11.754502  12.118385  inf  12.118385  ...    3.072188  16000        3
# 18  12.816641  11.617435  inf  11.617435  ...    3.072188  16000        3
# 19  13.631644  10.732721  inf  10.732721  ...    3.072188  16000        3
# 20  14.163534   9.152320  inf   9.152320  ...    3.072188  16000        3
# 21  14.447042   7.473364  inf   7.473364  ...    3.072188  16000        3
# 22  14.068188   6.499854  inf   6.499854  ...    3.072188  16000        3
# 23  14.030305   6.329352  inf   6.329352  ...    3.072188  16000        3
#
#     OVRL_raw   SIG_raw   BAK_raw      OVRL       SIG       BAK  P808_MOS
# 0   3.250640  3.569253  3.914407  2.956952  3.292896  3.885182  2.870284
# 1   2.940419  3.648328  3.104045  2.740022  3.340991  3.327170  2.873090
# 2   3.242935  3.873020  3.431062  2.951245  3.473829  3.571971  2.729020
# 3   2.899853  3.831106  2.904990  2.710857  3.449773  3.163255  2.894134
# 4   2.586646  4.005170  2.293308  2.478224  3.547660  2.601352  3.006527
# 5   2.524101  3.983687  2.158293  2.430466  3.535914  2.463592  2.818142
# 6   2.076991  3.496364  1.816373  2.070776  3.247020  2.091951  3.011774
# 7   1.989986  2.233114  3.208444  1.997832  2.312760  3.411415  2.078439
# 8   2.902199  3.258051  3.590959  2.713323  3.091341  3.683641  2.993399
# 9   3.281802  3.569847  3.958208  2.978015  3.293203  3.910056  3.082465
# 10  2.774854  3.490637  3.049884  2.619823  3.243513  3.283981  2.841168
# 11  2.925797  3.597889  3.205981  2.730339  3.310654  3.408863  3.146341
# 12  2.769468  3.657641  2.861252  2.615563  3.346795  3.122203  3.119608
# 13  2.407308  3.669547  2.280802  2.338848  3.353712  2.588965  2.821618
# 14  2.467280  3.867449  2.184958  2.386278  3.470773  2.491255  2.983341
# 15  1.234100  2.013977  1.175506  1.316100  2.087073  1.310244  2.459364
# 16  3.065268  3.354978  3.882914  2.829282  3.155729  3.866300  2.867439
# 17  2.901585  3.237231  3.737235  2.712785  3.077086  3.778378  2.789447
# 18  3.098948  3.567031  3.577678  2.852964  3.291551  3.674892  3.098930
# 19  3.061544  3.638641  3.403160  2.826675  3.335632  3.554188  3.095675
# 20  3.351140  3.834833  3.707800  3.024070  3.451964  3.759708  3.198521
# 21  3.022553  3.651747  3.285387  2.799092  3.343464  3.467384  3.054996
# 22  2.719089  3.574024  2.849112  2.578518  3.295761  3.118439  3.129262
# 23  2.658527  3.645138  2.696301  2.531467  3.338073  2.982215  3.060500
#
# [24 rows x 25 columns]

# %%
dns_df_all[]
# Out:
#                                              filename  len_in_sec     sr  \
# 0   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 1   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 2   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 3   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 4   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 5   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 6   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 7   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 8   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 9   /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 10  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 11  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 12  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 13  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 14  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 15  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 16  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 17  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 18  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 19  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 20  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 21  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 22  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 23  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
#
#     num_hops  OVRL_raw   SIG_raw   BAK_raw      OVRL       SIG       BAK  \
# 0          3  3.250640  3.569253  3.914407  2.956952  3.292896  3.885182
# 1          3  3.098948  3.567031  3.577678  2.852964  3.291551  3.674892
# 2          3  3.242935  3.873020  3.431062  2.951245  3.473829  3.571971
# 3          3  2.899853  3.831106  2.904990  2.710857  3.449773  3.163255
# 4          3  2.586646  4.005170  2.293308  2.478224  3.547660  2.601352
# 5          3  3.281802  3.569847  3.958208  2.978015  3.293203  3.910056
# 6          3  1.234100  2.013977  1.175506  1.316100  2.087073  1.310244
# 7          3  2.925797  3.597889  3.205981  2.730339  3.310654  3.408863
# 8          3  2.902199  3.258051  3.590959  2.713323  3.091341  3.683641
# 9          3  2.901585  3.237231  3.737235  2.712785  3.077086  3.778378
# 10         3  2.774854  3.490637  3.049884  2.619823  3.243513  3.283981
# 11         3  2.940419  3.648328  3.104045  2.740022  3.340991  3.327170
# 12         3  3.022553  3.651747  3.285387  2.799092  3.343464  3.467384
# 13         3  2.769468  3.657641  2.861252  2.615563  3.346795  3.122203
# 14         3  2.524101  3.983687  2.158293  2.430466  3.535914  2.463592
# 15         3  3.351140  3.834833  3.707800  3.024070  3.451964  3.759708
# 16         3  3.065268  3.354978  3.882914  2.829282  3.155729  3.866300
# 17         3  2.719089  3.574024  2.849112  2.578518  3.295761  3.118439
# 18         3  2.658527  3.645138  2.696301  2.531467  3.338073  2.982215
# 19         3  2.076991  3.496364  1.816373  2.070776  3.247020  2.091951
# 20         3  2.467280  3.867449  2.184958  2.386278  3.470773  2.491255
# 21         3  1.989986  2.233114  3.208444  1.997832  2.312760  3.411415
# 22         3  2.407308  3.669547  2.280802  2.338848  3.353712  2.588965
# 23         3  3.061544  3.638641  3.403160  2.826675  3.335632  3.554188
#
#     P808_MOS
# 0   2.870284
# 1   3.098930
# 2   2.729020
# 3   2.894134
# 4   3.006527
# 5   3.082465
# 6   2.459364
# 7   3.146341
# 8   2.993399
# 9   2.789447
# 10  2.841168
# 11  2.873090
# 12  3.054996
# 13  3.119608
# 14  2.818142
# 15  3.198521
# 16  2.867439
# 17  3.129262
# 18  3.060500
# 19  3.011774
# 20  2.983341
# 21  2.078439
# 22  2.821618
# 23  3.095675

# %%
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 3/3 [00:00<00:00, 438.84it/s]
# 24it [00:05,  4.25it/s]
#          len_in_sec       sr  num_hops   OVRL_raw    SIG_raw    BAK_raw  \
# count  2.400000e+01     24.0      24.0  24.000000  24.000000  24.000000
# mean   3.072188e+00  16000.0       3.0   2.756376   3.511196   3.011586
# std    1.360922e-15      0.0       0.0   0.479085   0.471454   0.723804
# min    3.072188e+00  16000.0       3.0   1.234100   2.013977   1.175506
# 25%    3.072188e+00  16000.0       3.0   2.571010   3.494932   2.595553
# 50%    3.072188e+00  16000.0       3.0   2.900719   3.618265   3.155013
# 75%    3.072188e+00  16000.0       3.0   3.062475   3.709937   3.580998
# max    3.072188e+00  16000.0       3.0   3.351140   4.005170   3.958208
#
#             OVRL        SIG        BAK   P808_MOS
# count  24.000000  24.000000  24.000000  24.000000
# mean    2.591230   3.236965   3.188192   2.917645
# std     0.379245   0.342883   0.646231   0.244340
# min     1.316100   2.087073   1.310244   2.078439
# 25%     2.466285   3.246143   2.887000   2.836280
# 50%     2.711821   3.323143   3.368016   2.988370
# 75%     2.827327   3.377727   3.677079   3.085768
# max     3.024070   3.547660   3.910056   3.198521

# %%
dns_df
# Out:
#                                             filename  len_in_sec     sr  \
# 0  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 1  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 2  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
#
#    num_hops  OVRL_raw   SIG_raw   BAK_raw      OVRL       SIG       BAK  \
# 0         3  1.220763  1.944505  1.122648  1.306371  2.051766  1.244253
# 1         3  2.007946  3.612008  1.741228  2.012951  3.319237  2.006570
# 2         3  2.326704  3.889726  1.991992  2.275028  3.483384  2.286778
#
#    P808_MOS
# 0  2.510281
# 1  2.764667
# 2  2.866794

# %%
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 919.67it/s]
# 0it [00:00, ?it/s]
# 3it [00:01,  2.64it/s]
#        len_in_sec       sr  num_hops  OVRL_raw   SIG_raw   BAK_raw      OVRL  \
# count    3.000000      3.0       3.0  3.000000  3.000000  3.000000  3.000000
# mean     3.072188  16000.0       3.0  1.851804  3.148746  1.618623  1.864783
# std      0.000000      0.0       0.0  0.569264  1.052107  0.447452  0.501039
# min      3.072188  16000.0       3.0  1.220763  1.944505  1.122648  1.306371
# 25%      3.072188  16000.0       3.0  1.614355  2.778257  1.431938  1.659661
# 50%      3.072188  16000.0       3.0  2.007946  3.612008  1.741228  2.012951
# 75%      3.072188  16000.0       3.0  2.167325  3.750867  1.866610  2.143990
# max      3.072188  16000.0       3.0  2.326704  3.889726  1.991992  2.275028
#
#             SIG       BAK  P808_MOS
# count  3.000000  3.000000  3.000000
# mean   2.951462  1.845867  2.713914
# std    0.783471  0.539522  0.183595
# min    2.051766  1.244253  2.510281
# 25%    2.685501  1.625412  2.637474
# 50%    3.319237  2.006570  2.764667
# 75%    3.401311  2.146674  2.815730
# max    3.483384  2.286778  2.866794

# %%
dns_df
# Out:
#                                             filename  len_in_sec     sr  \
# 0  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 1  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
# 2  /data/ephraim/datasets/known_noise/undiff/exp_...    3.072188  16000
#
#    num_hops  OVRL_raw   SIG_raw   BAK_raw      OVRL       SIG       BAK  \
# 0         3  1.220763  1.944505  1.122648  1.306371  2.051766  1.244253
# 1         3  2.007946  3.612008  1.741228  2.012951  3.319237  2.006570
# 2         3  2.326704  3.889726  1.991992  2.275028  3.483384  2.286778
#
#    P808_MOS
# 0  2.510281
# 1  2.764667
# 2  2.866794

# %%
torchaudio.load(glob("/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/enhanced_60/snr5/s0.04/*wav")[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 torchaudio.load(glob("/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/c/enhanced_60/snr5/s0.04/*wav")[0])
#
# IndexError: list index out of range

# %%
ours
# Out:
# '/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/enhanced_60/snr5/s0.01/digits_snr5_power0.0019661201327046914_var0.00019275274073955498.wav'

# %%
enhanced_s
# Out:
# ['/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.01',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.04',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.05',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.06',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.07',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.08',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.09',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.1',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.11',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.12',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.13',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.14',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.15',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.16',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.17',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.18',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.19',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.2',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.21',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.22',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.23',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.24',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.25',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.3',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.35',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.4',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.5',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.7',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.8',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s1',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s1.2',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s1.5',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s2',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s3',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s4',
#  '/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/stats_dns.json']

# %%
glob("/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/enhanced_60/snr15/s0.01/*.wav")
# Out:
# ['/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/enhanced_60/snr15/s0.01/digits_snr15_power0.0001966120132704691_var1.927527407395549e-05.wav']

# %%
from asteroid.metrics import get_metrics

clean = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/clean_wav/LJ045-0072.wav"
noisy = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/noisy_wav/digits_snr5_power0.0019661201327046914_var0.00019275274073955498.wav"


speech_wav, SAMPLE_RATE_SPEECH = torchaudio.load(clean)
noise_wav, SAMPLE_RATE_NOISE = torchaudio.load(noisy)
data=[]
pathes = (glob("/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/enhanced_60/snr5/s*"))

for i,path_ in tqdm(enumerate(pathes)):
    ours = Path(path_)/"digits_snr5_power0.0019661201327046914_var0.00019275274073955498.wav"
    # s = Path(path_).name
    enhance, ensr = torchaudio.load(ours)
    # Compute metrics
    metrics = get_metrics(clean=speech_wav[0].numpy(), mix=noise_wav[0].numpy(),estimate=enhance[0].numpy(), sample_rate=16000)
    metrics["name"] = Path(path_).name
    # Print metrics
    # print(metrics)
    data.append(metrics)
    #[sgmse2 ,sgmse1,storm1,storm2,ours ]
df = pd.DataFrame.from_records(data,index=range(len(pathes))) 
print(df[["name","stoi","pesq","si_sdr","sdr", "sir","sar"]])
# Out:
# 0it [00:00, ?it/s]
# 35it [00:19,  1.76it/s]
#      name      stoi      pesq     si_sdr        sdr  sir        sar
# 0   s0.01  0.353197  1.062938 -64.825989 -27.333000  inf -27.333000
# 1   s0.04  0.396598  1.031105 -10.101040  -3.351145  inf  -3.351145
# 2   s0.05  0.463543  1.035519  -4.673670  -0.516497  inf  -0.516497
# 3   s0.06  0.433881  1.047396  -4.944730   0.626304  inf   0.626304
# 4   s0.07  0.511506  1.051811   0.763016   2.301575  inf   2.301575
# 5   s0.08  0.594236  1.063324   2.205606   3.914995  inf   3.914995
# 6   s0.09  0.601048  1.074659   3.440067   4.858814  inf   4.858814
# 7    s0.1  0.610531  1.101172   4.702497   6.025628  inf   6.025628
# 8   s0.11  0.710772  1.114754   5.361442   6.600272  inf   6.600272
# 9   s0.12  0.670574  1.105384   5.639671   6.807603  inf   6.807603
# 10  s0.13  0.642671  1.115147   5.797060   6.862854  inf   6.862854
# 11  s0.14  0.730910  1.154693   6.464624   7.217989  inf   7.217989
# 12  s0.15  0.769646  1.164315   7.349043   8.342362  inf   8.342362
# 13  s0.16  0.755454  1.159407   7.330917   8.166813  inf   8.166813
# 14  s0.17  0.812308  1.168539   7.897608   8.636819  inf   8.636819
# 15  s0.18  0.796717  1.167932   7.869333   8.655466  inf   8.655466
# 16  s0.19  0.811217  1.198832   8.386906   8.869232  inf   8.869232
# 17   s0.2  0.807217  1.187043   8.430483   8.880031  inf   8.880031
# 18  s0.21  0.817816  1.179732   8.936330   9.382163  inf   9.382163
# 19  s0.22  0.824586  1.218479   8.924810   9.342754  inf   9.342754
# 20  s0.23  0.831459  1.195913   8.914118   9.204101  inf   9.204101
# 21  s0.24  0.832868  1.185761   8.976956   9.362917  inf   9.362917
# 22  s0.25  0.841674  1.224421   9.267732   9.587707  inf   9.587707
# 23   s0.3  0.863595  1.283913   9.869423   9.886648  inf   9.886648
# 24  s0.35  0.865893  1.279356   9.599752   9.399407  inf   9.399407
# 25   s0.4  0.885058  1.414425   9.819670   9.557735  inf   9.557735
# 26   s0.5  0.899355  1.430953   9.813878   9.202316  inf   9.202316
# 27   s0.7  0.438282  1.020656 -11.886783 -12.108435  inf -12.108435
# 28   s0.8  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 29     s1  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 30   s1.2  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 31   s1.5  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 32     s2  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 33     s3  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 34     s4  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933

# %%
noisy_dir = "/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/noisy_wav/"
clean_dir = "/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/clean_wav/"
enhance_dir = "/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.3/"
noises = os.listdir(noisy_dir)
dont_calculated = []
results = {
    "pesq_noisy": {},
    "stoi_noisy": {},
    "pesq_enhanced": {},
    "stoi_enhanced": {},
}

i = 0

for ref_filename in tqdm(noises):
    reference = os.path.join(clean_dir, ref_filename)
    test_noisy = os.path.join(noisy_dir, ref_filename)
    # test_enhanced = os.path.join(enhance_dir, "1000k_0.wav")
    print(enhance_dir)
    test_files = glob(enhance_dir+"*.wav")
    print("test_files:", test_files)
    WAVEFORM_SPEECH, SAMPLE_RATE_SPEECH = torchaudio.load(reference)
    WAVEFORM_NOISE, SAMPLE_RATE_NOISE = torchaudio.load(test_noisy)
    
    stoi_enhanced_array = np.zeros(len(test_files))
    pesq_enhanced_array = np.zeros(len(test_files))
    stoi_enhanced = None
    pesq_enhanced = None
    try:
        for i, test_enhanced in enumerate(test_files):
            WAVEFORM_enhanced, SAMPLE_RATE_enhanced = torchaudio.load(test_enhanced)
            
            if WAVEFORM_SPEECH.shape[1] < WAVEFORM_enhanced.shape[1]:
                WAVEFORM_enhanced = WAVEFORM_enhanced[:, : WAVEFORM_SPEECH.shape[1]]
            else:
                WAVEFORM_SPEECH = WAVEFORM_SPEECH[:, : WAVEFORM_enhanced.shape[1]]
            if WAVEFORM_NOISE.shape[1] < WAVEFORM_enhanced.shape[1]:
                    WAVEFORM_enhanced = WAVEFORM_enhanced[:, : WAVEFORM_NOISE.shape[1]]
            else:
                WAVEFORM_NOISE = WAVEFORM_NOISE[:, : WAVEFORM_enhanced.shape[1]]
            
            metrics = get_metrics(clean=speech_wav[0].numpy(), mix=noise_wav[0].numpy(),estimate=enhance[0].numpy(), sample_rate=SAMPLE_RATE_SPEECH)
    except: 
        print("------------- failed --------------", enhance_dir)
        dont_calculated.append(ref_filename)
        stoi_enhanced = -1
        pesq_enhanced = -1

    df = pd.DataFrame.from_records(data,index=range(len(pathes))) 
    print(df[["name","stoi","pesq","si_sdr","sdr", "sir","sar"]])

    results["pesq_noisy"][ref_filename] = pesq_noise
    results["stoi_noisy"][ref_filename] = stoi_noise

    results["stoi_enhanced"][ref_filename] = stoi_enhanced
    results["pesq_enhanced"][ref_filename] = pesq_enhanced
    df = pd.DataFrame.from_dict(results)
    print("pesq_enhanced: ", pesq_enhanced)
    print("pesq_noisy: ", pesq_noise)
    print(df["pesq_noisy"])
    print(df["pesq_enhanced"])
    df["pesq_diff"] = df["pesq_enhanced"].sub(df["pesq_noisy"])
    df["stoi_diff"] = df["stoi_enhanced"].sub(df["stoi_noisy"])

    df.head()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# /data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.1/
# test_files: ['/data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.1/digits_snr5_power0.0032503484660146675_var0.0003345966415635422.wav']
# ------------- failed -------------- /data/ephraim/datasets/known_noise/undiff/exp_ar_i_095/b/enhanced_60/snr5/s0.1/
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 52
#      49     pesq_enhanced = -1
#      51 df = pd.DataFrame.from_records(data,index=range(len(test_files)))
# ---> 52 print(df[["name","stoi","pesq","si_sdr","sdr", "sir","sar"]])
#      55 df.head()
#
# File /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File /data/ephraim/downloads/anaconda/lib/python3.11/site-packages/pandas/core/indexes/base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['name', 'stoi', 'pesq', 'si_sdr', 'sdr', 'sir', 'sar'], dtype='object')] are in the [columns]"

# %%
df
# Out:
#                                                     pesq_noisy  stoi_noisy  \
# digits_snr5_power0.0032503484660146675_var0.000...          -1          -1
# digits_snr10_power0.0010278504341840744_var0.00...          -1          -1
# digits_snr15_power0.00032503484660146664_var3.3...          -1          -1
#
#                                                     pesq_enhanced  \
# digits_snr5_power0.0032503484660146675_var0.000...             -1
# digits_snr10_power0.0010278504341840744_var0.00...             -1
# digits_snr15_power0.00032503484660146664_var3.3...             -1
#
#                                                     stoi_enhanced  pesq_diff  \
# digits_snr5_power0.0032503484660146675_var0.000...             -1          0
# digits_snr10_power0.0010278504341840744_var0.00...             -1          0
# digits_snr15_power0.00032503484660146664_var3.3...             -1          0
#
#                                                     stoi_diff
# digits_snr5_power0.0032503484660146675_var0.000...          0
# digits_snr10_power0.0010278504341840744_var0.00...          0
# digits_snr15_power0.00032503484660146664_var3.3...          0

# %%
from pesq import pesq
from pystoi import stoi
clean = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/clean_wav/LJ045-0072.wav"

snr5path = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h/c/noisy_wav/digits_snr5_power0.001966120132704692_var0.0003768711770958883.wav"
snr10path = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h/c/noisy_wav/digits_snr10_power0.0006217417772859335_var0.00011917713040916882.wav"
snr15path = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h/c/noisy_wav/digits_snr15_power0.00019661201327046915_var3.768711770958882e-05.wav"
# enhancedpath = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h/a/enhanced_constant/snr15/s0.05/digits_snr15_power0.0003041422736918628_var5.7854771367023836e-05.wav"
# Out:
# 1.340324878692627
# 0.9084301417686218

# %%
import torch
import librosa
from asteroid.metrics import get_metrics

# %%
# wav_file_path = 'path/to/your/file.wav'

# # Load the .wav file
# audio, sample_rate = librosa.load(wav_file_path, sr=None)  # sr=None to preserve original sample rate

# # Convert audio to tensor
# audio_tensor = torch.tensor(audio).unsqueeze(0)  # Adding batch dimension

# # Assuming you have target and estimate tensors (here we use the same for demonstration)
# target_tensor = audio_tensor  # For demonstration purposes
# estimate_tensor = audio_tensor  # For demonstration purposes

# Compute metrics
metrics = get_metrics(clean=WAVEFORM_SPEECH[0].numpy(), mix=WAVEFORM_NOISE[0].numpy(),estimate=WAVEFORM_NOISE[0].numpy(), sample_rate=16000)

# Print metrics
print(metrics)
# Out:
# {'input_si_sdr': 13.555511474609375, 'input_sdr': 13.581198577406244, 'input_sir': inf, 'input_sar': 13.581198577406244, 'input_stoi': 0.8948478023683961, 'input_pesq': 1.3012539148330688, 'si_sdr': 13.555511474609375, 'sdr': 13.581198577406244, 'sir': inf, 'sar': 13.581198577406244, 'stoi': 0.8948478023683961, 'pesq': 1.3012539148330688}

# %%
stoi(WAVEFORM_SPEECH[0].numpy(),
                    WAVEFORM_NOISE[0].numpy(),
                    16000,
                    extended=False,
                )
# Out:
# 0.8948478023683961

# %%
enhance_dir = os.path.join(rootconstant, "snr15/s"+str(0.01))
pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
print(pkl_results_file)
if os.path.exists(pkl_results_file):
    print("b")
    with open(pkl_results_file, "rb") as handle:
        df5 = pd.read_pickle(handle)
        stats5 = df5.describe()
        print(stats5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 enhance_dir = os.path.join(rootconstant, "snr15/s"+str(0.01))
#       2 pkl_results_file = os.path.join(enhance_dir, "stats.pickle")
#       3 print(pkl_results_file)
#
# NameError: name 'rootconstant' is not defined

# %%
from pathlib import Path
# root_ = Path("/data/ephraim/datasets/known_noise/undiff/exp_ar_white/c/")
# root_ = Path("/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c")
root_ = Path("/data/ephraim/datasets/known_noise/undiff/exp_ar_h/c")

root40 = root_ / "enhanced_40/"
root50 =  root_ / "enhanced_50/"
root60 =  root_ / "enhanced_60/"
root90 =  root_ / "enhanced_90/"

rootlinear =  root_ / "enhanced_linear/"
rootconstant = root_ / "enhanced_constant/"
rootsinusoidal =  root_ / "enhanced_sinusoidal/"

# %%
df = df_for_snr(os.path.join(root60, "snr5"))
print(max(df.pesq))
print(df[df.pesq == max(df.pesq)]["stoi"])
print(df[df.pesq == max(df.pesq)]["s"])
df
# Out:
# 1.3799630403518677
# 14    0.8530429185718731
# Name: stoi, dtype: object
# 14    0.17
# Name: s, dtype: float64
#        s                pesq                stoi              pesq_diff  \
# 0   0.01  1.0271283388137817  0.3608944366879183   -0.14383288224538168
# 1   0.04  1.1168324947357178  0.6643616419847752   -0.05412872632344564
# 2   0.05   1.151658535003662  0.6803924809522389    -0.0193026860555013
# 3   0.06   1.165947437286377  0.7572962436486216  -0.005013783772786458
# 4   0.07  1.1953725814819336  0.7712611711114395   0.024411360422770183
# 5   0.08  1.2148081064224243  0.7969008230249818     0.0438468853632609
# 6   0.09  1.3369107246398926  0.8268875927685926    0.16594950358072916
# 7   0.10  1.2420588731765747  0.8360855701128612     0.0710976521174113
# 8   0.11   1.361473560333252  0.8404649452086611    0.19051233927408853
# 9   0.12  1.3325084447860718  0.8457943819757304    0.16154722372690836
# 10  0.13  1.3040618896484375  0.8590880134041702    0.13310066858927408
# 11  0.14  1.3211452960968018  0.8550156847121118    0.15018407503763834
# 12  0.15  1.3256964683532715  0.8567645837951229    0.15473524729410806
# 13  0.16  1.2803369760513306   0.856009436149369    0.10937575499216716
# 14  0.17  1.3799630403518677  0.8530429185718731    0.20900181929270426
# 15  0.18  1.2681927680969238  0.8565740656460058    0.09723154703776042
# 16  0.19  1.2802798748016357  0.8457441984862855    0.10931865374247234
# 17  0.20   1.315791368484497  0.8559108814930537    0.14483014742533365
# 18  0.21     1.2816241979599  0.8418087472821211     0.1106629769007365
# 19  0.22  1.2700101137161255  0.8478814533149008    0.09904889265696208
# 20  0.23  1.2497857809066772  0.8410896638741868    0.07882455984751384
# 21  0.24  1.2710567712783813  0.8576386061255645    0.10009555021921794
# 22  0.25  1.2639535665512085  0.8490727898323976    0.09299234549204509
# 23  0.30  1.2468183040618896  0.8443773317067107    0.07585708300272624
# 24  0.35   1.236937403678894  0.8280438196945082    0.06597618261973064
# 25  0.40  1.2547633647918701  0.8293799953640665    0.08380214373270671
# 26  0.50  1.2319080829620361  0.8168623409736062    0.06094686190287272
# 27  0.70  1.1769053936004639  0.8058242950681033   0.005944172541300456
# 28  0.80  1.1292474269866943  0.7839357711390446   -0.04171379407246908
# 29  1.00   1.043713927268982  0.4758813250828718    -0.1272472937901815
# 30  1.20   1.043713927268982  0.4758813250828718    -0.1272472937901815
# 31  1.50   1.043713927268982  0.4758813250828718    -0.1272472937901815
# 32  2.00   1.043713927268982  0.4758813250828718    -0.1272472937901815
# 33  3.00   1.043713927268982  0.4758813250828718    -0.1272472937901815
# 34  4.00   1.043713927268982  0.4758813250828718    -0.1272472937901815
#
#                  stoi_diff                OVRL                 SIG  \
# 0     -0.47947684132638174   1.675498456506092  2.3179688549254176
# 1      -0.1760096360295249   2.188643508990186   2.511838801770795
# 2     -0.15997879706206108  2.6136666855093997   2.980439119787928
# 3     -0.08307503436567854   2.785551262555258  3.1274824277794253
# 4     -0.06911010690286057  2.7842642479520907   3.084797194542489
# 5     -0.04347045498931845   2.684999707720435  3.0835318659291144
# 6    -0.013483685245707533  2.9527887096314664   3.259763388889884
# 7   -0.0042857079014387844   2.690049366476997   3.125134985623756
# 8    9.366719436099125e-05  2.6918681451918203  3.0262788861361436
# 9     0.005423103961430309  2.5541156461147545  2.9202046815433906
# 10    0.018716735389870065    2.71920367070091   3.330237314813258
# 11     0.01464440669781164  2.6544957162054903   3.308077703999894
# 12    0.016393305780822764  2.7116482272092863  3.1237943132170938
# 13    0.015638158135068858  3.0235500367349757  3.4360334885338246
# 14    0.012671640557572972  2.7941963804569645   3.231908056253644
# 15    0.016202787631705684   2.522174745185809  3.3493341485273262
# 16    0.005372920471985343  2.6291920005120866  3.2638346160097513
# 17    0.015539603478753494  3.0845253378272695  3.4752879682248596
# 18   0.0014374692678209566   2.907493273302105   3.463134026380158
# 19    0.007510175300600719  2.5703811762989726  3.4814119683553546
# 20   0.0007183858598867054   2.426589044523137  3.3573425349137906
# 21    0.017267328111264413  2.3448099149238106  3.3679489942728886
# 22     0.00870151181809753  2.4636906377779755  3.4343057516276634
# 23    0.004006053692410583   2.353511271122808   3.489855483337329
# 24   -0.012327458319791984    2.33801487665008  3.3863776059153357
# 25   -0.010991282650233747   2.143271475106817   3.352930448410575
# 26     -0.0235089370406939  2.0439225815609663  3.2402639118465735
# 27   -0.034546982946196736   1.754003791799047  2.9582025064114696
# 28    -0.05643550687525556  1.6244466877528287  2.8251823139019656
# 29    -0.36448995293142833  1.9978318181679848   2.312759831636081
# 30    -0.36448995293142833  1.9978318181679848   2.312759831636081
# 31    -0.36448995293142833  1.9978318181679848   2.312759831636081
# 32    -0.36448995293142833  1.9978318181679848   2.312759831636081
# 33    -0.36448995293142833  1.9978318181679848   2.312759831636081
# 34    -0.36448995293142833  1.9978318181679848   2.312759831636081
#
#                    BAK                                        enhance_dir  \
# 0    3.407133316669128  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1   3.6889125885542313  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2   3.7306778215473186  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3   3.8601268489024996  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4   3.9430881280694887  /data/ephraim/datasets/known_noise/undiff/exp_...
# 5     3.66341125736333  /data/ephraim/datasets/known_noise/undiff/exp_...
# 6     3.90914501551239  /data/ephraim/datasets/known_noise/undiff/exp_...
# 7   3.5915294699074045  /data/ephraim/datasets/known_noise/undiff/exp_...
# 8   3.7586584227005897  /data/ephraim/datasets/known_noise/undiff/exp_...
# 9   3.6272442842427886  /data/ephraim/datasets/known_noise/undiff/exp_...
# 10   3.279277629277076  /data/ephraim/datasets/known_noise/undiff/exp_...
# 11   3.229664192040545  /data/ephraim/datasets/known_noise/undiff/exp_...
# 12  3.6485421458854184  /data/ephraim/datasets/known_noise/undiff/exp_...
# 13  3.7658630224062875  /data/ephraim/datasets/known_noise/undiff/exp_...
# 14   3.631587934629078  /data/ephraim/datasets/known_noise/undiff/exp_...
# 15  2.8810263983956523  /data/ephraim/datasets/known_noise/undiff/exp_...
# 16  3.2531621102508996  /data/ephraim/datasets/known_noise/undiff/exp_...
# 17  3.8266205448019357  /data/ephraim/datasets/known_noise/undiff/exp_...
# 18  3.5230561626917356  /data/ephraim/datasets/known_noise/undiff/exp_...
# 19  2.8157655283593317  /data/ephraim/datasets/known_noise/undiff/exp_...
# 20   2.731247920600318  /data/ephraim/datasets/known_noise/undiff/exp_...
# 21  2.5426935590698734  /data/ephraim/datasets/known_noise/undiff/exp_...
# 22   2.709077397172189  /data/ephraim/datasets/known_noise/undiff/exp_...
# 23   2.402495749723179  /data/ephraim/datasets/known_noise/undiff/exp_...
# 24      2.502324426044  /data/ephraim/datasets/known_noise/undiff/exp_...
# 25  2.2504628120470205  /data/ephraim/datasets/known_noise/undiff/exp_...
# 26   2.009438805120977  /data/ephraim/datasets/known_noise/undiff/exp_...
# 27   1.743605023869067  /data/ephraim/datasets/known_noise/undiff/exp_...
# 28  1.5077045089195413  /data/ephraim/datasets/known_noise/undiff/exp_...
# 29  3.4114148129843467  /data/ephraim/datasets/known_noise/undiff/exp_...
# 30  3.4114148129843467  /data/ephraim/datasets/known_noise/undiff/exp_...
# 31  3.4114148129843467  /data/ephraim/datasets/known_noise/undiff/exp_...
# 32  3.4114148129843467  /data/ephraim/datasets/known_noise/undiff/exp_...
# 33  3.4114148129843467  /data/ephraim/datasets/known_noise/undiff/exp_...
# 34  3.4114148129843467  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...
# 14  Namespace(enhanced_dir='/data/ephraim/datasets...
# 15  Namespace(enhanced_dir='/data/ephraim/datasets...
# 16  Namespace(enhanced_dir='/data/ephraim/datasets...
# 17  Namespace(enhanced_dir='/data/ephraim/datasets...
# 18  Namespace(enhanced_dir='/data/ephraim/datasets...
# 19  Namespace(enhanced_dir='/data/ephraim/datasets...
# 20  Namespace(enhanced_dir='/data/ephraim/datasets...
# 21  Namespace(enhanced_dir='/data/ephraim/datasets...
# 22  Namespace(enhanced_dir='/data/ephraim/datasets...
# 23  Namespace(enhanced_dir='/data/ephraim/datasets...
# 24  Namespace(enhanced_dir='/data/ephraim/datasets...
# 25  Namespace(enhanced_dir='/data/ephraim/datasets...
# 26  Namespace(enhanced_dir='/data/ephraim/datasets...
# 27  Namespace(enhanced_dir='/data/ephraim/datasets...
# 28  Namespace(enhanced_dir='/data/ephraim/datasets...
# 29  Namespace(enhanced_dir='/data/ephraim/datasets...
# 30  Namespace(enhanced_dir='/data/ephraim/datasets...
# 31  Namespace(enhanced_dir='/data/ephraim/datasets...
# 32  Namespace(enhanced_dir='/data/ephraim/datasets...
# 33  Namespace(enhanced_dir='/data/ephraim/datasets...
# 34  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
#calc metrics againt noisy - maybe can choose s
import torch
import librosa
from tqdm import tqdm
from glob import glob
from asteroid.metrics import get_metrics



clean = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/clean_wav/LJ045-0072.wav"
noisy = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/noisy_wav/digits_snr5_power0.0019661201327046914_var0.00019275274073955498.wav"


speech_wav, SAMPLE_RATE_SPEECH = torchaudio.load(clean)
noise_wav, SAMPLE_RATE_NOISE = torchaudio.load(noisy)
data=[]
pathes = (glob("/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/enhanced_60/snr5/s*"))

for i,path_ in tqdm(enumerate(pathes)):
    ours = Path(path_)/"digits_snr5_power0.0019661201327046914_var0.00019275274073955498.wav"
    # s = Path(path_).name
    enhance, ensr = torchaudio.load(ours)
    # Compute metrics
    metrics = get_metrics(clean=speech_wav[0].numpy(), mix=noise_wav[0].numpy(),estimate=enhance[0].numpy(), sample_rate=16000)
    metrics["name"] = Path(path_).name
    # Print metrics
    # print(metrics)
    data.append(metrics)
    #[sgmse2 ,sgmse1,storm1,storm2,ours ]
df = pd.DataFrame.from_records(data,index=range(len(pathes))) 
print(df[["name","stoi","pesq","si_sdr","sdr", "sir","sar"]])
# Out:
# 0it [00:00, ?it/s]
# 35it [00:18,  1.85it/s]
#      name      stoi      pesq     si_sdr        sdr  sir        sar
# 0   s0.01  0.353197  1.062938 -64.825989 -27.333000  inf -27.333000
# 1   s0.04  0.396598  1.031105 -10.101040  -3.351145  inf  -3.351145
# 2   s0.05  0.463543  1.035519  -4.673670  -0.516497  inf  -0.516497
# 3   s0.06  0.433881  1.047396  -4.944730   0.626304  inf   0.626304
# 4   s0.07  0.511506  1.051811   0.763016   2.301575  inf   2.301575
# 5   s0.08  0.594236  1.063324   2.205606   3.914995  inf   3.914995
# 6   s0.09  0.601048  1.074659   3.440067   4.858814  inf   4.858814
# 7    s0.1  0.610531  1.101172   4.702497   6.025628  inf   6.025628
# 8   s0.11  0.710772  1.114754   5.361442   6.600272  inf   6.600272
# 9   s0.12  0.670574  1.105384   5.639671   6.807603  inf   6.807603
# 10  s0.13  0.642671  1.115147   5.797060   6.862854  inf   6.862854
# 11  s0.14  0.730910  1.154693   6.464624   7.217989  inf   7.217989
# 12  s0.15  0.769646  1.164315   7.349043   8.342362  inf   8.342362
# 13  s0.16  0.755454  1.159407   7.330917   8.166813  inf   8.166813
# 14  s0.17  0.812308  1.168539   7.897608   8.636819  inf   8.636819
# 15  s0.18  0.796717  1.167932   7.869333   8.655466  inf   8.655466
# 16  s0.19  0.811217  1.198832   8.386906   8.869232  inf   8.869232
# 17   s0.2  0.807217  1.187043   8.430483   8.880031  inf   8.880031
# 18  s0.21  0.817816  1.179732   8.936330   9.382163  inf   9.382163
# 19  s0.22  0.824586  1.218479   8.924810   9.342754  inf   9.342754
# 20  s0.23  0.831459  1.195913   8.914118   9.204101  inf   9.204101
# 21  s0.24  0.832868  1.185761   8.976956   9.362917  inf   9.362917
# 22  s0.25  0.841674  1.224421   9.267732   9.587707  inf   9.587707
# 23   s0.3  0.863595  1.283913   9.869423   9.886648  inf   9.886648
# 24  s0.35  0.865893  1.279356   9.599752   9.399407  inf   9.399407
# 25   s0.4  0.885058  1.414425   9.819670   9.557735  inf   9.557735
# 26   s0.5  0.899355  1.430953   9.813878   9.202316  inf   9.202316
# 27   s0.7  0.438282  1.020656 -11.886783 -12.108435  inf -12.108435
# 28   s0.8  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 29     s1  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 30   s1.2  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 31   s1.5  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 32     s2  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 33     s3  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933
# 34     s4  0.475881  1.043714 -79.936211 -16.616933  inf -16.616933

# %%
#calc metrics againt noisy - maybe can choose s
import torch
import librosa
from tqdm import tqdm
from glob import glob
from asteroid.metrics import get_metrics


clean = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/clean_wav/LJ045-0072.wav"
noisy = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/noisy_wav/digits_snr5_power0.0019661201327046914_var0.00019275274073955498.wav"


speech_wav, SAMPLE_RATE_SPEECH = torchaudio.load(clean)
noise_wav, SAMPLE_RATE_NOISE = torchaudio.load(noisy)
data=[]
pathes = (glob("/data/ephraim/datasets/known_noise/undiff/exp_ar_h_0.99/c/enhanced_60/snr5/s*"))

for i,path_ in tqdm(enumerate(pathes)):
    ours = Path(path_)/"digits_snr5_power0.0019661201327046914_var0.00019275274073955498.wav"
    # s = Path(path_).name
    enhance, ensr = torchaudio.load(ours)
    # Compute metrics
    metrics = get_metrics(clean=noise_wav[0].numpy(), mix=noise_wav[0].numpy(),estimate=enhance[0].numpy(), sample_rate=16000)
    metrics["name"] = Path(path_).name
    # Print metrics
    # print(metrics)
    data.append(metrics)
    #[sgmse2 ,sgmse1,storm1,storm2,ours ]
df = pd.DataFrame.from_records(data,index=range(len(pathes))) 
print(df[["name","stoi","pesq","si_sdr","sdr", "sir","sar"]])
# Out:
# 0it [00:00, ?it/s]
# 35it [00:17,  2.00it/s]
#      name      stoi      pesq     si_sdr        sdr  sir        sar
# 0   s0.01  0.023996  1.036760 -48.827812 -25.961935  inf -25.961935
# 1   s0.04  0.124999  1.064239 -11.061398  -4.296213  inf  -4.296213
# 2   s0.05  0.241652  1.051729  -6.041173  -1.453495  inf  -1.453495
# 3   s0.06  0.216599  1.071157  -6.661726  -0.894341  inf  -0.894341
# 4   s0.07  0.338127  1.046701  -2.001199   0.705708  inf   0.705708
# 5   s0.08  0.407562  1.041903  -1.059867   1.615222  inf   1.615222
# 6   s0.09  0.418278  1.040727  -0.402974   2.579752  inf   2.579752
# 7    s0.1  0.432810  1.040719   0.421921   3.320174  inf   3.320174
# 8   s0.11  0.544100  1.044273   0.796982   3.655694  inf   3.655694
# 9   s0.12  0.516292  1.042668   0.850605   3.794015  inf   3.794015
# 10  s0.13  0.483211  1.037653   0.969407   3.640432  inf   3.640432
# 11  s0.14  0.565251  1.041228   1.361476   3.898725  inf   3.898725
# 12  s0.15  0.606539  1.038613   1.697929   4.480550  inf   4.480550
# 13  s0.16  0.595399  1.040406   1.730795   4.371912  inf   4.371912
# 14  s0.17  0.629705  1.041930   1.995107   4.435658  inf   4.435658
# 15  s0.18  0.615656  1.045207   2.014401   4.609694  inf   4.609694
# 16  s0.19  0.633454  1.040743   2.180523   4.589722  inf   4.589722
# 17   s0.2  0.626893  1.040375   2.451471   4.667058  inf   4.667058
# 18  s0.21  0.639326  1.039471   2.504370   4.677209  inf   4.677209
# 19  s0.22  0.640540  1.040991   2.492940   4.875574  inf   4.875574
# 20  s0.23  0.654400  1.045045   2.623886   4.810293  inf   4.810293
# 21  s0.24  0.656828  1.043798   2.596640   4.929930  inf   4.929930
# 22  s0.25  0.664785  1.042277   2.818279   5.068783  inf   5.068783
# 23   s0.3  0.683792  1.043773   3.163611   5.197000  inf   5.197000
# 24  s0.35  0.687992  1.046919   3.528089   5.273241  inf   5.273241
# 25   s0.4  0.706232  1.047991   3.934532   5.647409  inf   5.647409
# 26   s0.5  0.717513  1.054932   4.390933   5.899700  inf   5.899700
# 27   s0.7  0.240772  1.032914  -9.942677  -8.837977  inf  -8.837977
# 28   s0.8  0.030589  1.061256 -51.499336  -9.677972  inf  -9.677972
# 29     s1  0.030589  1.061256 -51.499336  -9.677972  inf  -9.677972
# 30   s1.2  0.030589  1.061256 -51.499336  -9.677972  inf  -9.677972
# 31   s1.5  0.030589  1.061256 -51.499336  -9.677972  inf  -9.677972
# 32     s2  0.030589  1.061256 -51.499336  -9.677972  inf  -9.677972
# 33     s3  0.030589  1.061256 -51.499336  -9.677972  inf  -9.677972
# 34     s4  0.030589  1.061256 -51.499336  -9.677972  inf  -9.677972

# %%
print(df[15:][["name","stoi","pesq","si_sdr","sdr", "sir","sar"]])
# 'si_sdr': -48.538665771484375,
#  'sdr': -20.16799081672319,
#  'sir': inf,
#  'sar': -20.16799
# Out:
#      name      stoi      pesq     si_sdr       sdr  sir       sar
# 15  s0.18  0.615656  1.045207   2.014401  4.609694  inf  4.609694
# 16  s0.19  0.633454  1.040743   2.180523  4.589722  inf  4.589722
# 17   s0.2  0.626893  1.040375   2.451471  4.667058  inf  4.667058
# 18  s0.21  0.639326  1.039471   2.504370  4.677209  inf  4.677209
# 19  s0.22  0.640540  1.040991   2.492940  4.875574  inf  4.875574
# 20  s0.23  0.654400  1.045045   2.623886  4.810293  inf  4.810293
# 21  s0.24  0.656828  1.043798   2.596640  4.929930  inf  4.929930
# 22  s0.25  0.664785  1.042277   2.818279  5.068783  inf  5.068783
# 23   s0.3  0.683792  1.043773   3.163611  5.197000  inf  5.197000
# 24  s0.35  0.687992  1.046919   3.528089  5.273241  inf  5.273241
# 25   s0.4  0.706232  1.047991   3.934532  5.647409  inf  5.647409
# 26   s0.5  0.717513  1.054932   4.390933  5.899700  inf  5.899700
# 27   s0.7  0.240772  1.032914  -9.942677 -8.837977  inf -8.837977
# 28   s0.8  0.030589  1.061256 -51.499336 -9.677972  inf -9.677972
# 29     s1  0.030589  1.061256 -51.499336 -9.677972  inf -9.677972
# 30   s1.2  0.030589  1.061256 -51.499336 -9.677972  inf -9.677972
# 31   s1.5  0.030589  1.061256 -51.499336 -9.677972  inf -9.677972
# 32     s2  0.030589  1.061256 -51.499336 -9.677972  inf -9.677972
# 33     s3  0.030589  1.061256 -51.499336 -9.677972  inf -9.677972
# 34     s4  0.030589  1.061256 -51.499336 -9.677972  inf -9.677972

# %%
Path("/data/ephraim/datasets/known_noise/undiff/exp_ar_h/b/enhanced_60/snr5/s0.01/").name
# Out:
# 's0.01'

# %%
df = df_for_snr(os.path.join(rootconstant, "snr5"))
print(max(df.pesq))
df
# Out:
# 1.1946148872375488
#        s                pesq                 stoi              pesq_diff  \
# 0   0.01   1.022957444190979   0.4198762016825633    -0.1227857271830241
# 1   0.04  1.1472238302230835    0.803464672797916  0.0014806588490804036
# 2   0.05  1.1801098585128784   0.8638902670308247    0.03436668713887533
# 3   0.06  1.1946148872375488   0.8630571288458259    0.04887171586354574
# 4   0.07  1.1643410921096802    0.865348725527753   0.018597920735677082
# 5   0.08  1.1513864994049072   0.8621343946718781   0.005643328030904134
# 6   0.09  1.1368775367736816   0.8505936123655014  -0.008865634600321451
# 7   0.10  1.1166263818740845   0.8473445486089638   -0.02911678949991862
# 8   0.11  1.1078381538391113    0.839714950768187   -0.03790501753489176
# 9   0.12   1.102105975151062    0.829838428116671   -0.04363719622294108
# 10  0.13  1.0910301208496094    0.825335098211197  -0.054713050524393715
# 11  0.14  1.0755574703216553   0.8158072731337219   -0.07018570105234782
# 12  0.15  1.0699117183685303    0.804366471330941   -0.07583145300547282
# 13  0.16   1.065861701965332   0.8018808488008092   -0.07988146940867107
# 14  0.17  1.0572477579116821    0.794778766252476   -0.08849541346232097
# 15  0.18   1.053419589996338   0.7908725374101859    -0.0923235813776652
# 16  0.19   1.048478126525879    0.785443506704591   -0.09726504484812419
# 17  0.20  1.0468063354492188   0.7849739958540128   -0.09893683592478435
# 18  0.21   1.043425440788269   0.7775014729644258   -0.10231773058573405
# 19  0.22  1.0415477752685547   0.7751382127525236   -0.10419539610544841
# 20  0.23  1.0401310920715332   0.7719457561397197    -0.1056120793024699
# 21  0.24   1.037898302078247   0.7697901754037852   -0.10784486929575603
# 22  0.25  1.0365443229675293   0.7676414040863441    -0.1091988484064738
# 23  0.30  1.0287426710128784   0.7483516063579562   -0.11700050036112468
# 24  0.35   1.055466890335083  0.24361448978449038   -0.09027628103892009
# 25  0.40  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 26  0.50  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 27  0.70  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 28  0.80  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 29  1.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 30  1.20  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 31  1.50  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 32  2.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 33  3.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 34  4.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
#
#                  stoi_diff                OVRL                 SIG  \
# 0     -0.40095557737259346   2.643365509901421  3.0256898923046665
# 1    -0.017367106257240843  2.2467800941186487  3.3010025287889015
# 2      0.04305848797566788   2.391246599585339   3.398785482117778
# 3      0.04222534979066902  2.5513869795429542  3.4517166656255673
# 4      0.04451694647259615  2.4486718461027768  3.5365179837747363
# 5     0.041302615616721404  2.3086791970469673  3.5090764658667455
# 6     0.029761833310344505   2.307815813559109   3.534660844894098
# 7     0.026512769553807065  2.3115127991286464    3.55947137397122
# 8     0.018883171713030073  2.2059519497228175  3.5474887158970145
# 9     0.009006649061514013  2.1070390132657897   3.507732206258418
# 10    0.004503319156040149   2.158033707936764  3.5613871063000317
# 11  -0.0050245059214348116   2.083819777246796   3.499099402713015
# 12   -0.016465307724215877  2.0542020197711794  3.4646283438574677
# 13   -0.018950930254347725  1.9522226765631878   3.318041076469414
# 14   -0.026053012802680835   1.991582951752903  3.3882384304696704
# 15   -0.029959241644970918  1.9004147145375871  3.3078115623751287
# 16    -0.03538827235056589   1.986252517748357   3.385404299035549
# 17    -0.03585778320114411  1.8835647563600992   3.256880304132762
# 18      -0.043330306090731  1.8452263308397925  3.2374452938961005
# 19    -0.04569356630263336   1.786581737377082   3.125396540095275
# 20    -0.04888602291543712  1.8196901361547673  3.2283239348435595
# 21    -0.05104160365137159   1.746368852933325  3.0446385953615547
# 22    -0.05319037496881277  1.8184191285003435  3.2340435272472194
# 23    -0.07248017269720068   1.441728525906287  2.4280914374972675
# 24     -0.5772172892706665   1.098152944392634  1.2137307830289845
# 25      -0.357344151663652   2.050853804747207  2.3948427066511497
# 26      -0.357344151663652   2.050853804747207  2.3948427066511497
# 27      -0.357344151663652   2.050853804747207  2.3948427066511497
# 28      -0.357344151663652   2.050853804747207  2.3948427066511497
# 29      -0.357344151663652   2.050853804747207  2.3948427066511497
# 30      -0.357344151663652   2.050853804747207  2.3948427066511497
# 31      -0.357344151663652   2.050853804747207  2.3948427066511497
# 32      -0.357344151663652   2.050853804747207  2.3948427066511497
# 33      -0.357344151663652   2.050853804747207  2.3948427066511497
# 34      -0.357344151663652   2.050853804747207  2.3948427066511497
#
#                    BAK                                        enhance_dir  \
# 0    3.755884478472936  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1   2.4209744771975723  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2   2.5560648175239074  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3    2.769356453884298  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4   2.4501732748117617  /data/ephraim/datasets/known_noise/undiff/exp_...
# 5   2.2494320479995213  /data/ephraim/datasets/known_noise/undiff/exp_...
# 6   2.2452589423673137  /data/ephraim/datasets/known_noise/undiff/exp_...
# 7   2.2197132345164152  /data/ephraim/datasets/known_noise/undiff/exp_...
# 8    2.011982563565733  /data/ephraim/datasets/known_noise/undiff/exp_...
# 9   1.8815939849421546  /data/ephraim/datasets/known_noise/undiff/exp_...
# 10  1.9338126543060805  /data/ephraim/datasets/known_noise/undiff/exp_...
# 11  1.8500135313634498  /data/ephraim/datasets/known_noise/undiff/exp_...
# 12  1.7849564440016465  /data/ephraim/datasets/known_noise/undiff/exp_...
# 13  1.7367856903192904  /data/ephraim/datasets/known_noise/undiff/exp_...
# 14  1.7767124546586952  /data/ephraim/datasets/known_noise/undiff/exp_...
# 15  1.6832698128712802  /data/ephraim/datasets/known_noise/undiff/exp_...
# 16  1.7964339266277878  /data/ephraim/datasets/known_noise/undiff/exp_...
# 17   1.664525179444204  /data/ephraim/datasets/known_noise/undiff/exp_...
# 18  1.6879807029474652  /data/ephraim/datasets/known_noise/undiff/exp_...
# 19  1.6685644782775848  /data/ephraim/datasets/known_noise/undiff/exp_...
# 20   1.653461069614476  /data/ephraim/datasets/known_noise/undiff/exp_...
# 21  1.6312648592943408  /data/ephraim/datasets/known_noise/undiff/exp_...
# 22  1.6229487278299988  /data/ephraim/datasets/known_noise/undiff/exp_...
# 23   1.344459075503581  /data/ephraim/datasets/known_noise/undiff/exp_...
# 24  1.1804165115023253  /data/ephraim/datasets/known_noise/undiff/exp_...
# 25  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 26  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 27  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 28  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 29  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 30  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 31  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 32  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 33  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 34  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...
# 14  Namespace(enhanced_dir='/data/ephraim/datasets...
# 15  Namespace(enhanced_dir='/data/ephraim/datasets...
# 16  Namespace(enhanced_dir='/data/ephraim/datasets...
# 17  Namespace(enhanced_dir='/data/ephraim/datasets...
# 18  Namespace(enhanced_dir='/data/ephraim/datasets...
# 19  Namespace(enhanced_dir='/data/ephraim/datasets...
# 20  Namespace(enhanced_dir='/data/ephraim/datasets...
# 21  Namespace(enhanced_dir='/data/ephraim/datasets...
# 22  Namespace(enhanced_dir='/data/ephraim/datasets...
# 23  Namespace(enhanced_dir='/data/ephraim/datasets...
# 24  Namespace(enhanced_dir='/data/ephraim/datasets...
# 25  Namespace(enhanced_dir='/data/ephraim/datasets...
# 26  Namespace(enhanced_dir='/data/ephraim/datasets...
# 27  Namespace(enhanced_dir='/data/ephraim/datasets...
# 28  Namespace(enhanced_dir='/data/ephraim/datasets...
# 29  Namespace(enhanced_dir='/data/ephraim/datasets...
# 30  Namespace(enhanced_dir='/data/ephraim/datasets...
# 31  Namespace(enhanced_dir='/data/ephraim/datasets...
# 32  Namespace(enhanced_dir='/data/ephraim/datasets...
# 33  Namespace(enhanced_dir='/data/ephraim/datasets...
# 34  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df = df_for_snr(os.path.join(root60, "snr5"))
print(max(df.pesq))
df
# Out:
# 1.3547475337982178
#        s                pesq                stoi              pesq_diff  \
# 0   0.01  1.0280380249023438  0.2205348748343944   -0.11770514647165935
# 1   0.04  1.1173017024993896  0.6988403514119699  -0.028441468874613445
# 2   0.05  1.1538439989089966  0.7292166750996262    0.00810082753499349
# 3   0.06  1.2630536556243896  0.7836766511923149    0.11731048425038655
# 4   0.07  1.2653493881225586  0.8188582746304759     0.1196062167485555
# 5   0.08    1.30306875705719  0.8113574721726385    0.15732558568318686
# 6   0.09  1.2854890823364258  0.8295548705701427     0.1397459109624227
# 7   0.10  1.3240017890930176  0.8293700777769532     0.1782586177190145
# 8   0.11  1.2958664894104004  0.8407890775130992     0.1501233180363973
# 9   0.12    1.30734121799469  0.8452712397025506    0.16159804662068686
# 10  0.13  1.2921454906463623  0.8402733320695691    0.14640231927235922
# 11  0.14   1.256935715675354  0.8441411924026784     0.1111925443013509
# 12  0.15  1.3380541801452637   0.856940022225329     0.1923110087712606
# 13  0.16  1.3006924390792847  0.8562774200834596    0.15494926770528158
# 14  0.17  1.3029279708862305  0.8414759505238201    0.15718479951222739
# 15  0.18  1.3038116693496704  0.8657806563512603    0.15806849797566733
# 16  0.19  1.2915736436843872  0.8493970086410476    0.14583047231038412
# 17  0.20   1.280745267868042  0.8463828128894625     0.1350020964940389
# 18  0.21  1.3547475337982178  0.8532288366426046     0.2090043624242147
# 19  0.22  1.3202232122421265  0.8455742855500045    0.17448004086812338
# 20  0.23  1.3104376792907715  0.8402622629262991     0.1646945079167684
# 21  0.24    1.27950119972229  0.8324452195851699    0.13375802834828696
# 22  0.25  1.2765916585922241  0.8381993350750626    0.13084848721822104
# 23  0.30  1.2790411710739136  0.8399441087846314     0.1332979996999105
# 24  0.35  1.2163137197494507  0.8035164387851571    0.07057054837544759
# 25  0.40  1.1955113410949707  0.7923159262729583    0.04976816972096761
# 26  0.50  1.1660429239273071  0.7829397692596936   0.020299752553304035
# 27  0.70  1.1175576448440552  0.7674102542927587  -0.028185526529947918
# 28  0.80  1.0617036819458008  0.7024822675842484   -0.08403948942820232
# 29  1.00  1.0801525115966797  0.4634876273915048   -0.06559065977732341
# 30  1.20  1.0801525115966797  0.4634876273915048   -0.06559065977732341
# 31  1.50  1.0801525115966797  0.4634876273915048   -0.06559065977732341
# 32  2.00  1.0801525115966797  0.4634876273915048   -0.06559065977732341
# 33  3.00  1.0801525115966797  0.4634876273915048   -0.06559065977732341
# 34  4.00  1.0801525115966797  0.4634876273915048   -0.06559065977732341
#
#                 stoi_diff                OVRL                 SIG  \
# 0     -0.6002969042207624  2.5821971983023673  2.8847652149629885
# 1    -0.12199142764318698   2.661393988559077   2.982303400579439
# 2    -0.09161510395553067  2.5860106239324705   2.918025257924709
# 3   -0.037155127862841954   2.826515434708167  3.1449004257268567
# 4   -0.001973504424680842  3.0963938569404235   3.361930018112385
# 5   -0.009474306882518194  2.9747119756328386   3.261974347365123
# 6    0.008723091514985922   2.839866500023882  3.1429922274287825
# 7    0.008538298721796308   2.854918652904417   3.148753138637402
# 8    0.019957298457942325   2.880727236300278  3.2070950699678606
# 9    0.024439460647393735   3.126131651699687  3.4553539575436822
# 10   0.019441553014412267  3.0695039025014137   3.398501962433301
# 11    0.02330941334752153  2.8809281163447813  3.4585303027986862
# 12   0.036108243170172104  2.7320070900722646  3.2512944001024087
# 13    0.03544564102830291   2.735645746399956   3.371045485192574
# 14   0.020644171468663226   2.663606199223241  3.4163646490865176
# 15   0.044948877296103494  2.7867666564852915   3.526842890238887
# 16   0.028565229585890767  2.7531132619700385   3.510414156378323
# 17   0.025551033834305643  2.4963560027965244  3.4608133445049174
# 18   0.032397057587447785  2.6888067966705997   3.538018659810025
# 19   0.024742506494847622  2.5089938235321783   3.549095857426597
# 20   0.019430483871142396  2.4912522617815385   3.520143983175103
# 21   0.011613440530013083   2.509622566037681  3.5255099200985813
# 22   0.017367556019905656  2.5194397251637723   3.576177391256062
# 23    0.01911232972947448  2.4478300232515555  3.5549211837093098
# 24   -0.01731534026999985   2.248526977176714   3.499077615217476
# 25   -0.02851585278219852  2.1632109117172957  3.4870271059513587
# 26   -0.03789200979546329  1.9271804708580744  3.2043899782101404
# 27   -0.05342152476239829  1.8574363048466844  3.2349907831300975
# 28   -0.11834951147090848  1.1108903093619398  1.1855296057419624
# 29     -0.357344151663652   2.050853804747207  2.3948427066511497
# 30     -0.357344151663652   2.050853804747207  2.3948427066511497
# 31     -0.357344151663652   2.050853804747207  2.3948427066511497
# 32     -0.357344151663652   2.050853804747207  2.3948427066511497
# 33     -0.357344151663652   2.050853804747207  2.3948427066511497
# 34     -0.357344151663652   2.050853804747207  2.3948427066511497
#
#                    BAK                                        enhance_dir  \
# 0    3.827388877428699  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1   3.8090712771251054  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2   3.7859156035551744  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3   3.9001891847446575  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4    4.052067428531795  /data/ephraim/datasets/known_noise/undiff/exp_...
# 5   3.9862500110000063  /data/ephraim/datasets/known_noise/undiff/exp_...
# 6    3.909891179147993  /data/ephraim/datasets/known_noise/undiff/exp_...
# 7   3.9508708442614924  /data/ephraim/datasets/known_noise/undiff/exp_...
# 8   3.8978137910227417  /data/ephraim/datasets/known_noise/undiff/exp_...
# 9    3.963394599206964  /data/ephraim/datasets/known_noise/undiff/exp_...
# 10  3.9210061370647495  /data/ephraim/datasets/known_noise/undiff/exp_...
# 11  3.4307500285881503  /data/ephraim/datasets/known_noise/undiff/exp_...
# 12   3.458992395297632  /data/ephraim/datasets/known_noise/undiff/exp_...
# 13  3.3046097980042264  /data/ephraim/datasets/known_noise/undiff/exp_...
# 14  3.0910946956019854  /data/ephraim/datasets/known_noise/undiff/exp_...
# 15   3.166318993707099  /data/ephraim/datasets/known_noise/undiff/exp_...
# 16   3.136577353320707  /data/ephraim/datasets/known_noise/undiff/exp_...
# 17   2.640135128779671  /data/ephraim/datasets/known_noise/undiff/exp_...
# 18  2.9347289299127524  /data/ephraim/datasets/known_noise/undiff/exp_...
# 19   2.565386174966591  /data/ephraim/datasets/known_noise/undiff/exp_...
# 20   2.560467798084943  /data/ephraim/datasets/known_noise/undiff/exp_...
# 21   2.603934643115096  /data/ephraim/datasets/known_noise/undiff/exp_...
# 22  2.5618113366018145  /data/ephraim/datasets/known_noise/undiff/exp_...
# 23  2.4844498768471337  /data/ephraim/datasets/known_noise/undiff/exp_...
# 24  2.1419720638248756  /data/ephraim/datasets/known_noise/undiff/exp_...
# 25   2.019520458789802  /data/ephraim/datasets/known_noise/undiff/exp_...
# 26  1.8133347993763957  /data/ephraim/datasets/known_noise/undiff/exp_...
# 27  1.7312286953050917  /data/ephraim/datasets/known_noise/undiff/exp_...
# 28  1.1020606344385149  /data/ephraim/datasets/known_noise/undiff/exp_...
# 29  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 30  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 31  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 32  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 33  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 34  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...
# 14  Namespace(enhanced_dir='/data/ephraim/datasets...
# 15  Namespace(enhanced_dir='/data/ephraim/datasets...
# 16  Namespace(enhanced_dir='/data/ephraim/datasets...
# 17  Namespace(enhanced_dir='/data/ephraim/datasets...
# 18  Namespace(enhanced_dir='/data/ephraim/datasets...
# 19  Namespace(enhanced_dir='/data/ephraim/datasets...
# 20  Namespace(enhanced_dir='/data/ephraim/datasets...
# 21  Namespace(enhanced_dir='/data/ephraim/datasets...
# 22  Namespace(enhanced_dir='/data/ephraim/datasets...
# 23  Namespace(enhanced_dir='/data/ephraim/datasets...
# 24  Namespace(enhanced_dir='/data/ephraim/datasets...
# 25  Namespace(enhanced_dir='/data/ephraim/datasets...
# 26  Namespace(enhanced_dir='/data/ephraim/datasets...
# 27  Namespace(enhanced_dir='/data/ephraim/datasets...
# 28  Namespace(enhanced_dir='/data/ephraim/datasets...
# 29  Namespace(enhanced_dir='/data/ephraim/datasets...
# 30  Namespace(enhanced_dir='/data/ephraim/datasets...
# 31  Namespace(enhanced_dir='/data/ephraim/datasets...
# 32  Namespace(enhanced_dir='/data/ephraim/datasets...
# 33  Namespace(enhanced_dir='/data/ephraim/datasets...
# 34  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df = df_for_snr(os.path.join(root50, "snr5"))
print(max(df.pesq))
df
# Out:
# 1.3447929620742798
#        s                pesq                 stoi              pesq_diff  \
# 0   0.01  1.0707439184188843  0.21717561428342905   -0.07499925295511882
# 1   0.04  1.0946760177612305    0.683014135720463   -0.05106715361277262
# 2   0.05  1.1789579391479492   0.7305411897086568    0.03321476777394613
# 3   0.06  1.2161773443222046   0.7736044044721749    0.07043417294820149
# 4   0.07   1.232875108718872   0.7795850380183401    0.08713193734486897
# 5   0.08  1.2742427587509155   0.8029074477016688    0.12849958737691244
# 6   0.09  1.3266525268554688   0.8178245503085373    0.18090935548146567
# 7   0.10  1.2816250324249268   0.8279769055799976    0.13588186105092367
# 8   0.11  1.3424872159957886    0.839271683785045     0.1967440446217855
# 9   0.12  1.2858961820602417   0.8341192785544923    0.14015301068623862
# 10  0.13  1.3055744171142578   0.8491954559929304    0.15983124574025473
# 11  0.14  1.2920061349868774   0.8472132236175117    0.14626296361287436
# 12  0.15  1.2848422527313232   0.8366369639163884    0.13909908135732016
# 13  0.16   1.293657660484314   0.8358899091863817    0.14791448911031088
# 14  0.17  1.2717336416244507    0.836983588314773     0.1259904702504476
# 15  0.18  1.3447929620742798   0.8525965291460847     0.1990497907002767
# 16  0.19  1.3098833560943604   0.8499302992111691    0.16414018472035727
# 17  0.20  1.3286060094833374   0.8514826863954421    0.18286283810933432
# 18  0.21  1.2856709957122803   0.8472028507401465     0.1399278243382772
# 19  0.22  1.3075491189956665   0.8387299711982555    0.16180594762166342
# 20  0.23  1.3241829872131348   0.8538496499443208    0.17843981583913168
# 21  0.24  1.3210340738296509   0.8386484346090138     0.1752909024556478
# 22  0.25  1.2768501043319702   0.8253513615007361    0.13110693295796713
# 23  0.30  1.2777409553527832   0.8376266323653606    0.13199778397878012
# 24  0.35   1.261561632156372   0.8305198677284243    0.11581846078236897
# 25  0.40  1.2091331481933594    0.812432065450162    0.06338997681935628
# 26  0.50  1.1780060529708862   0.7851729878069807    0.03226288159688314
# 27  0.70  1.1394151449203491   0.7830543880302359  -0.006328026453653972
# 28  0.80  1.1228169202804565   0.7643210771183545   -0.02292625109354655
# 29  1.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 30  1.20  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 31  1.50  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 32  2.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 33  3.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 34  4.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
#
#                  stoi_diff                OVRL                 SIG  \
# 0      -0.6036561647717277   2.692440007941762    2.99547263425356
# 1     -0.13781764333469385   2.628197573474648  2.9464464524264526
# 2     -0.09029058934650007  2.7216338514478626  3.0042645687354494
# 3     -0.04722737458298202  2.6680965074680154   2.964591004353301
# 4    -0.041246741036816616  2.9749840114139707  3.2613964675393055
# 5     -0.01792433135348807   2.838107182286265   3.147608557368156
# 6   -0.0030072287466195538     3.0371068807153  3.3196432291544697
# 7     0.007145126524840746   2.943743922527458   3.209682073265111
# 8     0.018439904729888063  3.0526913810529335  3.3182535685531107
# 9     0.013287499499335572   3.044873485162729  3.3522937274962494
# 10    0.028363676937773603   3.097469924087048  3.3930214303392314
# 11     0.02638144456235499  2.9934101839108536     3.2837802085324
# 12    0.015805184861231576   2.896130857990209   3.380886331957626
# 13    0.015058130131224886   2.797858165043387   3.356036806873949
# 14    0.016151809259616196  2.9670641816911454  3.4693437811031873
# 15    0.031764750090927794   2.889965789334539  3.5034139361508143
# 16    0.029098520156012293   2.955807081855967  3.4741831975952095
# 17    0.030650907340285267  2.6454228637959494   3.424772352790929
# 18    0.026371071684989606   2.600399727865866  3.3895717414423077
# 19    0.017898192143098807     2.8424489003878   3.590379470792527
# 20    0.033017870889163935   2.511459897534284   3.507548159195102
# 21    0.017816655553856992  2.6859123741202917  3.5619530359272007
# 22    0.004519582445579225   2.762087369394851  3.5554705816903933
# 23    0.016794853310203767   2.418757954668838   3.557678533676587
# 24      0.0096880886732675  2.2906707436071314   3.518649967573324
# 25   -0.008399713604994844  2.2768736492629045  3.5291231978703297
# 26   -0.035658791248176204   2.136722266935847   3.393480833909343
# 27    -0.03777739102492098  1.9520903331668393    3.31387156823437
# 28   -0.056510701936802334  1.9572762377327426   3.272098082233945
# 29      -0.357344151663652   2.050853804747207  2.3948427066511497
# 30      -0.357344151663652   2.050853804747207  2.3948427066511497
# 31      -0.357344151663652   2.050853804747207  2.3948427066511497
# 32      -0.357344151663652   2.050853804747207  2.3948427066511497
# 33      -0.357344151663652   2.050853804747207  2.3948427066511497
# 34      -0.357344151663652   2.050853804747207  2.3948427066511497
#
#                    BAK                                        enhance_dir  \
# 0    3.870030156232887  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1    3.836497543446048  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2    3.918007193562509  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3   3.8969516064521867  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4    3.983048123179443  /data/ephraim/datasets/known_noise/undiff/exp_...
# 5   3.9061221284272145  /data/ephraim/datasets/known_noise/undiff/exp_...
# 6    4.016039552378761  /data/ephraim/datasets/known_noise/undiff/exp_...
# 7    3.987823499244501  /data/ephraim/datasets/known_noise/undiff/exp_...
# 8    4.038926220413257  /data/ephraim/datasets/known_noise/undiff/exp_...
# 9   3.9731403308375275  /data/ephraim/datasets/known_noise/undiff/exp_...
# 10   4.010097901601687  /data/ephraim/datasets/known_noise/undiff/exp_...
# 11  3.9768328798339962  /data/ephraim/datasets/known_noise/undiff/exp_...
# 12  3.6514615641278376  /data/ephraim/datasets/known_noise/undiff/exp_...
# 13  3.5053201475124802  /data/ephraim/datasets/known_noise/undiff/exp_...
# 14  3.6079797905823114  /data/ephraim/datasets/known_noise/undiff/exp_...
# 15  3.3948314467970113  /data/ephraim/datasets/known_noise/undiff/exp_...
# 16  3.6242631000963494  /data/ephraim/datasets/known_noise/undiff/exp_...
# 17  2.9885620452610198  /data/ephraim/datasets/known_noise/undiff/exp_...
# 18   2.976555123669864  /data/ephraim/datasets/known_noise/undiff/exp_...
# 19   3.120814680078348  /data/ephraim/datasets/known_noise/undiff/exp_...
# 20   2.652335012744215  /data/ephraim/datasets/known_noise/undiff/exp_...
# 21  2.8478625224740033  /data/ephraim/datasets/known_noise/undiff/exp_...
# 22  2.9919072642475517  /data/ephraim/datasets/known_noise/undiff/exp_...
# 23  2.4054249107777923  /data/ephraim/datasets/known_noise/undiff/exp_...
# 24   2.204925938946174  /data/ephraim/datasets/known_noise/undiff/exp_...
# 25   2.160762551478688  /data/ephraim/datasets/known_noise/undiff/exp_...
# 26  2.0526251845954184  /data/ephraim/datasets/known_noise/undiff/exp_...
# 27  1.8014738284091567  /data/ephraim/datasets/known_noise/undiff/exp_...
# 28   1.889516731778466  /data/ephraim/datasets/known_noise/undiff/exp_...
# 29  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 30  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 31  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 32  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 33  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 34  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...
# 14  Namespace(enhanced_dir='/data/ephraim/datasets...
# 15  Namespace(enhanced_dir='/data/ephraim/datasets...
# 16  Namespace(enhanced_dir='/data/ephraim/datasets...
# 17  Namespace(enhanced_dir='/data/ephraim/datasets...
# 18  Namespace(enhanced_dir='/data/ephraim/datasets...
# 19  Namespace(enhanced_dir='/data/ephraim/datasets...
# 20  Namespace(enhanced_dir='/data/ephraim/datasets...
# 21  Namespace(enhanced_dir='/data/ephraim/datasets...
# 22  Namespace(enhanced_dir='/data/ephraim/datasets...
# 23  Namespace(enhanced_dir='/data/ephraim/datasets...
# 24  Namespace(enhanced_dir='/data/ephraim/datasets...
# 25  Namespace(enhanced_dir='/data/ephraim/datasets...
# 26  Namespace(enhanced_dir='/data/ephraim/datasets...
# 27  Namespace(enhanced_dir='/data/ephraim/datasets...
# 28  Namespace(enhanced_dir='/data/ephraim/datasets...
# 29  Namespace(enhanced_dir='/data/ephraim/datasets...
# 30  Namespace(enhanced_dir='/data/ephraim/datasets...
# 31  Namespace(enhanced_dir='/data/ephraim/datasets...
# 32  Namespace(enhanced_dir='/data/ephraim/datasets...
# 33  Namespace(enhanced_dir='/data/ephraim/datasets...
# 34  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df = df_for_snr(os.path.join(root40, "snr5"))
print(max(df.pesq[1:]))
df
# Out:
# 1.354715347290039
#        s                pesq                 stoi              pesq_diff  \
# 0   0.01   3.199397087097168  0.23327341329614415      2.053653915723165
# 1   0.04  1.0972042083740234   0.6571884524768428   -0.04853896299997965
# 2   0.05  1.1637510061264038   0.7151977993762135   0.018007834752400715
# 3   0.06  1.1982425451278687   0.7600711122333018    0.05249937375386556
# 4   0.07   1.238625168800354   0.7528161234668233     0.0928819974263509
# 5   0.08  1.2801117897033691   0.7730409406166029    0.13436861832936606
# 6   0.09  1.2837543487548828   0.7946490034443211    0.13801117738087973
# 7   0.10  1.2992762327194214    0.821391190156238     0.1535330613454183
# 8   0.11  1.2942956686019897   0.8234291764171647    0.14855249722798666
# 9   0.12  1.3166111707687378   0.8231851236437565     0.1708679993947347
# 10  0.13  1.3154774904251099   0.8210872541965092    0.16973431905110678
# 11  0.14   1.354715347290039   0.8305405444126648    0.20897217591603598
# 12  0.15  1.3141512870788574   0.8324034313085705    0.16840811570485434
# 13  0.16   1.247187852859497   0.8343102159034851    0.10144468148549397
# 14  0.17  1.2580835819244385   0.8317407512051079    0.11234041055043538
# 15  0.18  1.2724350690841675   0.8269492202008178     0.1266918977101644
# 16  0.19  1.2720847129821777    0.855577650910963    0.12634154160817465
# 17  0.20  1.2797297239303589   0.8404337768751544     0.1339865525563558
# 18  0.21   1.329930067062378   0.8479006725494269    0.18418689568837485
# 19  0.22  1.3068910837173462   0.8423835137911734     0.1611479123433431
# 20  0.23  1.3198384046554565   0.8346949080424885    0.17409523328145346
# 21  0.24  1.2617815732955933   0.8413751071027992    0.11603840192159016
# 22  0.25  1.2830688953399658   0.8345247857007104    0.13732572396596274
# 23  0.30  1.2788249254226685   0.8405357453725698    0.13308175404866537
# 24  0.35   1.246886968612671   0.8249328834147437     0.1011437972386678
# 25  0.40  1.2328431606292725   0.8198757486604965    0.08709998925526936
# 26  0.50  1.2130476236343384    0.812957666315819    0.06730445226033528
# 27  0.70  1.1492222547531128   0.7789217268606521  0.0034790833791097007
# 28  0.80  1.1352016925811768    0.768131089932421  -0.010541478792826334
# 29  1.00  1.1203655004501343   0.7668506813707906  -0.025377670923868816
# 30  1.20  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 31  1.50  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 32  2.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 33  3.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
# 34  4.00  1.0801525115966797   0.4634876273915048   -0.06559065977732341
#
#                  stoi_diff                OVRL                 SIG  \
# 0      -0.5875583657590128   2.537409178742718   2.874587533446576
# 1     -0.16364332657831407  2.6912783191877203  3.0038447869574236
# 2     -0.10563397967894332   2.489424989055585   2.843681821834757
# 3    -0.060760666821855026   2.685438353725032  3.0083522924040706
# 4     -0.06801565558833349  2.7599161087719213  3.0365232142289917
# 5     -0.04779083843855384   2.637821930182318   2.977011076212178
# 6    -0.026182775610835745  2.7442469184481006   3.079304835133623
# 7    0.0005594111010810051   2.906188424403811   3.198711426515644
# 8     0.002597397362007777  2.9081472170290295  3.1805104569416516
# 9     0.002353344588599556  2.8506592339210166  3.1352401903639406
# 10  0.00025547514135245325   3.082719189352813  3.3787829731527883
# 11     0.00970876535750794   2.924699469319186  3.2836676148671198
# 12    0.011571652253413686   2.934823654464167     3.3450329219598
# 13    0.013478436848328243  2.9420182338526115   3.270777099132293
# 14    0.010908972149951087  2.9858729188050215   3.347973242124676
# 15    0.006117441145660892   3.188431130823438  3.5600035432392154
# 16      0.0347458718558061  2.7982402749903996  3.3078370594519697
# 17     0.01960199781999757   2.792038295732177  3.3063370463249804
# 18     0.02706889349427007  2.6559848537614386  3.4370126367975193
# 19    0.021551734736016532  2.8279752221721695  3.5641345241369726
# 20    0.013863128987331627  2.7511391531266147  3.4793893030546124
# 21    0.020543328047642213  2.5301762291916807    3.40767725722138
# 22    0.013693006645553693  2.8867061197600585  3.5654235030450527
# 23    0.019703966317412964   2.748050611230124  3.5220590254229314
# 24    0.004101104359586845  2.4758659832708045  3.5442251436701455
# 25   -0.000956030394660227   2.440873175497837  3.5742181969560507
# 26   -0.007874112739337727    2.23760531264892   3.463111691167435
# 27   -0.041910052194504756  2.1682098264165544  3.4519343275652674
# 28    -0.05270068912273588  1.7360145057889274  2.9355846936453864
# 29    -0.05398109768436624  1.9104396602263425  3.2149725874377952
# 30      -0.357344151663652   2.050853804747207  2.3948427066511497
# 31      -0.357344151663652   2.050853804747207  2.3948427066511497
# 32      -0.357344151663652   2.050853804747207  2.3948427066511497
# 33      -0.357344151663652   2.050853804747207  2.3948427066511497
# 34      -0.357344151663652   2.050853804747207  2.3948427066511497
#
#                    BAK                                        enhance_dir  \
# 0    3.903794391970983  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1   3.8757294731309715  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2   3.7145368485522687  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3   3.8168751240476886  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4   3.9335892550803875  /data/ephraim/datasets/known_noise/undiff/exp_...
# 5    3.801853767722403  /data/ephraim/datasets/known_noise/undiff/exp_...
# 6   3.8262362199311957  /data/ephraim/datasets/known_noise/undiff/exp_...
# 7   3.9639656764241873  /data/ephraim/datasets/known_noise/undiff/exp_...
# 8   4.0030149302144125  /data/ephraim/datasets/known_noise/undiff/exp_...
# 9   3.9441065130075086  /data/ephraim/datasets/known_noise/undiff/exp_...
# 10   4.002256704662983  /data/ephraim/datasets/known_noise/undiff/exp_...
# 11  3.8412079157942194  /data/ephraim/datasets/known_noise/undiff/exp_...
# 12   3.767886769998597  /data/ephraim/datasets/known_noise/undiff/exp_...
# 13  3.9129004875104623  /data/ephraim/datasets/known_noise/undiff/exp_...
# 14   3.858271437895065  /data/ephraim/datasets/known_noise/undiff/exp_...
# 15  3.8773483693576742  /data/ephraim/datasets/known_noise/undiff/exp_...
# 16  3.5760962278648463  /data/ephraim/datasets/known_noise/undiff/exp_...
# 17   3.519525795964589  /data/ephraim/datasets/known_noise/undiff/exp_...
# 18  2.9841213510821745  /data/ephraim/datasets/known_noise/undiff/exp_...
# 19   3.182593362981838  /data/ephraim/datasets/known_noise/undiff/exp_...
# 20   3.149283705425585  /data/ephraim/datasets/known_noise/undiff/exp_...
# 21   2.787137678083812  /data/ephraim/datasets/known_noise/undiff/exp_...
# 22  3.2788185899803834  /data/ephraim/datasets/known_noise/undiff/exp_...
# 23  3.0714438595239906  /data/ephraim/datasets/known_noise/undiff/exp_...
# 24   2.517463948616365  /data/ephraim/datasets/known_noise/undiff/exp_...
# 25  2.4480860263133053  /data/ephraim/datasets/known_noise/undiff/exp_...
# 26   2.157151384999487  /data/ephraim/datasets/known_noise/undiff/exp_...
# 27  2.0596927994411254  /data/ephraim/datasets/known_noise/undiff/exp_...
# 28  1.6594042144950458  /data/ephraim/datasets/known_noise/undiff/exp_...
# 29  1.8268450846318418  /data/ephraim/datasets/known_noise/undiff/exp_...
# 30  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 31  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 32  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 33  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
# 34  3.4148480480126153  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 13  Namespace(enhanced_dir='/data/ephraim/datasets...
# 14  Namespace(enhanced_dir='/data/ephraim/datasets...
# 15  Namespace(enhanced_dir='/data/ephraim/datasets...
# 16  Namespace(enhanced_dir='/data/ephraim/datasets...
# 17  Namespace(enhanced_dir='/data/ephraim/datasets...
# 18  Namespace(enhanced_dir='/data/ephraim/datasets...
# 19  Namespace(enhanced_dir='/data/ephraim/datasets...
# 20  Namespace(enhanced_dir='/data/ephraim/datasets...
# 21  Namespace(enhanced_dir='/data/ephraim/datasets...
# 22  Namespace(enhanced_dir='/data/ephraim/datasets...
# 23  Namespace(enhanced_dir='/data/ephraim/datasets...
# 24  Namespace(enhanced_dir='/data/ephraim/datasets...
# 25  Namespace(enhanced_dir='/data/ephraim/datasets...
# 26  Namespace(enhanced_dir='/data/ephraim/datasets...
# 27  Namespace(enhanced_dir='/data/ephraim/datasets...
# 28  Namespace(enhanced_dir='/data/ephraim/datasets...
# 29  Namespace(enhanced_dir='/data/ephraim/datasets...
# 30  Namespace(enhanced_dir='/data/ephraim/datasets...
# 31  Namespace(enhanced_dir='/data/ephraim/datasets...
# 32  Namespace(enhanced_dir='/data/ephraim/datasets...
# 33  Namespace(enhanced_dir='/data/ephraim/datasets...
# 34  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr10"))
# Out:
#       s                pesq                stoi            pesq_diff  \
# 0  0.08  1.3363275527954102  0.8313439828647876  0.19058438142140707
# 1  0.09  1.3694021701812744  0.8440864170032581  0.22365899880727133
# 2  0.10  1.4475719928741455  0.8469163546661753   0.3018288215001424
# 3  0.11  1.3462779521942139  0.8512710462943627  0.20053478082021078
# 4  0.12  1.4107733964920044  0.8468873037465127   0.2650302251180013
#
#               stoi_diff                OVRL                 SIG  \
# 0  0.010512203809630768   3.008532975097011  3.2849140069696126
# 1  0.023254637948101304   3.067142700739397  3.3288875880494393
# 2  0.026084575611018474  2.8402440488674108  3.1685712275310154
# 3   0.03043926723920583  2.9843682842886423  3.2506307293632823
# 4   0.02605552469135582  2.9204127467389327    3.20951995772565
#
#                   BAK                                        enhance_dir  \
# 0   4.003008946114903  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1    4.03347685921523  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2  3.8769413575467437  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3   4.021016291325195  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4   3.963281631383091  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root, "snr5"))
# Out:
#       s                pesq                stoi            pesq_diff  \
# 0  0.08  1.2866277694702148  0.7958022881010288  0.14088459809621176
# 1  0.09  1.3068293333053589  0.8149432461417239   0.1610861619313558
# 2  0.10  1.3198009729385376  0.8231705318137955  0.17405780156453451
# 3  0.11  1.3300397396087646  0.8125959235510477  0.18429656823476157
# 4  0.12  1.2993483543395996  0.8248268862315905  0.15360518296559653
#
#                stoi_diff                OVRL                 SIG  \
# 0  -0.025029490954128025   2.939316116153949   3.201993595968438
# 1   -0.00588853291343298   2.886819158264178  3.1726079279454544
# 2   0.002338752758638781  3.0347695593135637  3.3308817152656927
# 3  -0.008235855504109138  2.9444836401109664   3.257530809917793
# 4   0.003995107176433661   3.049432716520656   3.347135369913055
#
#                   BAK                                        enhance_dir  \
# 0     4.0326263232035  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1   3.987465393895875  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2   3.999094025913247  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3  3.9329797674713602  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4  3.9948876421372965  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root3, "snr15"))
# Out:
#       s                pesq                stoi            pesq_diff  \
# 0  0.08  1.4534249305725098  0.8531579724764052   0.2824637095133464
# 1  0.09  1.5040901899337769   0.863698264289242  0.33312896887461346
# 2  0.10   1.452805995941162  0.8610060151024171   0.2818447748819987
# 3  0.11  1.4896039962768555  0.8700805086371362   0.3186427752176921
# 4  0.12  1.5052533149719238   0.876972730154538  0.33429209391276044
#
#               stoi_diff                OVRL                 SIG  \
# 0   0.01278669446210512  2.7086637069256647  3.0981661968068757
# 1  0.023326986274942008  2.6663326175651108  3.0232076425415717
# 2  0.020634737088117028   2.841425097561246   3.186895680824097
# 3  0.029709230622836036    2.73172976071206   3.122046405942147
# 4   0.03660145214023791   2.776574656105288   3.193859475018854
#
#                   BAK                                        enhance_dir  \
# 0  3.6788305656001907  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1   3.739285336256575  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2   3.847254098367715  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3  3.6857826761910366  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4   3.654566616366535  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root3, "snr10"))
# Out:
#       s                pesq                stoi            pesq_diff  \
# 0  0.08  1.3116207122802734  0.8381862279224187  0.14065949122111002
# 1  0.09  1.4776527881622314  0.8426161693062738  0.30669156710306805
# 2  0.10   1.444916009902954  0.8523864476521482   0.2739547888437907
# 3  0.11  1.4609041213989258  0.8588395982473656   0.2899429003397624
# 4  0.12  1.5091910362243652  0.8803922800553936  0.33822981516520184
#
#                stoi_diff                OVRL                 SIG  \
# 0  -0.002185050091881302  2.9724788753275675   3.305533353898163
# 1   0.002244891291973694   2.895651519960565  3.1898450191110967
# 2     0.0120151696378481   2.817817159229057  3.2517856899804976
# 3    0.01846832023306544    2.93425350474876  3.2926312865336684
# 4    0.04002100204109349  2.8724889197199044  3.2265463533517953
#
#                   BAK                                        enhance_dir  \
# 0   3.895674881816047  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1   3.924122279758682  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2   3.645233583214438  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3  3.8152852191401116  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4   3.804683208267676  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df_for_snr(os.path.join(root3, "snr5"))
# Out:
#       s                pesq                stoi             pesq_diff  \
# 0  0.08  1.2062665224075317  0.8034713250469357  0.035305301348368325
# 1  0.09  1.3068782091140747  0.8292934009566194    0.1359169880549113
# 2  0.10  1.3275423049926758  0.8454350783685906   0.15658108393351236
# 3  0.11  1.2545945644378662  0.8465975385697754    0.0836333433787028
# 4  0.12  1.2743067741394043  0.8352514622184447   0.10334555308024089
#
#                stoi_diff                OVRL                 SIG  \
# 0   -0.03689995296736426  2.7970824127653757  3.1648422602186685
# 1  -0.011077877057680707  2.8318605954805363   3.164703786655263
# 2  0.0050638003542905485  2.7990791422242083  3.1164520407672303
# 3    0.00622626055547526  2.5166672790475357   3.078401826611054
# 4   -0.00511981579585552  2.6742694620132084  3.0247461431208698
#
#                   BAK                                        enhance_dir  \
# 0  3.7431165591315465  /data/ephraim/datasets/known_noise/undiff/exp_...
# 1  3.8550084965176765  /data/ephraim/datasets/known_noise/undiff/exp_...
# 2  3.8320517280745974  /data/ephraim/datasets/known_noise/undiff/exp_...
# 3  3.2567981031459383  /data/ephraim/datasets/known_noise/undiff/exp_...
# 4  3.6922309758753795  /data/ephraim/datasets/known_noise/undiff/exp_...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
list(np.logspace(-2,0.7,num=40))
# Out:
# [0.01,
#  0.011728183955791524,
#  0.013755029890088569,
#  0.01613215208683696,
#  0.018920084727722997,
#  0.02218982341458972,
#  0.02602463309528382,
#  0.03052216843234688,
#  0.035796960610421716,
#  0.04198333390972491,
#  0.04923882631706739,
#  0.05774820128138352,
#  0.0677281527744142,
#  0.07943282347242814,
#  0.09316027658125524,
#  0.10926008611173785,
#  0.1281422388944084,
#  0.15028757502606052,
#  0.17626003261754578,
#  0.2067210086592391,
#  0.24244620170823283,
#  0.2843453653017093,
#  0.33348547512351867,
#  0.39111789988331647,
#  0.45871026782343877,
#  0.5379838403443686,
#  0.6309573444801934,
#  0.7399983804321428,
#  0.8678837132695973,
#  1.0178699841461256,
#  1.1937766417144369,
#  1.4000832056153938,
#  1.6420433388871634,
#  1.9258186341850783,
#  2.2586355207213766,
#  2.6489692876105297,
#  3.10675990983383,
#  3.643665172900946,
#  4.27335754210932,
#  5.011872336272722]

# %%
p_path = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h/c/snr10_50_0.1.pickle"
with open(p_path, "rb") as handle:
    loss_array_snr10_50_01 = pd.read_pickle(handle)
p_path = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h/c/snr10_50_0.11.pickle"
with open(p_path, "rb") as handle:
    loss_array_snr10_50_11 = pd.read_pickle(handle)
p_path = "/data/ephraim/datasets/known_noise/undiff/exp_ar_h/c/snr5_50_0.11.pickle"
with open(p_path, "rb") as handle:
    loss_array_snr5_50_11 = pd.read_pickle(handle)

# %%
loss_array_snr5_50_11
# Out:
# [tensor(92648.7734, device='cuda:0', requires_grad=True)]

# %%
loss_array_snr10_50_01
# Out:
# [tensor(89082.4688, device='cuda:0', requires_grad=True)]

# %%
loss_array_snr10_50_11
# Out:
# [tensor(89558.6953, device='cuda:0', requires_grad=True)]
